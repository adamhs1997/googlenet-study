# %% [markdown]
# Synthesizing [adversarial examples](https://arxiv.org/abs/1312.6199) for neural networks is surprisingly easy: small, carefully-crafted perturbations to inputs can cause neural networks to misclassify inputs in arbitrarily chosen ways. Given that adversarial examples [transfer to the physical world](https://arxiv.org/abs/1607.02533) and [can be made extremely robust](https://blog.openai.com/robust-adversarial-inputs/), this is a real security concern.
#
# In this post, we give a brief introduction to algorithms for synthesizing adversarial examples, and we walk through the process of implementing attacks in [TensorFlow](https://www.tensorflow.org/), building up to synthesizing a robust adversarial example following [this technique](https://arxiv.org/abs/1707.07397).
#
# **This post is an executable [Jupyter notebook](http://jupyter.org/): you're encouraged to [download it](/media/2017/07/25/adversarial.ipynb) and experiment with the examples yourself!**

# %% [markdown]
# # Setup
#
# We choose to attack an [Inception v3](https://arxiv.org/abs/1512.00567) network trained on [ImageNet](http://www.image-net.org/). In this section, we load a pre-trained network from the [TF-slim image classification library](https://github.com/tensorflow/models/tree/master/slim). This part isn't particularly interesting, so **feel free to [skip this section](#adversarial-examples)**.

# %%
import tensorflow as tf
import tensorflow.contrib.slim as slim
import tensorflow.contrib.slim.nets as nets

# %%
tf.logging.set_verbosity(tf.logging.ERROR)
sess = tf.InteractiveSession()

# %% [markdown]
# First, we set up the input image. We use a `tf.Variable` instead of a `tf.placeholder` because we will need it to be trainable. We can still feed it when we want to.

# %%
image = tf.Variable(tf.zeros((224, 224, 3)))

# %% [markdown]
# Next, we load the Inception v3 model.

# %%
def inception(image, reuse):
    preprocessed = tf.multiply(tf.subtract(tf.expand_dims(image, 0), 0.5), 2.0)
    arg_scope = nets.inception.inception_v1_arg_scope(weight_decay=0.0)
    with slim.arg_scope(arg_scope):
        logits, _ = nets.inception.inception_v1(
            preprocessed, 1001, is_training=False, reuse=reuse)
        logits = logits[:,1:] # ignore background class
        probs = tf.nn.softmax(logits) # probabilities
    return logits, probs

logits, probs = inception(image, reuse=False)

# %% [markdown]
# Next, we load pre-trained weights. This Inception v3 has a top-5 accuracy of 93.9%.

# %%
import tempfile
from urllib.request import urlretrieve
import tarfile
import os

# %%
data_dir = tempfile.mkdtemp()
inception_tarball, _ = urlretrieve(
    'http://download.tensorflow.org/models/inception_v1_2016_08_28.tar.gz')
tarfile.open(inception_tarball, 'r:gz').extractall(data_dir)

# %%
restore_vars = [
    var for var in tf.global_variables()
    if var.name.startswith('InceptionV1/')
]
saver = tf.train.Saver(restore_vars)
saver.restore(sess, os.path.join(data_dir, 'inception_v1.ckpt'))

# %% [markdown]
# Next, we write some code to show an image, classify it, and show the classification result.

# %%
import json
import matplotlib.pyplot as plt

# %%
imagenet_json, _ = urlretrieve(
    'http://www.anishathalye.com/media/2017/07/25/imagenet.json')
with open(imagenet_json) as f:
    imagenet_labels = json.load(f)

# %%
def classify(img, correct_class=None, target_class=None):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 8))
    fig.sca(ax1)
    p = sess.run(probs, feed_dict={image: img})[0]
    ax1.imshow(img)
    fig.sca(ax1)
    
    topk = list(p.argsort()[-10:][::-1])
    topprobs = p[topk]
    barlist = ax2.bar(range(10), topprobs)
    if target_class in topk:
        barlist[topk.index(target_class)].set_color('r')
    if correct_class in topk:
        barlist[topk.index(correct_class)].set_color('g')
    plt.sca(ax2)
    plt.ylim([0, 1.1])
    plt.xticks(range(10),
               [imagenet_labels[i][:15] for i in topk],
               rotation='vertical')
    fig.subplots_adjust(bottom=0.2)
    plt.show()

# %% [markdown]
# ## Example image
#
# We load our example image and make sure it's classified correctly.

# %%
import PIL
import numpy as np
from os import listdir
from os.path import isdir

# %%
# Define our custom get_top_five
def get_top_five(path, img):
    # Get predictions
    p = sess.run(probs, feed_dict={image: img})[0]
    topk = list(p.argsort()[-10:][::-1])
    topprobs = p[topk]
    
    # Put results in nice list
    current_results = [path]
    for i in range(5):
        current_results.append('{}: probability: {:.02f}, label: {}'
              .format(i+1, topprobs[i], imagenet_labels[topk[i]]))

    #return(topk, topprobs, [imagenet_labels[i] for i in topk])
    # Legacy requires us to wrap the results in another empty list
    to_return = []
    to_return.append(current_results)
    return(to_return)

# %%
# Run across each dir and get the similar images predicitons
for file in sorted(listdir("/home/w266ajh/Documents/top5gen/data_imageparts_1/")):
    if not file.endswith('.jpg'): continue

    # Figure out which similar-images file that we need to retrieve
    gt_class = file.split('.')[0][:-1].capitalize()

    # Get our images for this groundtruth class
    sim_path = '/home/w266ajh/Documents/top5gen/similar-images/' + gt_class
    if not isdir(sim_path): continue

    # Find the images that we need to make sim_images for
    sim_img_nums = []
    for sim_img in sorted(listdir(sim_path)):
        if sim_img.endswith(".num"):
            sim_img_nums.append(int(sim_img.split('.')[0]))
    
    # Run through each of the sim_img nums and create our similar images
    for advi in sim_img_nums:
        demo_target = advi

        # Get image and write out the results
        img = PIL.Image.open("/home/w266ajh/Documents/top5gen/data_imageparts_1/" + file)
        big_dim = max(img.width, img.height)
        wide = img.width > img.height
        new_w = 224 if not wide else int(img.width * 224 / img.height)
        new_h = 224 if wide else int(img.height * 224 / img.width)
        img = img.resize((new_w, new_h)).crop((0, 0, 224, 224))
        img = (np.asarray(img) / 255.0).astype(np.float32)

        print(get_top_five("img_path", img))

        # Generate the adversarial ###
        x = tf.placeholder(tf.float32, (224, 224, 3))

        x_hat = image # our trainable adversarial input
        assign_op = tf.assign(x_hat, x)

        learning_rate = tf.placeholder(tf.float32, ())
        y_hat = tf.placeholder(tf.int32, ())

        labels = tf.one_hot(y_hat, 1000)
        loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=[labels])
        optim_step = tf.train.GradientDescentOptimizer(
            learning_rate).minimize(loss, var_list=[x_hat])

        epsilon = tf.placeholder(tf.float32, ())

        below = x - epsilon
        above = x + epsilon
        projected = tf.clip_by_value(tf.clip_by_value(x_hat, below, above), 0, 1)
        with tf.control_dependencies([projected]):
            project_step = tf.assign(x_hat, projected)

        demo_epsilon = 2.0/255.0 # a really small perturbation
        demo_lr = 1e-1
        demo_steps = 100

        # initialization step
        sess.run(assign_op, feed_dict={x: img})

        # projected gradient descent
        for i in range(demo_steps):
            # gradient descent step
            _, loss_value = sess.run(
                [optim_step, loss],
                feed_dict={learning_rate: demo_lr, y_hat: demo_target})
            # project step
            sess.run(project_step, feed_dict={x: img, epsilon: demo_epsilon})
            if (i+1) % 10 == 0:
                print('step %d, loss=%g' % (i+1, loss_value))


        adv = x_hat.eval() # retrieve the adversarial example
        from skimage.io import imsave
        imsave("sim_adv_images/adv_" + file + "_" + str(advi) + ".png", adv, plugin='pil', format_str='png')

        ###

        # Get the adv prediction
        print(get_top_five("adv", adv))
# Out:
# [['img_path', '1: probability: 0.87, label: colobus, colobus monkey', '2: probability: 0.02, label: gibbon, Hylobates lar', '3: probability: 0.00, label: guenon, guenon monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca']]
# step 10, loss=0.0333631
# step 20, loss=0.0193584
# step 30, loss=0.0142069
# step 40, loss=0.0113915
# step 50, loss=0.00965509
# step 60, loss=0.00844101
# step 70, loss=0.00755288
# step 80, loss=0.00686572
# step 90, loss=0.00631326
# step 100, loss=0.00586159
# /home/w266ajh/.local/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float32 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# [['adv', '1: probability: 0.99, label: gibbon, Hylobates lar', '2: probability: 0.00, label: siamang, Hylobates syndactylus, Symphalangus syndactylus', '3: probability: 0.00, label: colobus, colobus monkey', '4: probability: 0.00, label: spider monkey, Ateles geoffroyi', '5: probability: 0.00, label: indri, indris, Indri indri, Indri brevicaudatus']]
# [['img_path', '1: probability: 0.87, label: colobus, colobus monkey', '2: probability: 0.02, label: gibbon, Hylobates lar', '3: probability: 0.00, label: guenon, guenon monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca']]
# step 10, loss=0.0280876
# step 20, loss=0.0146476
# step 30, loss=0.0105064
# step 40, loss=0.0084033
# step 50, loss=0.00703311
# step 60, loss=0.00601162
# step 70, loss=0.00529376
# step 80, loss=0.0047536
# step 90, loss=0.00434039
# step 100, loss=0.00401322
# [['adv', '1: probability: 1.00, label: guenon, guenon monkey', '2: probability: 0.00, label: colobus, colobus monkey', '3: probability: 0.00, label: patas, hussar monkey, Erythrocebus patas', '4: probability: 0.00, label: titi, titi monkey', '5: probability: 0.00, label: badger']]
# [['img_path', '1: probability: 0.92, label: colobus, colobus monkey', '2: probability: 0.01, label: gibbon, Hylobates lar', '3: probability: 0.01, label: guenon, guenon monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: skunk, polecat, wood pussy']]
# step 10, loss=0.0188395
# step 20, loss=0.0106521
# step 30, loss=0.0077631
# step 40, loss=0.00623211
# step 50, loss=0.00525427
# step 60, loss=0.00456126
# step 70, loss=0.00403733
# step 80, loss=0.0036243
# step 90, loss=0.00329713
# step 100, loss=0.00302714
# [['adv', '1: probability: 1.00, label: gibbon, Hylobates lar', '2: probability: 0.00, label: colobus, colobus monkey', '3: probability: 0.00, label: siamang, Hylobates syndactylus, Symphalangus syndactylus', '4: probability: 0.00, label: howler monkey, howler', '5: probability: 0.00, label: titi, titi monkey']]
# [['img_path', '1: probability: 0.92, label: colobus, colobus monkey', '2: probability: 0.01, label: gibbon, Hylobates lar', '3: probability: 0.01, label: guenon, guenon monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: skunk, polecat, wood pussy']]
# step 10, loss=0.00994714
# step 20, loss=0.00536656
# step 30, loss=0.00378298
# step 40, loss=0.0029966
# step 50, loss=0.00250597
# step 60, loss=0.00214692
# step 70, loss=0.00187852
# step 80, loss=0.00168218
# step 90, loss=0.00152769
# step 100, loss=0.00139901
# [['adv', '1: probability: 1.00, label: guenon, guenon monkey', '2: probability: 0.00, label: colobus, colobus monkey', '3: probability: 0.00, label: patas, hussar monkey, Erythrocebus patas', '4: probability: 0.00, label: baboon', '5: probability: 0.00, label: titi, titi monkey']]
# [['img_path', '1: probability: 0.96, label: colobus, colobus monkey', '2: probability: 0.01, label: guenon, guenon monkey', '3: probability: 0.00, label: langur', '4: probability: 0.00, label: gibbon, Hylobates lar', '5: probability: 0.00, label: titi, titi monkey']]
# step 10, loss=0.0117863
# step 20, loss=0.006845
# step 30, loss=0.00506629
# step 40, loss=0.0041196
# step 50, loss=0.00348342
# step 60, loss=0.00299981
# step 70, loss=0.00263855
# step 80, loss=0.00235947
# step 90, loss=0.00213776
# step 100, loss=0.00195883
# [['adv', '1: probability: 1.00, label: gibbon, Hylobates lar', '2: probability: 0.00, label: colobus, colobus monkey', '3: probability: 0.00, label: titi, titi monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: indri, indris, Indri indri, Indri brevicaudatus']]
# [['img_path', '1: probability: 0.96, label: colobus, colobus monkey', '2: probability: 0.01, label: guenon, guenon monkey', '3: probability: 0.00, label: langur', '4: probability: 0.00, label: gibbon, Hylobates lar', '5: probability: 0.00, label: titi, titi monkey']]
# step 10, loss=0.0155773
# step 20, loss=0.0080188
# step 30, loss=0.0055661
# step 40, loss=0.0043449
# step 50, loss=0.00357798
# step 60, loss=0.00304842
# step 70, loss=0.00265472
# step 80, loss=0.00235756
# step 90, loss=0.00212563
# step 100, loss=0.00193968
# [['adv', '1: probability: 1.00, label: guenon, guenon monkey', '2: probability: 0.00, label: colobus, colobus monkey', '3: probability: 0.00, label: patas, hussar monkey, Erythrocebus patas', '4: probability: 0.00, label: titi, titi monkey', '5: probability: 0.00, label: squirrel monkey, Saimiri sciureus']]
# [['img_path', '1: probability: 0.85, label: colobus, colobus monkey', '2: probability: 0.04, label: guenon, guenon monkey', '3: probability: 0.01, label: gibbon, Hylobates lar', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: siamang, Hylobates syndactylus, Symphalangus syndactylus']]
# step 10, loss=0.00899383
# step 20, loss=0.00544671
# step 30, loss=0.00406677
# step 40, loss=0.00331187
# step 50, loss=0.0028334
# step 60, loss=0.00249064
# step 70, loss=0.00223125
# step 80, loss=0.00203402
# step 90, loss=0.00187245
# step 100, loss=0.00173383
# [['adv', '1: probability: 1.00, label: gibbon, Hylobates lar', '2: probability: 0.00, label: siamang, Hylobates syndactylus, Symphalangus syndactylus', '3: probability: 0.00, label: colobus, colobus monkey', '4: probability: 0.00, label: indri, indris, Indri indri, Indri brevicaudatus', '5: probability: 0.00, label: gorilla, Gorilla gorilla']]
# [['img_path', '1: probability: 0.85, label: colobus, colobus monkey', '2: probability: 0.04, label: guenon, guenon monkey', '3: probability: 0.01, label: gibbon, Hylobates lar', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: siamang, Hylobates syndactylus, Symphalangus syndactylus']]
# step 10, loss=0.00623093
# step 20, loss=0.00339076
# step 30, loss=0.00241691
# step 40, loss=0.00188197
# step 50, loss=0.00154352
# step 60, loss=0.00131521
# step 70, loss=0.00114673
# step 80, loss=0.00101741
# step 90, loss=0.000916776
# step 100, loss=0.000834355
# [['adv', '1: probability: 1.00, label: guenon, guenon monkey', '2: probability: 0.00, label: colobus, colobus monkey', '3: probability: 0.00, label: patas, hussar monkey, Erythrocebus patas', '4: probability: 0.00, label: baboon', '5: probability: 0.00, label: titi, titi monkey']]
# [['img_path', '1: probability: 0.97, label: colobus, colobus monkey', '2: probability: 0.01, label: guenon, guenon monkey', '3: probability: 0.00, label: gibbon, Hylobates lar', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: indri, indris, Indri indri, Indri brevicaudatus']]
# step 10, loss=0.014576
# step 20, loss=0.00898142
# step 30, loss=0.00674992
# step 40, loss=0.00552164
# step 50, loss=0.00473319
# step 60, loss=0.00419024
# step 70, loss=0.00379485
# step 80, loss=0.00348009
# step 90, loss=0.00322204
# step 100, loss=0.00300848
# [['adv', '1: probability: 1.00, label: gibbon, Hylobates lar', '2: probability: 0.00, label: siamang, Hylobates syndactylus, Symphalangus syndactylus', '3: probability: 0.00, label: colobus, colobus monkey', '4: probability: 0.00, label: indri, indris, Indri indri, Indri brevicaudatus', '5: probability: 0.00, label: titi, titi monkey']]
# [['img_path', '1: probability: 0.97, label: colobus, colobus monkey', '2: probability: 0.01, label: guenon, guenon monkey', '3: probability: 0.00, label: gibbon, Hylobates lar', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: indri, indris, Indri indri, Indri brevicaudatus']]
# step 10, loss=0.0130298
# step 20, loss=0.00746094
# step 30, loss=0.00533573
# step 40, loss=0.00421018
# step 50, loss=0.00350765
# step 60, loss=0.00301621
# step 70, loss=0.00265603
# step 80, loss=0.00238408
# step 90, loss=0.0021644
# step 100, loss=0.00198548
# [['adv', '1: probability: 1.00, label: guenon, guenon monkey', '2: probability: 0.00, label: colobus, colobus monkey', '3: probability: 0.00, label: patas, hussar monkey, Erythrocebus patas', '4: probability: 0.00, label: titi, titi monkey', '5: probability: 0.00, label: baboon']]
# [['img_path', '1: probability: 0.98, label: nematode, nematode worm, roundworm', '2: probability: 0.01, label: hook, claw', "3: probability: 0.00, label: jack-o'-lantern", '4: probability: 0.00, label: eel', '5: probability: 0.00, label: corkscrew, bottle screw']]
# step 10, loss=0.0032843
# step 20, loss=0.00146794
# step 30, loss=0.00104825
# step 40, loss=0.000833164
# step 50, loss=0.000698323
# step 60, loss=0.000603136
# step 70, loss=0.000533438
# step 80, loss=0.000478392
# step 90, loss=0.000434423
# step 100, loss=0.000399391
# [['adv', '1: probability: 1.00, label: gar, garfish, garpike, billfish, Lepisosteus osseus', '2: probability: 0.00, label: barracouta, snoek', '3: probability: 0.00, label: sturgeon', '4: probability: 0.00, label: eel', '5: probability: 0.00, label: puffer, pufferfish, blowfish, globefish']]
# [['img_path', '1: probability: 0.98, label: nematode, nematode worm, roundworm', '2: probability: 0.01, label: vine snake', '3: probability: 0.00, label: sea snake', '4: probability: 0.00, label: hook, claw', '5: probability: 0.00, label: water snake']]
# step 10, loss=0.00112923
# step 20, loss=0.000735489
# step 30, loss=0.00056525
# step 40, loss=0.000465642
# step 50, loss=0.000401535
# step 60, loss=0.000354823
# step 70, loss=0.000319549
# step 80, loss=0.000292139
# step 90, loss=0.000269734
# step 100, loss=0.000250547
# [['adv', '1: probability: 1.00, label: gar, garfish, garpike, billfish, Lepisosteus osseus', '2: probability: 0.00, label: barracouta, snoek', '3: probability: 0.00, label: eel', '4: probability: 0.00, label: water snake', '5: probability: 0.00, label: sturgeon']]
# [['img_path', '1: probability: 1.00, label: nematode, nematode worm, roundworm', '2: probability: 0.00, label: hook, claw', '3: probability: 0.00, label: vine snake', '4: probability: 0.00, label: night snake, Hypsiglena torquata', '5: probability: 0.00, label: eel']]
# step 10, loss=0.0035838
# step 20, loss=0.00187436
# step 30, loss=0.00132485
# step 40, loss=0.00104778
# step 50, loss=0.000881641
# step 60, loss=0.000767771
# step 70, loss=0.000683789
# step 80, loss=0.00061922
# step 90, loss=0.000565726
# step 100, loss=0.000520452
# [['adv', '1: probability: 1.00, label: gar, garfish, garpike, billfish, Lepisosteus osseus', '2: probability: 0.00, label: eel', '3: probability: 0.00, label: barracouta, snoek', '4: probability: 0.00, label: sturgeon', '5: probability: 0.00, label: platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus']]
# [['img_path', '1: probability: 1.00, label: nematode, nematode worm, roundworm', '2: probability: 0.00, label: crane', '3: probability: 0.00, label: hook, claw', '4: probability: 0.00, label: scabbard', '5: probability: 0.00, label: ladle']]
# step 10, loss=0.00192148
# step 20, loss=0.000958698
# step 30, loss=0.000685099
# step 40, loss=0.000542851
# step 50, loss=0.000455038
# step 60, loss=0.000396531
# step 70, loss=0.000353393
# step 80, loss=0.000319668
# step 90, loss=0.000293093
# step 100, loss=0.000271164
# [['adv', '1: probability: 1.00, label: gar, garfish, garpike, billfish, Lepisosteus osseus', '2: probability: 0.00, label: barracouta, snoek', '3: probability: 0.00, label: water snake', '4: probability: 0.00, label: eel', '5: probability: 0.00, label: ladle']]
# [['img_path', '1: probability: 1.00, label: nematode, nematode worm, roundworm', '2: probability: 0.00, label: hook, claw', '3: probability: 0.00, label: crane', '4: probability: 0.00, label: chain', '5: probability: 0.00, label: sax, saxophone']]
# step 10, loss=0.00149329
# step 20, loss=0.000803982
# step 30, loss=0.000602421
# step 40, loss=0.000490664
# step 50, loss=0.000423103
# step 60, loss=0.000373532
# step 70, loss=0.000336114
# step 80, loss=0.000307274
# step 90, loss=0.000282963
# step 100, loss=0.000262226
# [['adv', '1: probability: 1.00, label: gar, garfish, garpike, billfish, Lepisosteus osseus', '2: probability: 0.00, label: barracouta, snoek', '3: probability: 0.00, label: sturgeon', '4: probability: 0.00, label: coho, cohoe, coho salmon, blue jack, silver salmon, Oncorhynchus kisutch', '5: probability: 0.00, label: eel']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: minibus', '3: probability: 0.00, label: trolleybus, trolley coach, trackless trolley', '4: probability: 0.00, label: passenger car, coach, carriage', '5: probability: 0.00, label: lifeboat']]
# step 10, loss=0.182596
# step 20, loss=0.0858426
# step 30, loss=0.0595788
# step 40, loss=0.0478296
# step 50, loss=0.0408122
# step 60, loss=0.0357779
# step 70, loss=0.0321669
# step 80, loss=0.0293779
# step 90, loss=0.0271954
# step 100, loss=0.0254127
# [['adv', '1: probability: 0.98, label: ambulance', '2: probability: 0.01, label: minibus', '3: probability: 0.00, label: school bus', '4: probability: 0.00, label: fire engine, fire truck', '5: probability: 0.00, label: police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria']]
# [['img_path', '1: probability: 0.92, label: school bus', '2: probability: 0.01, label: minibus', '3: probability: 0.00, label: ambulance', '4: probability: 0.00, label: cab, hack, taxi, taxicab', '5: probability: 0.00, label: fire engine, fire truck']]
# step 10, loss=0.0402641
# step 20, loss=0.0229356
# step 30, loss=0.0166363
# step 40, loss=0.0133405
# step 50, loss=0.0112386
# step 60, loss=0.00977303
# step 70, loss=0.0086865
# step 80, loss=0.00785488
# step 90, loss=0.0071877
# step 100, loss=0.0066353
# [['adv', '1: probability: 0.99, label: ambulance', '2: probability: 0.00, label: police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria', '3: probability: 0.00, label: minibus', '4: probability: 0.00, label: school bus', '5: probability: 0.00, label: moving van']]
# [['img_path', '1: probability: 0.91, label: school bus', '2: probability: 0.02, label: minibus', '3: probability: 0.02, label: moving van', '4: probability: 0.01, label: ambulance', '5: probability: 0.00, label: fire engine, fire truck']]
# step 10, loss=0.0434422
# step 20, loss=0.0246294
# step 30, loss=0.0181344
# step 40, loss=0.0146217
# step 50, loss=0.0124174
# step 60, loss=0.0108684
# step 70, loss=0.0097042
# step 80, loss=0.0087847
# step 90, loss=0.00804092
# step 100, loss=0.00742781
# [['adv', '1: probability: 0.99, label: ambulance', '2: probability: 0.00, label: police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria', '3: probability: 0.00, label: minibus', '4: probability: 0.00, label: moving van', '5: probability: 0.00, label: fire engine, fire truck']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: cab, hack, taxi, taxicab', '3: probability: 0.00, label: lifeboat', '4: probability: 0.00, label: trolleybus, trolley coach, trackless trolley', '5: probability: 0.00, label: passenger car, coach, carriage']]
# step 10, loss=0.0600578
# step 20, loss=0.0322383
# step 30, loss=0.0229533
# step 40, loss=0.0182264
# step 50, loss=0.0152921
# step 60, loss=0.0132419
# step 70, loss=0.0117336
# step 80, loss=0.0105645
# step 90, loss=0.00960633
# step 100, loss=0.00882558
# [['adv', '1: probability: 0.99, label: ambulance', '2: probability: 0.00, label: school bus', '3: probability: 0.00, label: police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria', '4: probability: 0.00, label: fire engine, fire truck', '5: probability: 0.00, label: minibus']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: crane', '3: probability: 0.00, label: cab, hack, taxi, taxicab', '4: probability: 0.00, label: trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi', '5: probability: 0.00, label: minibus']]
# step 10, loss=0.160187
# step 20, loss=0.0641543
# step 30, loss=0.0424997
# step 40, loss=0.0325004
# step 50, loss=0.0264981
# step 60, loss=0.0225924
# step 70, loss=0.0196738
# step 80, loss=0.017502
# step 90, loss=0.0158128
# step 100, loss=0.0144628
# [['adv', '1: probability: 0.99, label: ambulance', '2: probability: 0.00, label: police van, police wagon, paddy wagon, patrol wagon, wagon, black Maria', '3: probability: 0.00, label: fire engine, fire truck', '4: probability: 0.00, label: school bus', '5: probability: 0.00, label: moving van']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: teddy, teddy bear', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: pencil box, pencil case', '5: probability: 0.00, label: packet']]
# step 10, loss=0.0113291
# step 20, loss=0.00569602
# step 30, loss=0.00399446
# step 40, loss=0.00316726
# step 50, loss=0.00264961
# step 60, loss=0.00227704
# step 70, loss=0.00201404
# step 80, loss=0.00181474
# step 90, loss=0.00165528
# step 100, loss=0.00152543
# [['adv', '1: probability: 1.00, label: mitten', '2: probability: 0.00, label: sock', '3: probability: 0.00, label: wool, woolen, woollen', '4: probability: 0.00, label: Christmas stocking', '5: probability: 0.00, label: hair slide']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: teddy, teddy bear', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: pencil box, pencil case', '5: probability: 0.00, label: packet']]
# step 10, loss=0.0116401
# step 20, loss=0.00648158
# step 30, loss=0.00485325
# step 40, loss=0.00394459
# step 50, loss=0.00335143
# step 60, loss=0.00292041
# step 70, loss=0.00258398
# step 80, loss=0.00233104
# step 90, loss=0.00213015
# step 100, loss=0.00196478
# [['adv', '1: probability: 1.00, label: sock', '2: probability: 0.00, label: Christmas stocking', '3: probability: 0.00, label: clog, geta, patten, sabot', '4: probability: 0.00, label: running shoe', '5: probability: 0.00, label: knee pad']]
# [['img_path', '1: probability: 0.95, label: Christmas stocking', '2: probability: 0.04, label: sock', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: bib', '5: probability: 0.00, label: purse']]
# step 10, loss=0.00805274
# step 20, loss=0.00481743
# step 30, loss=0.0036319
# step 40, loss=0.00295773
# step 50, loss=0.00251656
# step 60, loss=0.00220699
# step 70, loss=0.00197466
# step 80, loss=0.00179261
# step 90, loss=0.00164362
# step 100, loss=0.00151876
# [['adv', '1: probability: 1.00, label: mitten', '2: probability: 0.00, label: sock', '3: probability: 0.00, label: Christmas stocking', '4: probability: 0.00, label: wool, woolen, woollen', '5: probability: 0.00, label: bow tie, bow-tie, bowtie']]
# [['img_path', '1: probability: 0.95, label: Christmas stocking', '2: probability: 0.04, label: sock', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: bib', '5: probability: 0.00, label: purse']]
# step 10, loss=0.0049102
# step 20, loss=0.00286978
# step 30, loss=0.00209398
# step 40, loss=0.00168884
# step 50, loss=0.0014139
# step 60, loss=0.00122817
# step 70, loss=0.00109029
# step 80, loss=0.00098478
# step 90, loss=0.000898673
# step 100, loss=0.000826018
# [['adv', '1: probability: 1.00, label: sock', '2: probability: 0.00, label: Christmas stocking', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: clog, geta, patten, sabot', '5: probability: 0.00, label: sandal']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: sock', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: teddy, teddy bear', '5: probability: 0.00, label: pillow']]
# step 10, loss=0.0258591
# step 20, loss=0.0139088
# step 30, loss=0.00976948
# step 40, loss=0.00762221
# step 50, loss=0.00633399
# step 60, loss=0.00546497
# step 70, loss=0.00482893
# step 80, loss=0.0043487
# step 90, loss=0.00396062
# step 100, loss=0.00365114
# [['adv', '1: probability: 1.00, label: mitten', '2: probability: 0.00, label: Christmas stocking', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: wool, woolen, woollen', '5: probability: 0.00, label: hair slide']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: sock', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: teddy, teddy bear', '5: probability: 0.00, label: pillow']]
# step 10, loss=0.0112117
# step 20, loss=0.00642603
# step 30, loss=0.00465464
# step 40, loss=0.00373832
# step 50, loss=0.00316512
# step 60, loss=0.00276529
# step 70, loss=0.00246376
# step 80, loss=0.00222673
# step 90, loss=0.00204092
# step 100, loss=0.00188566
# [['adv', '1: probability: 1.00, label: sock', '2: probability: 0.00, label: Christmas stocking', '3: probability: 0.00, label: clog, geta, patten, sabot', '4: probability: 0.00, label: mitten', '5: probability: 0.00, label: cowboy boot']]
# [['img_path', '1: probability: 0.94, label: Christmas stocking', '2: probability: 0.01, label: pillow', '3: probability: 0.00, label: mailbag, postbag', '4: probability: 0.00, label: packet', '5: probability: 0.00, label: purse']]
# step 10, loss=0.316164
# step 20, loss=0.104847
# step 30, loss=0.072483
# step 40, loss=0.0573101
# step 50, loss=0.0476795
# step 60, loss=0.041757
# step 70, loss=0.037292
# step 80, loss=0.03396
# step 90, loss=0.0313171
# step 100, loss=0.02915
# [['adv', '1: probability: 0.97, label: mitten', '2: probability: 0.01, label: Christmas stocking', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: wool, woolen, woollen', '5: probability: 0.00, label: ski mask']]
# [['img_path', '1: probability: 0.94, label: Christmas stocking', '2: probability: 0.01, label: pillow', '3: probability: 0.00, label: mailbag, postbag', '4: probability: 0.00, label: packet', '5: probability: 0.00, label: purse']]
# step 10, loss=0.0893919
# step 20, loss=0.0417552
# step 30, loss=0.0283986
# step 40, loss=0.0222694
# step 50, loss=0.0187582
# step 60, loss=0.0164569
# step 70, loss=0.0147607
# step 80, loss=0.0134298
# step 90, loss=0.012355
# step 100, loss=0.0114596
# [['adv', '1: probability: 0.99, label: sock', '2: probability: 0.01, label: Christmas stocking', '3: probability: 0.00, label: cowboy boot', '4: probability: 0.00, label: clog, geta, patten, sabot', '5: probability: 0.00, label: running shoe']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: apron', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: flagpole, flagstaff', '5: probability: 0.00, label: brassiere, bra, bandeau']]
# step 10, loss=2.24354
# step 20, loss=0.121994
# step 30, loss=0.0237543
# step 40, loss=0.0170703
# step 50, loss=0.0138421
# step 60, loss=0.0118372
# step 70, loss=0.0104765
# step 80, loss=0.00946817
# step 90, loss=0.0086703
# step 100, loss=0.00804115
# [['adv', '1: probability: 0.99, label: mitten', '2: probability: 0.00, label: sock', '3: probability: 0.00, label: Christmas stocking', '4: probability: 0.00, label: Windsor tie', '5: probability: 0.00, label: Band Aid']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: apron', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: flagpole, flagstaff', '5: probability: 0.00, label: brassiere, bra, bandeau']]
# step 10, loss=0.0411224
# step 20, loss=0.0219839
# step 30, loss=0.0159417
# step 40, loss=0.012661
# step 50, loss=0.010585
# step 60, loss=0.0092126
# step 70, loss=0.00815089
# step 80, loss=0.00733279
# step 90, loss=0.00666917
# step 100, loss=0.00612632
# [['adv', '1: probability: 0.99, label: sock', '2: probability: 0.00, label: Christmas stocking', '3: probability: 0.00, label: clog, geta, patten, sabot', '4: probability: 0.00, label: cowboy boot', '5: probability: 0.00, label: sandal']]
# [['img_path', '1: probability: 1.00, label: bullet train, bullet', '2: probability: 0.00, label: bobsled, bobsleigh, bob', '3: probability: 0.00, label: limousine, limo', '4: probability: 0.00, label: sports car, sport car', '5: probability: 0.00, label: streetcar, tram, tramcar, trolley, trolley car']]
# step 10, loss=0.00369461
# step 20, loss=0.00206293
# step 30, loss=0.0014846
# step 40, loss=0.0011815
# step 50, loss=0.000990973
# step 60, loss=0.000861155
# step 70, loss=0.000763363
# step 80, loss=0.000688078
# step 90, loss=0.000626606
# step 100, loss=0.0005749
# [['adv', '1: probability: 1.00, label: bobsled, bobsleigh, bob', '2: probability: 0.00, label: bullet train, bullet', '3: probability: 0.00, label: snowmobile', '4: probability: 0.00, label: stretcher', '5: probability: 0.00, label: bathtub, bathing tub, bath, tub']]
# [['img_path', '1: probability: 1.00, label: bullet train, bullet', '2: probability: 0.00, label: bobsled, bobsleigh, bob', '3: probability: 0.00, label: limousine, limo', '4: probability: 0.00, label: sports car, sport car', '5: probability: 0.00, label: streetcar, tram, tramcar, trolley, trolley car']]
# step 10, loss=0.0210344
# step 20, loss=0.0110619
# step 30, loss=0.00811813
# step 40, loss=0.00661789
# step 50, loss=0.0056441
# step 60, loss=0.0049548
# step 70, loss=0.00442656
# step 80, loss=0.0040245
# step 90, loss=0.003704
# step 100, loss=0.00343115
# [['adv', '1: probability: 1.00, label: passenger car, coach, carriage', '2: probability: 0.00, label: bullet train, bullet', '3: probability: 0.00, label: electric locomotive', '4: probability: 0.00, label: streetcar, tram, tramcar, trolley, trolley car', '5: probability: 0.00, label: slug']]
# [['img_path', '1: probability: 0.98, label: bullet train, bullet', '2: probability: 0.00, label: limousine, limo', '3: probability: 0.00, label: bobsled, bobsleigh, bob', '4: probability: 0.00, label: solar dish, solar collector, solar furnace', '5: probability: 0.00, label: convertible']]
# step 10, loss=0.0120913
# step 20, loss=0.00637758
# step 30, loss=0.00437565
# step 40, loss=0.00339396
# step 50, loss=0.0027849
# step 60, loss=0.00236434
# step 70, loss=0.00206317
# step 80, loss=0.00183426
# step 90, loss=0.00165695
# step 100, loss=0.00151174
# [['adv', '1: probability: 1.00, label: bobsled, bobsleigh, bob', '2: probability: 0.00, label: bullet train, bullet', '3: probability: 0.00, label: snowmobile', '4: probability: 0.00, label: canoe', '5: probability: 0.00, label: speedboat']]
# [['img_path', '1: probability: 0.98, label: bullet train, bullet', '2: probability: 0.00, label: limousine, limo', '3: probability: 0.00, label: bobsled, bobsleigh, bob', '4: probability: 0.00, label: solar dish, solar collector, solar furnace', '5: probability: 0.00, label: convertible']]
# step 10, loss=0.10437
# step 20, loss=0.0542658
# step 30, loss=0.037845
# step 40, loss=0.0281431
# step 50, loss=0.0221341
# step 60, loss=0.0179473
# step 70, loss=0.0151607
# step 80, loss=0.0132059
# step 90, loss=0.0117402
# step 100, loss=0.0105888
# [['adv', '1: probability: 0.99, label: passenger car, coach, carriage', '2: probability: 0.00, label: bullet train, bullet', '3: probability: 0.00, label: electric locomotive', '4: probability: 0.00, label: streetcar, tram, tramcar, trolley, trolley car', '5: probability: 0.00, label: freight car']]
# [['img_path', '1: probability: 0.91, label: bullet train, bullet', '2: probability: 0.00, label: speedboat', '3: probability: 0.00, label: aircraft carrier, carrier, flattop, attack aircraft carrier', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: warplane, military plane']]
# step 10, loss=0.0237514
# step 20, loss=0.0115977
# step 30, loss=0.00803867
# step 40, loss=0.00615392
# step 50, loss=0.00504554
# step 60, loss=0.00427072
# step 70, loss=0.00370625
# step 80, loss=0.00329297
# step 90, loss=0.00297687
# step 100, loss=0.00272201
# [['adv', '1: probability: 1.00, label: bobsled, bobsleigh, bob', '2: probability: 0.00, label: bullet train, bullet', '3: probability: 0.00, label: snowmobile', '4: probability: 0.00, label: speedboat', '5: probability: 0.00, label: canoe']]
# [['img_path', '1: probability: 0.91, label: bullet train, bullet', '2: probability: 0.00, label: speedboat', '3: probability: 0.00, label: aircraft carrier, carrier, flattop, attack aircraft carrier', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: warplane, military plane']]
# step 10, loss=0.312242
# step 20, loss=0.120371
# step 30, loss=0.0823669
# step 40, loss=0.0651741
# step 50, loss=0.0547993
# step 60, loss=0.0473928
# step 70, loss=0.0420689
# step 80, loss=0.0380504
# step 90, loss=0.0350636
# step 100, loss=0.0325002
# [['adv', '1: probability: 0.97, label: passenger car, coach, carriage', '2: probability: 0.02, label: bullet train, bullet', '3: probability: 0.01, label: electric locomotive', '4: probability: 0.00, label: streetcar, tram, tramcar, trolley, trolley car', '5: probability: 0.00, label: freight car']]
# [['img_path', '1: probability: 0.99, label: bullet train, bullet', '2: probability: 0.01, label: mouse, computer mouse', '3: probability: 0.00, label: passenger car, coach, carriage', '4: probability: 0.00, label: limousine, limo', '5: probability: 0.00, label: sports car, sport car']]
# step 10, loss=0.0042503
# step 20, loss=0.00236339
# step 30, loss=0.00171526
# step 40, loss=0.00136259
# step 50, loss=0.00114375
# step 60, loss=0.000992402
# step 70, loss=0.00087914
# step 80, loss=0.000789093
# step 90, loss=0.000716549
# step 100, loss=0.000657223
# [['adv', '1: probability: 1.00, label: bobsled, bobsleigh, bob', '2: probability: 0.00, label: bullet train, bullet', '3: probability: 0.00, label: pool table, billiard table, snooker table', '4: probability: 0.00, label: hog, pig, grunter, squealer, Sus scrofa', '5: probability: 0.00, label: canoe']]
# [['img_path', '1: probability: 0.99, label: bullet train, bullet', '2: probability: 0.01, label: mouse, computer mouse', '3: probability: 0.00, label: passenger car, coach, carriage', '4: probability: 0.00, label: limousine, limo', '5: probability: 0.00, label: sports car, sport car']]
# step 10, loss=0.015682
# step 20, loss=0.00852316
# step 30, loss=0.00603638
# step 40, loss=0.00475573
# step 50, loss=0.00397463
# step 60, loss=0.00342675
# step 70, loss=0.00303487
# step 80, loss=0.00272915
# step 90, loss=0.00248005
# step 100, loss=0.0022749
# [['adv', '1: probability: 1.00, label: passenger car, coach, carriage', '2: probability: 0.00, label: electric locomotive', '3: probability: 0.00, label: bullet train, bullet', '4: probability: 0.00, label: streetcar, tram, tramcar, trolley, trolley car', '5: probability: 0.00, label: freight car']]
# [['img_path', '1: probability: 0.88, label: bullet train, bullet', '2: probability: 0.04, label: warplane, military plane', '3: probability: 0.01, label: wing', '4: probability: 0.01, label: projectile, missile', '5: probability: 0.01, label: bobsled, bobsleigh, bob']]
# step 10, loss=0.00358997
# step 20, loss=0.00206745
# step 30, loss=0.00149698
# step 40, loss=0.00117864
# step 50, loss=0.000979302
# step 60, loss=0.000842931
# step 70, loss=0.000742041
# step 80, loss=0.000663895
# step 90, loss=0.000601588
# step 100, loss=0.000550476
# [['adv', '1: probability: 1.00, label: bobsled, bobsleigh, bob', '2: probability: 0.00, label: snowmobile', '3: probability: 0.00, label: bullet train, bullet', '4: probability: 0.00, label: canoe', '5: probability: 0.00, label: vacuum, vacuum cleaner']]
# [['img_path', '1: probability: 0.88, label: bullet train, bullet', '2: probability: 0.04, label: warplane, military plane', '3: probability: 0.01, label: wing', '4: probability: 0.01, label: projectile, missile', '5: probability: 0.01, label: bobsled, bobsleigh, bob']]
# step 10, loss=0.0365745
# step 20, loss=0.0196735
# step 30, loss=0.0141285
# step 40, loss=0.0111488
# step 50, loss=0.00924886
# step 60, loss=0.0079411
# step 70, loss=0.00700281
# step 80, loss=0.00628305
# step 90, loss=0.00570834
# step 100, loss=0.00524158
# [['adv', '1: probability: 0.99, label: passenger car, coach, carriage', '2: probability: 0.00, label: electric locomotive', '3: probability: 0.00, label: bullet train, bullet', '4: probability: 0.00, label: trolleybus, trolley coach, trackless trolley', '5: probability: 0.00, label: planetarium']]

# %%
# Run across each dir and get the similar images predicitons
for file in sorted(listdir("/home/w266ajh/Documents/top5gen/data_imageparts/")):
    if not file.endswith('.jpg'): continue

    # Figure out which similar-images file that we need to retrieve
    gt_class = file.split('.')[0][:-1].capitalize()

    # Get our images for this groundtruth class
    sim_path = '/home/w266ajh/Documents/top5gen/similar-images/' + gt_class
    if not isdir(sim_path): continue

    # Find the images that we need to make sim_images for
    sim_img_nums = []
    for sim_img in sorted(listdir(sim_path)):
        if sim_img.endswith(".num"):
            sim_img_nums.append(int(sim_img.split('.')[0]))
    
    # Run through each of the sim_img nums and create our similar images
    for advi in sim_img_nums:
        demo_target = advi

        # Get image and write out the results
        img = PIL.Image.open("/home/w266ajh/Documents/top5gen/data_imageparts/" + file)
        big_dim = max(img.width, img.height)
        wide = img.width > img.height
        new_w = 224 if not wide else int(img.width * 224 / img.height)
        new_h = 224 if wide else int(img.height * 224 / img.width)
        img = img.resize((new_w, new_h)).crop((0, 0, 224, 224))
        img = (np.asarray(img) / 255.0).astype(np.float32)
        with open("adv_input", "w") as out:
            out.write(str(img))

        print(get_top_five("img_path", img))
        with open("predictions_" + str(advi) + ".csv", 'a+') as f:
            for val in get_top_five("/home/w266ajh/Documents/top5gen/data_imageparts/" + file, img)[0]:
                f.write(val + ';')
            f.write('\n')

        # Generate the adversarial ###
        x = tf.placeholder(tf.float32, (224, 224, 3))

        x_hat = image # our trainable adversarial input
        assign_op = tf.assign(x_hat, x)

        learning_rate = tf.placeholder(tf.float32, ())
        y_hat = tf.placeholder(tf.int32, ())

        labels = tf.one_hot(y_hat, 1000)
        loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=[labels])
        optim_step = tf.train.GradientDescentOptimizer(
            learning_rate).minimize(loss, var_list=[x_hat])

        epsilon = tf.placeholder(tf.float32, ())

        below = x - epsilon
        above = x + epsilon
        projected = tf.clip_by_value(tf.clip_by_value(x_hat, below, above), 0, 1)
        with tf.control_dependencies([projected]):
            project_step = tf.assign(x_hat, projected)

        demo_epsilon = 2.0/255.0 # a really small perturbation
        demo_lr = 1e-1
        demo_steps = 100

        # initialization step
        sess.run(assign_op, feed_dict={x: img})

        # projected gradient descent
        for i in range(demo_steps):
            # gradient descent step
            _, loss_value = sess.run(
                [optim_step, loss],
                feed_dict={learning_rate: demo_lr, y_hat: demo_target})
            # project step
            sess.run(project_step, feed_dict={x: img, epsilon: demo_epsilon})
            if (i+1) % 10 == 0:
                print('step %d, loss=%g' % (i+1, loss_value))


        adv = x_hat.eval() # retrieve the adversarial example
        from skimage.io import imsave
        imsave("adv.png", adv, plugin='pil', format_str='png')
        # with open("adv_output.txt", 'w') as out:
        #     out.write(str(a) for a in adv)
        np.set_printoptions(threshold=np.nan)
        with open("adv_output.txt", "w") as out:
            out.write(str(adv))

        ###

        # Get the adv prediction
        print(get_top_five("adv", adv))

        with open("predictions_" + str(advi) + ".csv", 'a+') as f:
            for val in get_top_five("adv", adv)[0]:
                f.write(val + ';')
            f.write('\n')
# Out:
# [['img_path', '1: probability: 0.97, label: barn', '2: probability: 0.03, label: boathouse', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: church, church building', '5: probability: 0.00, label: lumbermill, sawmill']]
# step 10, loss=0.0291645
# step 20, loss=0.0142514
# step 30, loss=0.0099574
# step 40, loss=0.00783418
# step 50, loss=0.0065511
# step 60, loss=0.00568736
# step 70, loss=0.00506452
# step 80, loss=0.00458736
# step 90, loss=0.004216
# step 100, loss=0.00390933
# /home/w266ajh/.local/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float32 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# [['adv', '1: probability: 1.00, label: boathouse', '2: probability: 0.00, label: barn', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: lumbermill, sawmill', '5: probability: 0.00, label: tile roof']]
# [['img_path', '1: probability: 0.97, label: barn', '2: probability: 0.03, label: boathouse', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: church, church building', '5: probability: 0.00, label: lumbermill, sawmill']]
# step 10, loss=0.216673
# step 20, loss=0.0943571
# step 30, loss=0.0640741
# step 40, loss=0.0498471
# step 50, loss=0.0415535
# step 60, loss=0.0359629
# step 70, loss=0.0319516
# step 80, loss=0.0288945
# step 90, loss=0.0264582
# step 100, loss=0.0244512
# [['adv', '1: probability: 0.98, label: church, church building', '2: probability: 0.01, label: barn', '3: probability: 0.00, label: bell cote, bell cot', '4: probability: 0.00, label: tile roof', '5: probability: 0.00, label: boathouse']]
# [['img_path', '1: probability: 0.98, label: barn', '2: probability: 0.01, label: boathouse', '3: probability: 0.00, label: church, church building', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: solar dish, solar collector, solar furnace']]
# step 10, loss=0.129396
# step 20, loss=0.0650791
# step 30, loss=0.044356
# step 40, loss=0.0326713
# step 50, loss=0.0263353
# step 60, loss=0.0223968
# step 70, loss=0.0195271
# step 80, loss=0.0174409
# step 90, loss=0.0157977
# step 100, loss=0.0144444
# [['adv', '1: probability: 0.99, label: boathouse', '2: probability: 0.01, label: barn', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: tile roof', '5: probability: 0.00, label: thatch, thatched roof']]
# [['img_path', '1: probability: 0.98, label: barn', '2: probability: 0.01, label: boathouse', '3: probability: 0.00, label: church, church building', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: solar dish, solar collector, solar furnace']]
# step 10, loss=0.0486685
# step 20, loss=0.0270998
# step 30, loss=0.0195937
# step 40, loss=0.0156557
# step 50, loss=0.0132513
# step 60, loss=0.0116142
# step 70, loss=0.0103911
# step 80, loss=0.00941137
# step 90, loss=0.0086378
# step 100, loss=0.00799846
# [['adv', '1: probability: 0.99, label: church, church building', '2: probability: 0.00, label: bell cote, bell cot', '3: probability: 0.00, label: barn', '4: probability: 0.00, label: monastery', '5: probability: 0.00, label: tile roof']]
# [['img_path', '1: probability: 0.97, label: barn', '2: probability: 0.02, label: boathouse', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: church, church building']]
# step 10, loss=0.0128455
# step 20, loss=0.00752306
# step 30, loss=0.00546165
# step 40, loss=0.00433292
# step 50, loss=0.00359983
# step 60, loss=0.00310641
# step 70, loss=0.00274686
# step 80, loss=0.00247066
# step 90, loss=0.00224398
# step 100, loss=0.00206424
# [['adv', '1: probability: 1.00, label: boathouse', '2: probability: 0.00, label: birdhouse', '3: probability: 0.00, label: barn', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: lakeside, lakeshore']]
# [['img_path', '1: probability: 0.97, label: barn', '2: probability: 0.02, label: boathouse', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: church, church building']]
# step 10, loss=0.0744895
# step 20, loss=0.0394672
# step 30, loss=0.0278298
# step 40, loss=0.02218
# step 50, loss=0.0187041
# step 60, loss=0.0163738
# step 70, loss=0.0146277
# step 80, loss=0.0132604
# step 90, loss=0.0121422
# step 100, loss=0.011215
# [['adv', '1: probability: 0.99, label: church, church building', '2: probability: 0.01, label: monastery', '3: probability: 0.00, label: barn', '4: probability: 0.00, label: bell cote, bell cot', '5: probability: 0.00, label: castle']]
# [['img_path', '1: probability: 0.99, label: barn', '2: probability: 0.00, label: boathouse', '3: probability: 0.00, label: greenhouse, nursery, glasshouse', '4: probability: 0.00, label: lumbermill, sawmill', '5: probability: 0.00, label: worm fence, snake fence, snake-rail fence, Virginia fence']]
# step 10, loss=0.0163665
# step 20, loss=0.00989945
# step 30, loss=0.00733078
# step 40, loss=0.00587368
# step 50, loss=0.00492514
# step 60, loss=0.00426395
# step 70, loss=0.00377597
# step 80, loss=0.00339812
# step 90, loss=0.00309988
# step 100, loss=0.00285432
# [['adv', '1: probability: 1.00, label: boathouse', '2: probability: 0.00, label: barn', '3: probability: 0.00, label: lakeside, lakeshore', '4: probability: 0.00, label: mobile home, manufactured home', '5: probability: 0.00, label: lumbermill, sawmill']]
# [['img_path', '1: probability: 0.99, label: barn', '2: probability: 0.00, label: boathouse', '3: probability: 0.00, label: greenhouse, nursery, glasshouse', '4: probability: 0.00, label: lumbermill, sawmill', '5: probability: 0.00, label: worm fence, snake fence, snake-rail fence, Virginia fence']]
# step 10, loss=0.0723949
# step 20, loss=0.0357957
# step 30, loss=0.0252418
# step 40, loss=0.0198462
# step 50, loss=0.0166818
# step 60, loss=0.0146018
# step 70, loss=0.0130807
# step 80, loss=0.0119254
# step 90, loss=0.011009
# step 100, loss=0.0102691
# [['adv', '1: probability: 0.99, label: church, church building', '2: probability: 0.00, label: barn', '3: probability: 0.00, label: monastery', '4: probability: 0.00, label: altar', '5: probability: 0.00, label: castle']]
# [['img_path', '1: probability: 0.97, label: barn', '2: probability: 0.01, label: church, church building', '3: probability: 0.00, label: boathouse', '4: probability: 0.00, label: worm fence, snake fence, snake-rail fence, Virginia fence', '5: probability: 0.00, label: thatch, thatched roof']]
# step 10, loss=0.0107277
# step 20, loss=0.00690621
# step 30, loss=0.00526459
# step 40, loss=0.00429636
# step 50, loss=0.00365055
# step 60, loss=0.00318413
# step 70, loss=0.00283388
# step 80, loss=0.00255354
# step 90, loss=0.00233318
# step 100, loss=0.0021531
# [['adv', '1: probability: 1.00, label: boathouse', '2: probability: 0.00, label: barn', '3: probability: 0.00, label: lakeside, lakeshore', '4: probability: 0.00, label: mobile home, manufactured home', '5: probability: 0.00, label: church, church building']]
# [['img_path', '1: probability: 0.97, label: barn', '2: probability: 0.01, label: church, church building', '3: probability: 0.00, label: boathouse', '4: probability: 0.00, label: worm fence, snake fence, snake-rail fence, Virginia fence', '5: probability: 0.00, label: thatch, thatched roof']]
# step 10, loss=0.015206
# step 20, loss=0.00915402
# step 30, loss=0.00685305
# step 40, loss=0.00560308
# step 50, loss=0.00481066
# step 60, loss=0.00423736
# step 70, loss=0.00379129
# step 80, loss=0.00343887
# step 90, loss=0.00315597
# step 100, loss=0.00291982
# [['adv', '1: probability: 1.00, label: church, church building', '2: probability: 0.00, label: monastery', '3: probability: 0.00, label: barn', '4: probability: 0.00, label: bell cote, bell cot', '5: probability: 0.00, label: castle']]
# [['img_path', '1: probability: 0.98, label: dam, dike, dyke', '2: probability: 0.01, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: dock, dockage, docking facility', '5: probability: 0.00, label: container ship, containership, container vessel']]
# step 10, loss=0.030289
# step 20, loss=0.0168805
# step 30, loss=0.0120036
# step 40, loss=0.00948034
# step 50, loss=0.0079249
# step 60, loss=0.00684986
# step 70, loss=0.00606814
# step 80, loss=0.00545964
# step 90, loss=0.00496702
# step 100, loss=0.00455687
# [['adv', '1: probability: 1.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '2: probability: 0.00, label: dam, dike, dyke', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: dock, dockage, docking facility', '5: probability: 0.00, label: container ship, containership, container vessel']]
# [['img_path', '1: probability: 0.98, label: dam, dike, dyke', '2: probability: 0.01, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: dock, dockage, docking facility', '5: probability: 0.00, label: container ship, containership, container vessel']]
# step 10, loss=0.0527896
# step 20, loss=0.0272763
# step 30, loss=0.0193909
# step 40, loss=0.015527
# step 50, loss=0.0131367
# step 60, loss=0.0114072
# step 70, loss=0.0101246
# step 80, loss=0.00909129
# step 90, loss=0.00823495
# step 100, loss=0.00753253
# [['adv', '1: probability: 0.99, label: pier', '2: probability: 0.00, label: steel arch bridge', '3: probability: 0.00, label: suspension bridge', '4: probability: 0.00, label: dam, dike, dyke', '5: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty']]
# [['img_path', '1: probability: 0.99, label: dam, dike, dyke', '2: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: barn']]
# step 10, loss=0.0337998
# step 20, loss=0.0196986
# step 30, loss=0.0147789
# step 40, loss=0.0120566
# step 50, loss=0.0102825
# step 60, loss=0.00903482
# step 70, loss=0.00810986
# step 80, loss=0.00738545
# step 90, loss=0.00677811
# step 100, loss=0.00626232
# [['adv', '1: probability: 0.99, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '2: probability: 0.00, label: dam, dike, dyke', '3: probability: 0.00, label: stone wall', '4: probability: 0.00, label: dock, dockage, docking facility', '5: probability: 0.00, label: pier']]
# [['img_path', '1: probability: 0.99, label: dam, dike, dyke', '2: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: barn']]
# step 10, loss=0.0744732
# step 20, loss=0.0396958
# step 30, loss=0.0284039
# step 40, loss=0.0226534
# step 50, loss=0.0188437
# step 60, loss=0.0160685
# step 70, loss=0.0140157
# step 80, loss=0.0125047
# step 90, loss=0.0113176
# step 100, loss=0.0103745
# [['adv', '1: probability: 0.99, label: pier', '2: probability: 0.00, label: suspension bridge', '3: probability: 0.00, label: dam, dike, dyke', '4: probability: 0.00, label: steel arch bridge', '5: probability: 0.00, label: viaduct']]
# [['img_path', '1: probability: 1.00, label: dam, dike, dyke', '2: probability: 0.00, label: suspension bridge', '3: probability: 0.00, label: viaduct', '4: probability: 0.00, label: pier', '5: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty']]
# step 10, loss=0.00908598
# step 20, loss=0.00522083
# step 30, loss=0.00381338
# step 40, loss=0.00305638
# step 50, loss=0.0025665
# step 60, loss=0.00221853
# step 70, loss=0.00196026
# step 80, loss=0.00175786
# step 90, loss=0.00159006
# step 100, loss=0.00145461
# [['adv', '1: probability: 1.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '2: probability: 0.00, label: dam, dike, dyke', '3: probability: 0.00, label: bannister, banister, balustrade, balusters, handrail', '4: probability: 0.00, label: pier', '5: probability: 0.00, label: stone wall']]
# [['img_path', '1: probability: 1.00, label: dam, dike, dyke', '2: probability: 0.00, label: suspension bridge', '3: probability: 0.00, label: viaduct', '4: probability: 0.00, label: pier', '5: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty']]
# step 10, loss=0.034894
# step 20, loss=0.0190527
# step 30, loss=0.0138341
# step 40, loss=0.0109867
# step 50, loss=0.00925453
# step 60, loss=0.00804659
# step 70, loss=0.00717231
# step 80, loss=0.00650598
# step 90, loss=0.00597536
# step 100, loss=0.00553551
# [['adv', '1: probability: 0.99, label: pier', '2: probability: 0.00, label: suspension bridge', '3: probability: 0.00, label: dam, dike, dyke', '4: probability: 0.00, label: steel arch bridge', '5: probability: 0.00, label: viaduct']]
# [['img_path', '1: probability: 0.96, label: dam, dike, dyke', '2: probability: 0.03, label: wreck', '3: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '4: probability: 0.00, label: cliff, drop, drop-off', '5: probability: 0.00, label: park bench']]
# step 10, loss=0.00626848
# step 20, loss=0.00404207
# step 30, loss=0.0030767
# step 40, loss=0.00250348
# step 50, loss=0.00211742
# step 60, loss=0.00182629
# step 70, loss=0.00161565
# step 80, loss=0.00145377
# step 90, loss=0.00132509
# step 100, loss=0.00121853
# [['adv', '1: probability: 1.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '2: probability: 0.00, label: dam, dike, dyke', '3: probability: 0.00, label: lakeside, lakeshore', '4: probability: 0.00, label: wreck', '5: probability: 0.00, label: stone wall']]
# [['img_path', '1: probability: 0.96, label: dam, dike, dyke', '2: probability: 0.03, label: wreck', '3: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '4: probability: 0.00, label: cliff, drop, drop-off', '5: probability: 0.00, label: park bench']]
# step 10, loss=0.0325999
# step 20, loss=0.0188982
# step 30, loss=0.0138583
# step 40, loss=0.011162
# step 50, loss=0.00945058
# step 60, loss=0.00822301
# step 70, loss=0.00732475
# step 80, loss=0.00662855
# step 90, loss=0.00607821
# step 100, loss=0.00561849
# [['adv', '1: probability: 0.99, label: pier', '2: probability: 0.00, label: steel arch bridge', '3: probability: 0.00, label: suspension bridge', '4: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '5: probability: 0.00, label: dam, dike, dyke']]
# [['img_path', '1: probability: 0.97, label: dam, dike, dyke', '2: probability: 0.01, label: fountain', '3: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '4: probability: 0.00, label: fireboat', '5: probability: 0.00, label: castle']]
# step 10, loss=0.0150076
# step 20, loss=0.00797031
# step 30, loss=0.00570123
# step 40, loss=0.00451237
# step 50, loss=0.00372288
# step 60, loss=0.00318782
# step 70, loss=0.00279596
# step 80, loss=0.00250764
# step 90, loss=0.00228204
# step 100, loss=0.00210207
# [['adv', '1: probability: 1.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '2: probability: 0.00, label: beacon, lighthouse, beacon light, pharos', '3: probability: 0.00, label: dam, dike, dyke', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: pier']]
# [['img_path', '1: probability: 0.97, label: dam, dike, dyke', '2: probability: 0.01, label: fountain', '3: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '4: probability: 0.00, label: fireboat', '5: probability: 0.00, label: castle']]
# step 10, loss=0.0407272
# step 20, loss=0.0211579
# step 30, loss=0.0145909
# step 40, loss=0.0113202
# step 50, loss=0.00931241
# step 60, loss=0.00794359
# step 70, loss=0.00696114
# step 80, loss=0.00623128
# step 90, loss=0.00564268
# step 100, loss=0.00516687
# [['adv', '1: probability: 0.99, label: pier', '2: probability: 0.00, label: steel arch bridge', '3: probability: 0.00, label: suspension bridge', '4: probability: 0.00, label: fireboat', '5: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty']]
# [['img_path', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: parking meter', '4: probability: 0.00, label: vending machine', '5: probability: 0.00, label: golfcart, golf cart']]
# step 10, loss=0.0238327
# step 20, loss=0.0120625
# step 30, loss=0.00814805
# step 40, loss=0.00629028
# step 50, loss=0.00518122
# step 60, loss=0.00443333
# step 70, loss=0.00390303
# step 80, loss=0.00350492
# step 90, loss=0.00319518
# step 100, loss=0.00293836
# [['adv', '1: probability: 1.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '4: probability: 0.00, label: mailbox, letter box', '5: probability: 0.00, label: vending machine']]
# [['img_path', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: parking meter', '4: probability: 0.00, label: vending machine', '5: probability: 0.00, label: golfcart, golf cart']]
# step 10, loss=0.0131972
# step 20, loss=0.00811068
# step 30, loss=0.00605629
# step 40, loss=0.00492467
# step 50, loss=0.00417409
# step 60, loss=0.00365661
# step 70, loss=0.00326374
# step 80, loss=0.00295999
# step 90, loss=0.00271417
# step 100, loss=0.00250835
# [['adv', '1: probability: 1.00, label: pay-phone, pay-station', '2: probability: 0.00, label: dial telephone, dial phone', '3: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '4: probability: 0.00, label: parking meter', '5: probability: 0.00, label: Gila monster, Heloderma suspectum']]
# [['img_path', '1: probability: 0.87, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.05, label: pay-phone, pay-station', '3: probability: 0.05, label: vending machine', '4: probability: 0.00, label: parking meter', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# step 10, loss=0.0311759
# step 20, loss=0.0171237
# step 30, loss=0.0121322
# step 40, loss=0.00956335
# step 50, loss=0.00794643
# step 60, loss=0.00680853
# step 70, loss=0.00596837
# step 80, loss=0.00532008
# step 90, loss=0.004802
# step 100, loss=0.00437588
# [['adv', '1: probability: 1.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: vending machine', '4: probability: 0.00, label: slot, one-armed bandit', '5: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser']]
# [['img_path', '1: probability: 0.87, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.05, label: pay-phone, pay-station', '3: probability: 0.05, label: vending machine', '4: probability: 0.00, label: parking meter', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# step 10, loss=0.00672589
# step 20, loss=0.00416875
# step 30, loss=0.00304461
# step 40, loss=0.00243272
# step 50, loss=0.00203081
# step 60, loss=0.00175406
# step 70, loss=0.00154674
# step 80, loss=0.00138663
# step 90, loss=0.00126139
# step 100, loss=0.00115828
# [['adv', '1: probability: 1.00, label: pay-phone, pay-station', '2: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '3: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '4: probability: 0.00, label: dial telephone, dial phone', '5: probability: 0.00, label: Gila monster, Heloderma suspectum']]
# [['img_path', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: vending machine', '3: probability: 0.00, label: mailbox, letter box', '4: probability: 0.00, label: scale, weighing machine', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# step 10, loss=0.0296501
# step 20, loss=0.0162218
# step 30, loss=0.0114442
# step 40, loss=0.00906318
# step 50, loss=0.00757003
# step 60, loss=0.00652647
# step 70, loss=0.00572944
# step 80, loss=0.00512334
# step 90, loss=0.00464207
# step 100, loss=0.00424591
# [['adv', '1: probability: 1.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '2: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '3: probability: 0.00, label: vending machine', '4: probability: 0.00, label: pay-phone, pay-station', '5: probability: 0.00, label: mailbox, letter box']]
# [['img_path', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: vending machine', '3: probability: 0.00, label: mailbox, letter box', '4: probability: 0.00, label: scale, weighing machine', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# step 10, loss=0.0404888
# step 20, loss=0.0216582
# step 30, loss=0.0151481
# step 40, loss=0.0118344
# step 50, loss=0.00983488
# step 60, loss=0.00848971
# step 70, loss=0.00751963
# step 80, loss=0.00677443
# step 90, loss=0.00617963
# step 100, loss=0.00569507
# [['adv', '1: probability: 0.99, label: pay-phone, pay-station', '2: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '3: probability: 0.00, label: dial telephone, dial phone', '4: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '5: probability: 0.00, label: parking meter']]
# [['img_path', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: mailbox, letter box', '3: probability: 0.00, label: ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', '4: probability: 0.00, label: vending machine', '5: probability: 0.00, label: golfcart, golf cart']]
# step 10, loss=0.0180794
# step 20, loss=0.00941126
# step 30, loss=0.00668953
# step 40, loss=0.0052985
# step 50, loss=0.00444318
# step 60, loss=0.00384639
# step 70, loss=0.00336177
# step 80, loss=0.00296689
# step 90, loss=0.00265793
# step 100, loss=0.00241191
# [['adv', '1: probability: 1.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '2: probability: 0.00, label: mailbox, letter box', '3: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '4: probability: 0.00, label: pay-phone, pay-station', '5: probability: 0.00, label: vending machine']]
# [['img_path', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: mailbox, letter box', '3: probability: 0.00, label: ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', '4: probability: 0.00, label: vending machine', '5: probability: 0.00, label: golfcart, golf cart']]
# step 10, loss=0.0108948
# step 20, loss=0.00543047
# step 30, loss=0.00382597
# step 40, loss=0.00300872
# step 50, loss=0.00252143
# step 60, loss=0.00218106
# step 70, loss=0.00193266
# step 80, loss=0.00174204
# step 90, loss=0.00158732
# step 100, loss=0.00145984
# [['adv', '1: probability: 1.00, label: pay-phone, pay-station', '2: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '3: probability: 0.00, label: crutch', '4: probability: 0.00, label: dial telephone, dial phone', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# [['img_path', '1: probability: 0.93, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.02, label: ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', '3: probability: 0.02, label: vending machine', '4: probability: 0.01, label: mailbox, letter box', '5: probability: 0.00, label: parking meter']]
# step 10, loss=0.00592737
# step 20, loss=0.00366112
# step 30, loss=0.00271333
# step 40, loss=0.00216655
# step 50, loss=0.00180653
# step 60, loss=0.00155269
# step 70, loss=0.00136925
# step 80, loss=0.00122853
# step 90, loss=0.00111589
# step 100, loss=0.00102372
# [['adv', '1: probability: 1.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: vending machine', '4: probability: 0.00, label: mailbox, letter box', '5: probability: 0.00, label: photocopier']]
# [['img_path', '1: probability: 0.93, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.02, label: ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', '3: probability: 0.02, label: vending machine', '4: probability: 0.01, label: mailbox, letter box', '5: probability: 0.00, label: parking meter']]
# step 10, loss=0.00490106
# step 20, loss=0.00286966
# step 30, loss=0.00209636
# step 40, loss=0.00166123
# step 50, loss=0.00138925
# step 60, loss=0.00120269
# step 70, loss=0.00106624
# step 80, loss=0.000962271
# step 90, loss=0.000878306
# step 100, loss=0.000808746
# [['adv', '1: probability: 1.00, label: pay-phone, pay-station', '2: probability: 0.00, label: parking meter', '3: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '4: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '5: probability: 0.00, label: dial telephone, dial phone']]
# [['img_path', '1: probability: 1.00, label: mashed potato', '2: probability: 0.00, label: meat loaf, meatloaf', '3: probability: 0.00, label: cauliflower', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: red wolf, maned wolf, Canis rufus, Canis niger']]
# step 10, loss=0.00350195
# step 20, loss=0.00246495
# step 30, loss=0.00193575
# step 40, loss=0.00160363
# step 50, loss=0.00137687
# step 60, loss=0.00120758
# step 70, loss=0.00107767
# step 80, loss=0.000973942
# step 90, loss=0.000889621
# step 100, loss=0.000819705
# [['adv', '1: probability: 1.00, label: cauliflower', '2: probability: 0.00, label: mashed potato', '3: probability: 0.00, label: corn', '4: probability: 0.00, label: broccoli', '5: probability: 0.00, label: custard apple']]
# [['img_path', '1: probability: 0.99, label: mashed potato', '2: probability: 0.01, label: cauliflower', '3: probability: 0.00, label: red wolf, maned wolf, Canis rufus, Canis niger', '4: probability: 0.00, label: meat loaf, meatloaf', '5: probability: 0.00, label: ice cream, icecream']]
# step 10, loss=0.00292243
# step 20, loss=0.00196978
# step 30, loss=0.00153531
# step 40, loss=0.00127139
# step 50, loss=0.00108779
# step 60, loss=0.000958341
# step 70, loss=0.000859487
# step 80, loss=0.000779921
# step 90, loss=0.000713809
# step 100, loss=0.000659129
# [['adv', '1: probability: 1.00, label: cauliflower', '2: probability: 0.00, label: mashed potato', '3: probability: 0.00, label: space shuttle', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: corn']]
# [['img_path', '1: probability: 0.99, label: mashed potato', '2: probability: 0.01, label: cauliflower', '3: probability: 0.00, label: red wolf, maned wolf, Canis rufus, Canis niger', '4: probability: 0.00, label: meat loaf, meatloaf', '5: probability: 0.00, label: ice cream, icecream']]
# step 10, loss=0.00292243
# step 20, loss=0.00196978
# step 30, loss=0.00153531
# step 40, loss=0.00127139
# step 50, loss=0.00108779
# step 60, loss=0.000958341
# step 70, loss=0.000859487
# step 80, loss=0.000779921
# step 90, loss=0.000713809
# step 100, loss=0.000659129
# [['adv', '1: probability: 1.00, label: cauliflower', '2: probability: 0.00, label: mashed potato', '3: probability: 0.00, label: space shuttle', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: corn']]
# [['img_path', '1: probability: 0.99, label: mashed potato', '2: probability: 0.01, label: cauliflower', '3: probability: 0.00, label: dough', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: red wolf, maned wolf, Canis rufus, Canis niger']]
# step 10, loss=0.000666992
# step 20, loss=0.0005444
# step 30, loss=0.000462068
# step 40, loss=0.00040368
# step 50, loss=0.000359828
# step 60, loss=0.000325269
# step 70, loss=0.000297145
# step 80, loss=0.000274263
# step 90, loss=0.000254718
# step 100, loss=0.000238033
# [['adv', '1: probability: 1.00, label: cauliflower', '2: probability: 0.00, label: mashed potato', '3: probability: 0.00, label: custard apple', '4: probability: 0.00, label: broccoli', '5: probability: 0.00, label: corn']]
# [['img_path', '1: probability: 0.96, label: mashed potato', '2: probability: 0.01, label: ice cream, icecream', '3: probability: 0.01, label: cauliflower', '4: probability: 0.00, label: dough', '5: probability: 0.00, label: meat loaf, meatloaf']]
# step 10, loss=0.011334
# step 20, loss=0.0060134
# step 30, loss=0.00416175
# step 40, loss=0.00320053
# step 50, loss=0.00260907
# step 60, loss=0.00220592
# step 70, loss=0.0019166
# step 80, loss=0.0016992
# step 90, loss=0.00152543
# step 100, loss=0.00138473
# [['adv', '1: probability: 1.00, label: cauliflower', '2: probability: 0.00, label: mashed potato', '3: probability: 0.00, label: broccoli', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: corn']]
# [['img_path', '1: probability: 1.00, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: projector', '3: probability: 0.00, label: reflex camera', '4: probability: 0.00, label: joystick', '5: probability: 0.00, label: CD player']]
# step 10, loss=0.0105273
# step 20, loss=0.00578361
# step 30, loss=0.00410476
# step 40, loss=0.00326184
# step 50, loss=0.0027018
# step 60, loss=0.00232486
# step 70, loss=0.0020571
# step 80, loss=0.00185008
# step 90, loss=0.00168325
# step 100, loss=0.00154519
# [['adv', '1: probability: 1.00, label: projector', '2: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '3: probability: 0.00, label: loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', '4: probability: 0.00, label: printer', '5: probability: 0.00, label: CD player']]
# [['img_path', '1: probability: 1.00, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: projector', '3: probability: 0.00, label: reflex camera', '4: probability: 0.00, label: joystick', '5: probability: 0.00, label: CD player']]
# step 10, loss=0.0318599
# step 20, loss=0.0148692
# step 30, loss=0.0103163
# step 40, loss=0.0080609
# step 50, loss=0.00673193
# step 60, loss=0.00585756
# step 70, loss=0.0052213
# step 80, loss=0.00472548
# step 90, loss=0.00431974
# step 100, loss=0.00399613
# [['adv', '1: probability: 1.00, label: reflex camera', '2: probability: 0.00, label: lens cap, lens cover', '3: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '4: probability: 0.00, label: tripod', '5: probability: 0.00, label: joystick']]
# [['img_path', '1: probability: 0.98, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: tape player', '3: probability: 0.00, label: cassette player', '4: probability: 0.00, label: radio, wireless', '5: probability: 0.00, label: reflex camera']]
# step 10, loss=0.00753986
# step 20, loss=0.00430289
# step 30, loss=0.00314385
# step 40, loss=0.00251917
# step 50, loss=0.00212218
# step 60, loss=0.00184306
# step 70, loss=0.00163564
# step 80, loss=0.00147115
# step 90, loss=0.0013414
# step 100, loss=0.00123556
# [['adv', '1: probability: 1.00, label: projector', '2: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '3: probability: 0.00, label: radio, wireless', '4: probability: 0.00, label: spotlight, spot', '5: probability: 0.00, label: printer']]
# [['img_path', '1: probability: 0.98, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: tape player', '3: probability: 0.00, label: cassette player', '4: probability: 0.00, label: radio, wireless', '5: probability: 0.00, label: reflex camera']]
# step 10, loss=0.0256794
# step 20, loss=0.014766
# step 30, loss=0.0107408
# step 40, loss=0.00854349
# step 50, loss=0.00716095
# step 60, loss=0.00621043
# step 70, loss=0.00551726
# step 80, loss=0.0049854
# step 90, loss=0.00456339
# step 100, loss=0.0042211
# [['adv', '1: probability: 1.00, label: reflex camera', '2: probability: 0.00, label: lens cap, lens cover', '3: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '4: probability: 0.00, label: tripod', '5: probability: 0.00, label: binoculars, field glasses, opera glasses']]
# [['img_path', '1: probability: 0.83, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.15, label: projector', '3: probability: 0.00, label: loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', '4: probability: 0.00, label: CD player', '5: probability: 0.00, label: tape player']]
# step 10, loss=0.00512655
# step 20, loss=0.00295227
# step 30, loss=0.00217927
# step 40, loss=0.00177286
# step 50, loss=0.00149841
# step 60, loss=0.00130378
# step 70, loss=0.00116281
# step 80, loss=0.00105099
# step 90, loss=0.00095977
# step 100, loss=0.000886524
# [['adv', '1: probability: 1.00, label: projector', '2: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '3: probability: 0.00, label: loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', '4: probability: 0.00, label: CD player', '5: probability: 0.00, label: printer']]
# [['img_path', '1: probability: 0.83, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.15, label: projector', '3: probability: 0.00, label: loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', '4: probability: 0.00, label: CD player', '5: probability: 0.00, label: tape player']]
# step 10, loss=0.0328235
# step 20, loss=0.0194694
# step 30, loss=0.0144481
# step 40, loss=0.0116265
# step 50, loss=0.00989921
# step 60, loss=0.00863201
# step 70, loss=0.00769662
# step 80, loss=0.00696718
# step 90, loss=0.00638149
# step 100, loss=0.0059116
# [['adv', '1: probability: 0.99, label: reflex camera', '2: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '3: probability: 0.00, label: lens cap, lens cover', '4: probability: 0.00, label: binoculars, field glasses, opera glasses', '5: probability: 0.00, label: digital watch']]
# [['img_path', '1: probability: 0.99, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: reflex camera', '3: probability: 0.00, label: projector', '4: probability: 0.00, label: lens cap, lens cover', '5: probability: 0.00, label: iPod']]
# step 10, loss=0.0324312
# step 20, loss=0.0175829
# step 30, loss=0.0126607
# step 40, loss=0.0100117
# step 50, loss=0.00843415
# step 60, loss=0.0073212
# step 70, loss=0.00650124
# step 80, loss=0.00585247
# step 90, loss=0.00532814
# step 100, loss=0.00488813
# [['adv', '1: probability: 1.00, label: projector', '2: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '3: probability: 0.00, label: loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', '4: probability: 0.00, label: radio, wireless', '5: probability: 0.00, label: CD player']]
# [['img_path', '1: probability: 0.99, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: reflex camera', '3: probability: 0.00, label: projector', '4: probability: 0.00, label: lens cap, lens cover', '5: probability: 0.00, label: iPod']]
# step 10, loss=0.0434009
# step 20, loss=0.0202254
# step 30, loss=0.014269
# step 40, loss=0.0112245
# step 50, loss=0.00942838
# step 60, loss=0.00819322
# step 70, loss=0.00731043
# step 80, loss=0.00663968
# step 90, loss=0.00608058
# step 100, loss=0.00560178
# [['adv', '1: probability: 0.99, label: reflex camera', '2: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '3: probability: 0.00, label: lens cap, lens cover', '4: probability: 0.00, label: tripod', '5: probability: 0.00, label: projector']]
# [['img_path', '1: probability: 0.96, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.01, label: reflex camera', '3: probability: 0.00, label: projector', '4: probability: 0.00, label: espresso maker', '5: probability: 0.00, label: radio, wireless']]
# step 10, loss=0.0133698
# step 20, loss=0.00765852
# step 30, loss=0.00548785
# step 40, loss=0.0043322
# step 50, loss=0.00361278
# step 60, loss=0.00312162
# step 70, loss=0.00275209
# step 80, loss=0.00246198
# step 90, loss=0.00223137
# step 100, loss=0.00204188
# [['adv', '1: probability: 1.00, label: projector', '2: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '3: probability: 0.00, label: radio, wireless', '4: probability: 0.00, label: espresso maker', '5: probability: 0.00, label: microphone, mike']]
# [['img_path', '1: probability: 0.96, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.01, label: reflex camera', '3: probability: 0.00, label: projector', '4: probability: 0.00, label: espresso maker', '5: probability: 0.00, label: radio, wireless']]
# step 10, loss=0.0251323
# step 20, loss=0.0143119
# step 30, loss=0.010532
# step 40, loss=0.00856583
# step 50, loss=0.00735113
# step 60, loss=0.00647862
# step 70, loss=0.00582402
# step 80, loss=0.00530561
# step 90, loss=0.00488113
# step 100, loss=0.00452767
# [['adv', '1: probability: 1.00, label: reflex camera', '2: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '3: probability: 0.00, label: lens cap, lens cover', '4: probability: 0.00, label: binoculars, field glasses, opera glasses', '5: probability: 0.00, label: digital watch']]
# [['img_path', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '4: probability: 0.00, label: reflex camera', '5: probability: 0.00, label: joystick']]
# step 10, loss=0.0303789
# step 20, loss=0.0158884
# step 30, loss=0.0111105
# step 40, loss=0.00871167
# step 50, loss=0.00721066
# step 60, loss=0.00611044
# step 70, loss=0.0052998
# step 80, loss=0.00472168
# step 90, loss=0.00428259
# step 100, loss=0.00392298
# [['adv', '1: probability: 1.00, label: pay-phone, pay-station', '2: probability: 0.00, label: dial telephone, dial phone', '3: probability: 0.00, label: Gila monster, Heloderma suspectum', '4: probability: 0.00, label: parking meter', '5: probability: 0.00, label: safe']]
# [['img_path', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: hard disc, hard disk, fixed disk', '4: probability: 0.00, label: iron, smoothing iron', '5: probability: 0.00, label: magnetic compass']]
# step 10, loss=0.0741668
# step 20, loss=0.0367502
# step 30, loss=0.0257924
# step 40, loss=0.019933
# step 50, loss=0.0160326
# step 60, loss=0.0135717
# step 70, loss=0.0118559
# step 80, loss=0.0105562
# step 90, loss=0.00954965
# step 100, loss=0.00873128
# [['adv', '1: probability: 0.99, label: pay-phone, pay-station', '2: probability: 0.01, label: dial telephone, dial phone', '3: probability: 0.00, label: Gila monster, Heloderma suspectum', '4: probability: 0.00, label: parking meter', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# [['img_path', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: iron, smoothing iron', '4: probability: 0.00, label: iPod', '5: probability: 0.00, label: hard disc, hard disk, fixed disk']]
# step 10, loss=0.0667226
# step 20, loss=0.0324612
# step 30, loss=0.0226643
# step 40, loss=0.0179948
# step 50, loss=0.0150943
# step 60, loss=0.0130486
# step 70, loss=0.0115264
# step 80, loss=0.0103379
# step 90, loss=0.0094174
# step 100, loss=0.0086722
# [['adv', '1: probability: 0.99, label: pay-phone, pay-station', '2: probability: 0.01, label: dial telephone, dial phone', '3: probability: 0.00, label: safe', '4: probability: 0.00, label: combination lock', '5: probability: 0.00, label: Gila monster, Heloderma suspectum']]
# [['img_path', '1: probability: 0.84, label: dial telephone, dial phone', '2: probability: 0.02, label: vacuum, vacuum cleaner', '3: probability: 0.01, label: hand blower, blow dryer, blow drier, hair dryer, hair drier', '4: probability: 0.01, label: reflex camera', '5: probability: 0.01, label: Polaroid camera, Polaroid Land camera']]
# step 10, loss=0.0109162
# step 20, loss=0.0062994
# step 30, loss=0.00460979
# step 40, loss=0.00370887
# step 50, loss=0.00311723
# step 60, loss=0.00270917
# step 70, loss=0.00240133
# step 80, loss=0.00215667
# step 90, loss=0.00196443
# step 100, loss=0.00180725
# [['adv', '1: probability: 1.00, label: pay-phone, pay-station', '2: probability: 0.00, label: dial telephone, dial phone', '3: probability: 0.00, label: Gila monster, Heloderma suspectum', '4: probability: 0.00, label: safe', '5: probability: 0.00, label: parking meter']]
# [['img_path', '1: probability: 0.99, label: dial telephone, dial phone', '2: probability: 0.00, label: vacuum, vacuum cleaner', '3: probability: 0.00, label: iron, smoothing iron', '4: probability: 0.00, label: oxygen mask', '5: probability: 0.00, label: pay-phone, pay-station']]
# step 10, loss=0.02564
# step 20, loss=0.0140541
# step 30, loss=0.0100242
# step 40, loss=0.00791426
# step 50, loss=0.00664087
# step 60, loss=0.00577899
# step 70, loss=0.00514184
# step 80, loss=0.00463791
# step 90, loss=0.00423273
# step 100, loss=0.00389377
# [['adv', '1: probability: 1.00, label: pay-phone, pay-station', '2: probability: 0.00, label: dial telephone, dial phone', '3: probability: 0.00, label: parking meter', '4: probability: 0.00, label: vacuum, vacuum cleaner', '5: probability: 0.00, label: Gila monster, Heloderma suspectum']]
# [['img_path', '1: probability: 0.91, label: water tower', '2: probability: 0.01, label: mushroom', '3: probability: 0.01, label: golf ball', '4: probability: 0.00, label: ping-pong ball', '5: probability: 0.00, label: mosque']]
# step 10, loss=0.00758305
# step 20, loss=0.00407069
# step 30, loss=0.00280499
# step 40, loss=0.00219045
# step 50, loss=0.00181891
# step 60, loss=0.00156102
# step 70, loss=0.00136961
# step 80, loss=0.00122436
# step 90, loss=0.0011147
# step 100, loss=0.00102491
# [['adv', '1: probability: 1.00, label: balloon', '2: probability: 0.00, label: parachute, chute', '3: probability: 0.00, label: airship, dirigible', '4: probability: 0.00, label: water tower', '5: probability: 0.00, label: volleyball']]
# [['img_path', '1: probability: 0.91, label: water tower', '2: probability: 0.01, label: mushroom', '3: probability: 0.01, label: golf ball', '4: probability: 0.00, label: ping-pong ball', '5: probability: 0.00, label: mosque']]
# step 10, loss=0.0120148
# step 20, loss=0.00485907
# step 30, loss=0.00343067
# step 40, loss=0.00269027
# step 50, loss=0.00224041
# step 60, loss=0.00193718
# step 70, loss=0.00170883
# step 80, loss=0.00153091
# step 90, loss=0.00138509
# step 100, loss=0.00126937
# [['adv', '1: probability: 1.00, label: planetarium', '2: probability: 0.00, label: dome', '3: probability: 0.00, label: water tower', '4: probability: 0.00, label: balloon', '5: probability: 0.00, label: radio telescope, radio reflector']]
# [['img_path', '1: probability: 1.00, label: water tower', '2: probability: 0.00, label: balloon', '3: probability: 0.00, label: American black bear, black bear, Ursus americanus, Euarctos americanus', '4: probability: 0.00, label: radio telescope, radio reflector', '5: probability: 0.00, label: beacon, lighthouse, beacon light, pharos']]
# step 10, loss=0.325278
# step 20, loss=0.0201754
# step 30, loss=0.0126903
# step 40, loss=0.00964895
# step 50, loss=0.00803926
# step 60, loss=0.00693628
# step 70, loss=0.00607276
# step 80, loss=0.00545999
# step 90, loss=0.00497532
# step 100, loss=0.00457763
# [['adv', '1: probability: 1.00, label: balloon', '2: probability: 0.00, label: water tower', '3: probability: 0.00, label: airship, dirigible', '4: probability: 0.00, label: parachute, chute', '5: probability: 0.00, label: radio telescope, radio reflector']]
# [['img_path', '1: probability: 1.00, label: water tower', '2: probability: 0.00, label: balloon', '3: probability: 0.00, label: American black bear, black bear, Ursus americanus, Euarctos americanus', '4: probability: 0.00, label: radio telescope, radio reflector', '5: probability: 0.00, label: beacon, lighthouse, beacon light, pharos']]
# step 10, loss=0.0286299
# step 20, loss=0.0111603
# step 30, loss=0.00764031
# step 40, loss=0.00599811
# step 50, loss=0.00494258
# step 60, loss=0.00426633
# step 70, loss=0.00379165
# step 80, loss=0.00342794
# step 90, loss=0.00313886
# step 100, loss=0.00290128
# [['adv', '1: probability: 1.00, label: planetarium', '2: probability: 0.00, label: dome', '3: probability: 0.00, label: water tower', '4: probability: 0.00, label: airship, dirigible', '5: probability: 0.00, label: mosque']]
# [['img_path', '1: probability: 0.94, label: water tower', '2: probability: 0.00, label: flagpole, flagstaff', '3: probability: 0.00, label: hand blower, blow dryer, blow drier, hair dryer, hair drier', '4: probability: 0.00, label: airship, dirigible', '5: probability: 0.00, label: spotlight, spot']]
# step 10, loss=0.0129156
# step 20, loss=0.0050982
# step 30, loss=0.00360185
# step 40, loss=0.00287049
# step 50, loss=0.00240941
# step 60, loss=0.00208994
# step 70, loss=0.0018602
# step 80, loss=0.00167765
# step 90, loss=0.00152745
# step 100, loss=0.0014039
# [['adv', '1: probability: 1.00, label: balloon', '2: probability: 0.00, label: parachute, chute', '3: probability: 0.00, label: water tower', '4: probability: 0.00, label: airship, dirigible', '5: probability: 0.00, label: punching bag, punch bag, punching ball, punchball']]
# [['img_path', '1: probability: 0.94, label: water tower', '2: probability: 0.00, label: flagpole, flagstaff', '3: probability: 0.00, label: hand blower, blow dryer, blow drier, hair dryer, hair drier', '4: probability: 0.00, label: airship, dirigible', '5: probability: 0.00, label: spotlight, spot']]
# step 10, loss=2.00011
# step 20, loss=0.0284166
# step 30, loss=0.00482988
# step 40, loss=0.0034264
# step 50, loss=0.00273331
# step 60, loss=0.00232343
# step 70, loss=0.0020483
# step 80, loss=0.00184152
# step 90, loss=0.00166968
# step 100, loss=0.00152841
# [['adv', '1: probability: 1.00, label: planetarium', '2: probability: 0.00, label: dome', '3: probability: 0.00, label: water tower', '4: probability: 0.00, label: solar dish, solar collector, solar furnace', '5: probability: 0.00, label: balloon']]
# [['img_path', '1: probability: 0.93, label: water tower', '2: probability: 0.00, label: radio telescope, radio reflector', '3: probability: 0.00, label: folding chair', '4: probability: 0.00, label: planetarium', '5: probability: 0.00, label: solar dish, solar collector, solar furnace']]
# step 10, loss=0.771193
# step 20, loss=0.0217139
# step 30, loss=0.0136893
# step 40, loss=0.0108775
# step 50, loss=0.00912165
# step 60, loss=0.00796369
# step 70, loss=0.00714746
# step 80, loss=0.00653357
# step 90, loss=0.00607075
# step 100, loss=0.00565323
# [['adv', '1: probability: 0.99, label: balloon', '2: probability: 0.00, label: parachute, chute', '3: probability: 0.00, label: water tower', '4: probability: 0.00, label: airship, dirigible', '5: probability: 0.00, label: radio telescope, radio reflector']]
# [['img_path', '1: probability: 0.93, label: water tower', '2: probability: 0.00, label: radio telescope, radio reflector', '3: probability: 0.00, label: folding chair', '4: probability: 0.00, label: planetarium', '5: probability: 0.00, label: solar dish, solar collector, solar furnace']]
# step 10, loss=0.0353761
# step 20, loss=0.0193361
# step 30, loss=0.0140275
# step 40, loss=0.0113262
# step 50, loss=0.00961247
# step 60, loss=0.00839124
# step 70, loss=0.00751135
# step 80, loss=0.00682156
# step 90, loss=0.00626907
# step 100, loss=0.00581834
# [['adv', '1: probability: 0.99, label: planetarium', '2: probability: 0.00, label: dome', '3: probability: 0.00, label: water tower', '4: probability: 0.00, label: radio telescope, radio reflector', '5: probability: 0.00, label: mosque']]
# [['img_path', '1: probability: 0.84, label: water tower', '2: probability: 0.07, label: beacon, lighthouse, beacon light, pharos', '3: probability: 0.00, label: missile', '4: probability: 0.00, label: balloon', '5: probability: 0.00, label: freight car']]
# step 10, loss=0.0210208
# step 20, loss=0.0127011
# step 30, loss=0.00948766
# step 40, loss=0.00764397
# step 50, loss=0.00649626
# step 60, loss=0.0056876
# step 70, loss=0.00506262
# step 80, loss=0.00457146
# step 90, loss=0.00418656
# step 100, loss=0.00387596
# [['adv', '1: probability: 1.00, label: balloon', '2: probability: 0.00, label: parachute, chute', '3: probability: 0.00, label: water tower', '4: probability: 0.00, label: airship, dirigible', '5: probability: 0.00, label: punching bag, punch bag, punching ball, punchball']]
# [['img_path', '1: probability: 0.84, label: water tower', '2: probability: 0.07, label: beacon, lighthouse, beacon light, pharos', '3: probability: 0.00, label: missile', '4: probability: 0.00, label: balloon', '5: probability: 0.00, label: freight car']]
# step 10, loss=1.32416
# step 20, loss=0.00476534
# step 30, loss=0.00258255
# step 40, loss=0.00184318
# step 50, loss=0.00146353
# step 60, loss=0.00123627
# step 70, loss=0.00107969
# step 80, loss=0.00096239
# step 90, loss=0.000870683
# step 100, loss=0.000796359
# [['adv', '1: probability: 1.00, label: planetarium', '2: probability: 0.00, label: dome', '3: probability: 0.00, label: mosque', '4: probability: 0.00, label: cinema, movie theater, movie theatre, movie house, picture palace', '5: probability: 0.00, label: water tower']]

# %%
img_path, _ = urlretrieve("file:///home/w266ajh/Documents/top5gen/data_imageparts_1/burger1.jpg") #urlretrieve('http://www.anishathalye.com/media/2017/07/25/cat.jpg')
img_class = 281
img = PIL.Image.open(img_path)
big_dim = max(img.width, img.height)
wide = img.width > img.height
new_w = 224 if not wide else int(img.width * 224 / img.height)
new_h = 224 if wide else int(img.height * 224 / img.width)
img = img.resize((new_w, new_h)).crop((0, 0, 224, 224))
img = (np.asarray(img) / 255.0).astype(np.float32)
with open("adv_input", "w") as out:
    out.write(str(img))

# %%
classify(img, correct_class=img_class)
