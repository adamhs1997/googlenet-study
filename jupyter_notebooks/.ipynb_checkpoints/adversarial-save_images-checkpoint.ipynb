# %% [markdown]
# Synthesizing [adversarial examples](https://arxiv.org/abs/1312.6199) for neural networks is surprisingly easy: small, carefully-crafted perturbations to inputs can cause neural networks to misclassify inputs in arbitrarily chosen ways. Given that adversarial examples [transfer to the physical world](https://arxiv.org/abs/1607.02533) and [can be made extremely robust](https://blog.openai.com/robust-adversarial-inputs/), this is a real security concern.
#
# In this post, we give a brief introduction to algorithms for synthesizing adversarial examples, and we walk through the process of implementing attacks in [TensorFlow](https://www.tensorflow.org/), building up to synthesizing a robust adversarial example following [this technique](https://arxiv.org/abs/1707.07397).
#
# **This post is an executable [Jupyter notebook](http://jupyter.org/): you're encouraged to [download it](/media/2017/07/25/adversarial.ipynb) and experiment with the examples yourself!**

# %% [markdown]
# # Setup
#
# We choose to attack an [Inception v3](https://arxiv.org/abs/1512.00567) network trained on [ImageNet](http://www.image-net.org/). In this section, we load a pre-trained network from the [TF-slim image classification library](https://github.com/tensorflow/models/tree/master/slim). This part isn't particularly interesting, so **feel free to [skip this section](#adversarial-examples)**.

# %%
import tensorflow as tf
import tensorflow.contrib.slim as slim
import tensorflow.contrib.slim.nets as nets

# %%
tf.logging.set_verbosity(tf.logging.ERROR)
sess = tf.InteractiveSession()

# %% [markdown]
# First, we set up the input image. We use a `tf.Variable` instead of a `tf.placeholder` because we will need it to be trainable. We can still feed it when we want to.

# %%
image = tf.Variable(tf.zeros((224, 224, 3)))

# %% [markdown]
# Next, we load the Inception v3 model.

# %%
def inception(image, reuse):
    preprocessed = tf.multiply(tf.subtract(tf.expand_dims(image, 0), 0.5), 2.0)
    arg_scope = nets.inception.inception_v1_arg_scope(weight_decay=0.0)
    with slim.arg_scope(arg_scope):
        logits, _ = nets.inception.inception_v1(
            preprocessed, 1001, is_training=False, reuse=reuse)
        logits = logits[:,1:] # ignore background class
        probs = tf.nn.softmax(logits) # probabilities
    return logits, probs

logits, probs = inception(image, reuse=False)

# %% [markdown]
# Next, we load pre-trained weights. This Inception v3 has a top-5 accuracy of 93.9%.

# %%
import tempfile
from urllib.request import urlretrieve
import tarfile
import os

# %%
data_dir = tempfile.mkdtemp()
inception_tarball, _ = urlretrieve(
    'http://download.tensorflow.org/models/inception_v1_2016_08_28.tar.gz')
tarfile.open(inception_tarball, 'r:gz').extractall(data_dir)

# %%
restore_vars = [
    var for var in tf.global_variables()
    if var.name.startswith('InceptionV1/')
]
saver = tf.train.Saver(restore_vars)
saver.restore(sess, os.path.join(data_dir, 'inception_v1.ckpt'))

# %% [markdown]
# Next, we write some code to show an image, classify it, and show the classification result.

# %%
import json
import matplotlib.pyplot as plt

# %%
imagenet_json, _ = urlretrieve(
    'http://www.anishathalye.com/media/2017/07/25/imagenet.json')
with open(imagenet_json) as f:
    imagenet_labels = json.load(f)

# %%
def classify(img, correct_class=None, target_class=None):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 8))
    fig.sca(ax1)
    p = sess.run(probs, feed_dict={image: img})[0]
    ax1.imshow(img)
    fig.sca(ax1)
    
    topk = list(p.argsort()[-10:][::-1])
    topprobs = p[topk]
    barlist = ax2.bar(range(10), topprobs)
    if target_class in topk:
        barlist[topk.index(target_class)].set_color('r')
    if correct_class in topk:
        barlist[topk.index(correct_class)].set_color('g')
    plt.sca(ax2)
    plt.ylim([0, 1.1])
    plt.xticks(range(10),
               [imagenet_labels[i][:15] for i in topk],
               rotation='vertical')
    fig.subplots_adjust(bottom=0.2)
    plt.show()

# %% [markdown]
# ## Example image
#
# We load our example image and make sure it's classified correctly.

# %%
import PIL
import numpy as np
from os import listdir

# %%
# Define our custom get_top_five
def get_top_five(path, img):
    # Get predictions
    p = sess.run(probs, feed_dict={image: img})[0]
    topk = list(p.argsort()[-10:][::-1])
    topprobs = p[topk]
    
    # Put results in nice list
    current_results = [path]
    for i in range(5):
        current_results.append('{}: probability: {:.02f}, label: {}'
              .format(i+1, topprobs[i], imagenet_labels[topk[i]]))

    # Legacy requires us to wrap the results in another empty list
    to_return = []
    to_return.append(current_results)
    return(to_return)

# %%
# Run across each dir and get the similar images predicitons
for advi in [342, 773]:
    demo_target = advi # "guacamole"
    for file in sorted(listdir("/home/w266ajh/Documents/top5gen/data_imageparts_1/")):
        if not file.endswith('.jpg'): continue

        # Get image and write out the results
    #     img_path, _ = urlretrieve("file:///home/w266ajh/Documents/top5gen/data_imageparts_1/" + file) #urlretrieve('http://www.anishathalye.com/media/2017/07/25/cat.jpg')
    #     img_class = 281
        img = PIL.Image.open("/home/w266ajh/Documents/top5gen/data_imageparts_1/" + file)
        big_dim = max(img.width, img.height)
        wide = img.width > img.height
        new_w = 224 if not wide else int(img.width * 224 / img.height)
        new_h = 224 if wide else int(img.height * 224 / img.width)
        img = img.resize((new_w, new_h)).crop((0, 0, 224, 224))
        img = (np.asarray(img) / 255.0).astype(np.float32)
        with open("adv_input", "w") as out:
            out.write(str(img))

        print(get_top_five("img_path", img))
        with open("predictions_1_" + str(advi) + ".csv", 'a+') as f:
            for val in get_top_five("/home/w266ajh/Documents/top5gen/data_imageparts_1/" + file, img)[0]:
                f.write(val + ';')
            f.write('\n')

        # Generate the adversarial ###
        x = tf.placeholder(tf.float32, (224, 224, 3))

        x_hat = image # our trainable adversarial input
        assign_op = tf.assign(x_hat, x)

        learning_rate = tf.placeholder(tf.float32, ())
        y_hat = tf.placeholder(tf.int32, ())

        labels = tf.one_hot(y_hat, 1000)
        loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=[labels])
        optim_step = tf.train.GradientDescentOptimizer(
            learning_rate).minimize(loss, var_list=[x_hat])

        epsilon = tf.placeholder(tf.float32, ())

        below = x - epsilon
        above = x + epsilon
        projected = tf.clip_by_value(tf.clip_by_value(x_hat, below, above), 0, 1)
        with tf.control_dependencies([projected]):
            project_step = tf.assign(x_hat, projected)

        demo_epsilon = 2.0/255.0 # a really small perturbation
        demo_lr = 1e-1
        demo_steps = 100

        # initialization step
        sess.run(assign_op, feed_dict={x: img})

        # projected gradient descent
        for i in range(demo_steps):
            # gradient descent step
            _, loss_value = sess.run(
                [optim_step, loss],
                feed_dict={learning_rate: demo_lr, y_hat: demo_target})
            # project step
            sess.run(project_step, feed_dict={x: img, epsilon: demo_epsilon})
            if (i+1) % 10 == 0:
                print('step %d, loss=%g' % (i+1, loss_value))


        adv = x_hat.eval() # retrieve the adversarial example
        from skimage.io import imsave
        imsave("adv.png", adv, plugin='pil', format_str='png')
        # with open("adv_output.txt", 'w') as out:
        #     out.write(str(a) for a in adv)
        np.set_printoptions(threshold=np.nan)
        with open("adv_output.txt", "w") as out:
            out.write(str(adv))

        ###

        # Get the adv prediction
        print(get_top_five("adv", adv))

        with open("predictions_1_" + str(advi) + ".csv", 'a+') as f:
            for val in get_top_five("adv", adv)[0]:
                f.write(val + ';')
            f.write('\n')
# Out:
# [['img_path', '1: probability: 0.93, label: cheeseburger', '2: probability: 0.03, label: hotdog, hot dog, red hot', '3: probability: 0.01, label: bagel, beigel', '4: probability: 0.00, label: French loaf', '5: probability: 0.00, label: pretzel']]
# step 10, loss=0.836781
# step 20, loss=0.198237
# step 30, loss=0.138039
# step 40, loss=0.109172
# step 50, loss=0.0924095
# step 60, loss=0.0820637
# step 70, loss=0.0742294
# step 80, loss=0.0679194
# step 90, loss=0.0629717
# step 100, loss=0.0587234
# /home/w266ajh/.local/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float32 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# [['adv', '1: probability: 0.94, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: trifle', '4: probability: 0.00, label: shovel', '5: probability: 0.00, label: cucumber, cuke']]
# [['img_path', '1: probability: 0.94, label: cheeseburger', '2: probability: 0.01, label: meat loaf, meatloaf', '3: probability: 0.01, label: guacamole', '4: probability: 0.01, label: plate', '5: probability: 0.01, label: bagel, beigel']]
# step 10, loss=0.0716082
# step 20, loss=0.0352359
# step 30, loss=0.0253301
# step 40, loss=0.0204359
# step 50, loss=0.0171714
# step 60, loss=0.0149659
# step 70, loss=0.0134019
# step 80, loss=0.0121884
# step 90, loss=0.0112091
# step 100, loss=0.0104095
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: beaver', '5: probability: 0.00, label: trifle']]
# [['img_path', '1: probability: 0.99, label: cheeseburger', '2: probability: 0.00, label: bagel, beigel', '3: probability: 0.00, label: guacamole', '4: probability: 0.00, label: hotdog, hot dog, red hot', '5: probability: 0.00, label: meat loaf, meatloaf']]
# step 10, loss=3.94101
# step 20, loss=1.0972
# step 30, loss=0.137446
# step 40, loss=0.0569387
# step 50, loss=0.0415533
# step 60, loss=0.0339049
# step 70, loss=0.0291427
# step 80, loss=0.0257505
# step 90, loss=0.0230221
# step 100, loss=0.0209042
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: cheeseburger', '4: probability: 0.00, label: warthog', '5: probability: 0.00, label: ostrich, Struthio camelus']]
# [['img_path', '1: probability: 0.94, label: cheeseburger', '2: probability: 0.01, label: bagel, beigel', '3: probability: 0.01, label: burrito', '4: probability: 0.01, label: potpie', '5: probability: 0.00, label: guacamole']]
# step 10, loss=0.645327
# step 20, loss=0.0539963
# step 30, loss=0.0349226
# step 40, loss=0.0268618
# step 50, loss=0.0222231
# step 60, loss=0.0188873
# step 70, loss=0.0163832
# step 80, loss=0.0144322
# step 90, loss=0.0130166
# step 100, loss=0.0118871
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: cheeseburger']]
# [['img_path', '1: probability: 0.97, label: cheeseburger', '2: probability: 0.01, label: bagel, beigel', '3: probability: 0.00, label: bakery, bakeshop, bakehouse', '4: probability: 0.00, label: guacamole', '5: probability: 0.00, label: French loaf']]
# step 10, loss=0.27683
# step 20, loss=0.120228
# step 30, loss=0.0860666
# step 40, loss=0.070054
# step 50, loss=0.0603055
# step 60, loss=0.0541242
# step 70, loss=0.0494258
# step 80, loss=0.0456214
# step 90, loss=0.0426967
# step 100, loss=0.0399881
# [['adv', '1: probability: 0.96, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: cheeseburger', '4: probability: 0.00, label: warthog', '5: probability: 0.00, label: puffer, pufferfish, blowfish, globefish']]
# [['img_path', '1: probability: 0.87, label: colobus, colobus monkey', '2: probability: 0.02, label: gibbon, Hylobates lar', '3: probability: 0.00, label: guenon, guenon monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca']]
# step 10, loss=0.328617
# step 20, loss=0.0577663
# step 30, loss=0.043962
# step 40, loss=0.0368685
# step 50, loss=0.0321581
# step 60, loss=0.028904
# step 70, loss=0.0263698
# step 80, loss=0.0244415
# step 90, loss=0.0228534
# step 100, loss=0.0215628
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: beaver', '5: probability: 0.00, label: wombat']]
# [['img_path', '1: probability: 0.92, label: colobus, colobus monkey', '2: probability: 0.01, label: gibbon, Hylobates lar', '3: probability: 0.01, label: guenon, guenon monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: skunk, polecat, wood pussy']]
# step 10, loss=0.165393
# step 20, loss=0.07553
# step 30, loss=0.0540244
# step 40, loss=0.0436571
# step 50, loss=0.0367551
# step 60, loss=0.0320685
# step 70, loss=0.0284214
# step 80, loss=0.0257654
# step 90, loss=0.0236252
# step 100, loss=0.0219436
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: otter', '5: probability: 0.00, label: howler monkey, howler']]
# [['img_path', '1: probability: 0.96, label: colobus, colobus monkey', '2: probability: 0.01, label: guenon, guenon monkey', '3: probability: 0.00, label: langur', '4: probability: 0.00, label: gibbon, Hylobates lar', '5: probability: 0.00, label: titi, titi monkey']]
# step 10, loss=3.51086
# step 20, loss=0.259119
# step 30, loss=0.127579
# step 40, loss=0.0959669
# step 50, loss=0.0784769
# step 60, loss=0.0670208
# step 70, loss=0.0593818
# step 80, loss=0.0540973
# step 90, loss=0.0495179
# step 100, loss=0.0459803
# [['adv', '1: probability: 0.96, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: guenon, guenon monkey', '4: probability: 0.00, label: warthog', '5: probability: 0.00, label: titi, titi monkey']]
# [['img_path', '1: probability: 0.85, label: colobus, colobus monkey', '2: probability: 0.04, label: guenon, guenon monkey', '3: probability: 0.01, label: gibbon, Hylobates lar', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: siamang, Hylobates syndactylus, Symphalangus syndactylus']]
# step 10, loss=3.36419
# step 20, loss=0.0525898
# step 30, loss=0.0295523
# step 40, loss=0.0219731
# step 50, loss=0.0181391
# step 60, loss=0.0155571
# step 70, loss=0.0137857
# step 80, loss=0.0124912
# step 90, loss=0.0114927
# step 100, loss=0.0106527
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: guenon, guenon monkey', '5: probability: 0.00, label: otter']]
# [['img_path', '1: probability: 0.97, label: colobus, colobus monkey', '2: probability: 0.01, label: guenon, guenon monkey', '3: probability: 0.00, label: gibbon, Hylobates lar', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: indri, indris, Indri indri, Indri brevicaudatus']]
# step 10, loss=0.185122
# step 20, loss=0.0753428
# step 30, loss=0.0526629
# step 40, loss=0.0419863
# step 50, loss=0.0357198
# step 60, loss=0.0309716
# step 70, loss=0.0275986
# step 80, loss=0.0250974
# step 90, loss=0.0228353
# step 100, loss=0.0210978
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: beaver', '5: probability: 0.00, label: Scottish deerhound, deerhound']]
# [['img_path', '1: probability: 0.99, label: jackfruit, jak, jack', '2: probability: 0.00, label: fig', '3: probability: 0.00, label: custard apple', '4: probability: 0.00, label: lemon', '5: probability: 0.00, label: green snake, grass snake']]
# step 10, loss=0.0536474
# step 20, loss=0.0278493
# step 30, loss=0.0205017
# step 40, loss=0.0167381
# step 50, loss=0.0144631
# step 60, loss=0.0128661
# step 70, loss=0.0116281
# step 80, loss=0.0106177
# step 90, loss=0.00977928
# step 100, loss=0.00908491
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: mongoose', '5: probability: 0.00, label: beaver']]
# [['img_path', '1: probability: 1.00, label: jackfruit, jak, jack', '2: probability: 0.00, label: honeycomb', '3: probability: 0.00, label: dishrag, dishcloth', '4: probability: 0.00, label: brain coral', '5: probability: 0.00, label: chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour']]
# step 10, loss=0.238063
# step 20, loss=0.0916699
# step 30, loss=0.0591693
# step 40, loss=0.0448891
# step 50, loss=0.0341087
# step 60, loss=0.0289021
# step 70, loss=0.0254182
# step 80, loss=0.0226672
# step 90, loss=0.0207192
# step 100, loss=0.0188536
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: armadillo', '5: probability: 0.00, label: American black bear, black bear, Ursus americanus, Euarctos americanus']]
# [['img_path', '1: probability: 1.00, label: jackfruit, jak, jack', '2: probability: 0.00, label: brain coral', '3: probability: 0.00, label: fig', '4: probability: 0.00, label: honeycomb', '5: probability: 0.00, label: bolete']]
# step 10, loss=2.27932
# step 20, loss=0.25432
# step 30, loss=0.132161
# step 40, loss=0.0973144
# step 50, loss=0.080158
# step 60, loss=0.0692776
# step 70, loss=0.0625261
# step 80, loss=0.05732
# step 90, loss=0.0529404
# step 100, loss=0.0492887
# [['adv', '1: probability: 0.95, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: jackfruit, jak, jack', '4: probability: 0.00, label: brain coral', '5: probability: 0.00, label: bison']]
# [['img_path', '1: probability: 0.98, label: jackfruit, jak, jack', '2: probability: 0.00, label: bolete', '3: probability: 0.00, label: lemon', '4: probability: 0.00, label: custard apple', '5: probability: 0.00, label: acorn']]
# step 10, loss=0.0830392
# step 20, loss=0.0489353
# step 30, loss=0.037365
# step 40, loss=0.0312293
# step 50, loss=0.0272686
# step 60, loss=0.0244853
# step 70, loss=0.0223827
# step 80, loss=0.0206922
# step 90, loss=0.0193079
# step 100, loss=0.0180848
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: beaver', '5: probability: 0.00, label: jackfruit, jak, jack']]
# [['img_path', '1: probability: 0.92, label: jackfruit, jak, jack', '2: probability: 0.01, label: lemon', '3: probability: 0.00, label: vase', '4: probability: 0.00, label: fig', '5: probability: 0.00, label: sulphur butterfly, sulfur butterfly']]
# step 10, loss=2.50738
# step 20, loss=0.17307
# step 30, loss=0.0871592
# step 40, loss=0.0665514
# step 50, loss=0.0544878
# step 60, loss=0.0475462
# step 70, loss=0.0424864
# step 80, loss=0.0385303
# step 90, loss=0.035483
# step 100, loss=0.0331963
# [['adv', '1: probability: 0.97, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: jackfruit, jak, jack', '4: probability: 0.00, label: mongoose', '5: probability: 0.00, label: bonnet, poke bonnet']]
# [['img_path', '1: probability: 0.98, label: nematode, nematode worm, roundworm', '2: probability: 0.01, label: hook, claw', "3: probability: 0.00, label: jack-o'-lantern", '4: probability: 0.00, label: eel', '5: probability: 0.00, label: corkscrew, bottle screw']]
# step 10, loss=0.44836
# step 20, loss=0.0113554
# step 30, loss=0.00471967
# step 40, loss=0.00340323
# step 50, loss=0.00275661
# step 60, loss=0.00235732
# step 70, loss=0.00207269
# step 80, loss=0.00186032
# step 90, loss=0.00170098
# step 100, loss=0.00157816
# [['adv', '1: probability: 1.00, label: wild boar, boar, Sus scrofa', '2: probability: 0.00, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: brown bear, bruin, Ursus arctos', '5: probability: 0.00, label: sloth bear, Melursus ursinus, Ursus ursinus']]
# [['img_path', '1: probability: 0.98, label: nematode, nematode worm, roundworm', '2: probability: 0.01, label: vine snake', '3: probability: 0.00, label: sea snake', '4: probability: 0.00, label: hook, claw', '5: probability: 0.00, label: water snake']]
# step 10, loss=3.51147
# step 20, loss=0.801797
# step 30, loss=0.854089
# step 40, loss=0.00662808
# step 50, loss=0.00395635
# step 60, loss=0.00297105
# step 70, loss=0.00244045
# step 80, loss=0.00209018
# step 90, loss=0.00184437
# step 100, loss=0.00165528
# [['adv', '1: probability: 1.00, label: wild boar, boar, Sus scrofa', '2: probability: 0.00, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: mongoose', '5: probability: 0.00, label: beaver']]
# [['img_path', '1: probability: 1.00, label: nematode, nematode worm, roundworm', '2: probability: 0.00, label: hook, claw', '3: probability: 0.00, label: vine snake', '4: probability: 0.00, label: night snake, Hypsiglena torquata', '5: probability: 0.00, label: eel']]
# step 10, loss=0.0105925
# step 20, loss=0.00539158
# step 30, loss=0.0039161
# step 40, loss=0.00315157
# step 50, loss=0.0026854
# step 60, loss=0.00234543
# step 70, loss=0.00209731
# step 80, loss=0.00190351
# step 90, loss=0.0017512
# step 100, loss=0.00162553
# [['adv', '1: probability: 1.00, label: wild boar, boar, Sus scrofa', '2: probability: 0.00, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: brown bear, bruin, Ursus arctos', '5: probability: 0.00, label: mongoose']]
# [['img_path', '1: probability: 1.00, label: nematode, nematode worm, roundworm', '2: probability: 0.00, label: crane', '3: probability: 0.00, label: hook, claw', '4: probability: 0.00, label: scabbard', '5: probability: 0.00, label: ladle']]
# step 10, loss=2.45959
# step 20, loss=0.0195339
# step 30, loss=0.0112764
# step 40, loss=0.00869311
# step 50, loss=0.00730936
# step 60, loss=0.00636278
# step 70, loss=0.00571356
# step 80, loss=0.00519343
# step 90, loss=0.00477792
# step 100, loss=0.0044433
# [['adv', '1: probability: 1.00, label: wild boar, boar, Sus scrofa', '2: probability: 0.00, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: bonnet, poke bonnet', '5: probability: 0.00, label: beaver']]
# [['img_path', '1: probability: 1.00, label: nematode, nematode worm, roundworm', '2: probability: 0.00, label: hook, claw', '3: probability: 0.00, label: crane', '4: probability: 0.00, label: chain', '5: probability: 0.00, label: sax, saxophone']]
# step 10, loss=5.02715
# step 20, loss=5.82071
# step 30, loss=5.8344
# step 40, loss=4.10694
# step 50, loss=2.01265
# step 60, loss=6.20125
# step 70, loss=6.58247
# step 80, loss=9.5335
# step 90, loss=4.72593
# step 100, loss=0.0403911
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: sloth bear, Melursus ursinus, Ursus ursinus', '5: probability: 0.00, label: beaver']]
# [['img_path', '1: probability: 0.97, label: remote control, remote', '2: probability: 0.01, label: dial telephone, dial phone', '3: probability: 0.00, label: cellular telephone, cellular phone, cellphone, cell, mobile phone', '4: probability: 0.00, label: microwave, microwave oven', '5: probability: 0.00, label: CD player']]
# step 10, loss=4.43183
# step 20, loss=3.11111
# step 30, loss=0.400105
# step 40, loss=0.0989852
# step 50, loss=0.0711736
# step 60, loss=0.058694
# step 70, loss=0.0512739
# step 80, loss=0.0452373
# step 90, loss=0.0409407
# step 100, loss=0.0375423
# [['adv', '1: probability: 0.96, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: torch', '5: probability: 0.00, label: dial telephone, dial phone']]
# [['img_path', '1: probability: 0.97, label: remote control, remote', '2: probability: 0.00, label: hair slide', '3: probability: 0.00, label: cellular telephone, cellular phone, cellphone, cell, mobile phone', '4: probability: 0.00, label: pencil box, pencil case', '5: probability: 0.00, label: Band Aid']]
# step 10, loss=1.97975
# step 20, loss=0.0458198
# step 30, loss=0.0287455
# step 40, loss=0.0225102
# step 50, loss=0.0188654
# step 60, loss=0.0164127
# step 70, loss=0.0146383
# step 80, loss=0.0132945
# step 90, loss=0.0122172
# step 100, loss=0.0113575
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: beaver', '4: probability: 0.00, label: warthog', '5: probability: 0.00, label: eel']]
# [['img_path', '1: probability: 0.80, label: remote control, remote', '2: probability: 0.04, label: hand-held computer, hand-held microcomputer', '3: probability: 0.02, label: radio, wireless', '4: probability: 0.02, label: joystick', '5: probability: 0.01, label: CD player']]
# step 10, loss=3.28491
# step 20, loss=1.69226
# step 30, loss=0.933795
# step 40, loss=0.49022
# step 50, loss=0.318479
# step 60, loss=0.240928
# step 70, loss=0.167493
# step 80, loss=0.12818
# step 90, loss=0.121923
# step 100, loss=0.105842
# [['adv', '1: probability: 0.90, label: wild boar, boar, Sus scrofa', '2: probability: 0.05, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.01, label: warthog', '4: probability: 0.01, label: reel', '5: probability: 0.00, label: hand-held computer, hand-held microcomputer']]
# [['img_path', '1: probability: 0.99, label: remote control, remote', '2: probability: 0.00, label: joystick', '3: probability: 0.00, label: dial telephone, dial phone', '4: probability: 0.00, label: switch, electric switch, electrical switch', '5: probability: 0.00, label: space bar']]
# step 10, loss=3.72322
# step 20, loss=2.27484
# step 30, loss=0.544028
# step 40, loss=0.213578
# step 50, loss=0.155542
# step 60, loss=0.126714
# step 70, loss=0.111515
# step 80, loss=0.100813
# step 90, loss=0.0934615
# step 100, loss=0.0876034
# [['adv', '1: probability: 0.92, label: wild boar, boar, Sus scrofa', '2: probability: 0.05, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: clog, geta, patten, sabot', '5: probability: 0.00, label: mongoose']]
# [['img_path', '1: probability: 0.97, label: remote control, remote', '2: probability: 0.00, label: dial telephone, dial phone', '3: probability: 0.00, label: cellular telephone, cellular phone, cellphone, cell, mobile phone', '4: probability: 0.00, label: hand-held computer, hand-held microcomputer', '5: probability: 0.00, label: microwave, microwave oven']]
# step 10, loss=3.25744
# step 20, loss=1.23219
# step 30, loss=0.139324
# step 40, loss=0.0728705
# step 50, loss=0.0558525
# step 60, loss=0.0465493
# step 70, loss=0.0406913
# step 80, loss=0.0362484
# step 90, loss=0.0326323
# step 100, loss=0.0301246
# [['adv', '1: probability: 0.97, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: ostrich, Struthio camelus', '5: probability: 0.00, label: remote control, remote']]
# [['img_path', '1: probability: 0.50, label: slide rule, slipstick', '2: probability: 0.10, label: rule, ruler', '3: probability: 0.02, label: syringe', '4: probability: 0.01, label: envelope', '5: probability: 0.01, label: crossword puzzle, crossword']]
# step 10, loss=3.15025
# step 20, loss=0.580229
# step 30, loss=0.0645726
# step 40, loss=0.0356212
# step 50, loss=0.026982
# step 60, loss=0.0227193
# step 70, loss=0.0198505
# step 80, loss=0.0179098
# step 90, loss=0.0162402
# step 100, loss=0.0150956
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: bobsled, bobsleigh, bob', '5: probability: 0.00, label: piggy bank, penny bank']]
# [['img_path', '1: probability: 0.74, label: slide rule, slipstick', '2: probability: 0.14, label: rule, ruler', '3: probability: 0.02, label: oscilloscope, scope, cathode-ray oscilloscope, CRO', '4: probability: 0.02, label: radio, wireless', '5: probability: 0.02, label: scale, weighing machine']]
# step 10, loss=3.69247
# step 20, loss=1.28234
# step 30, loss=0.170252
# step 40, loss=0.121249
# step 50, loss=0.0996067
# step 60, loss=0.0862344
# step 70, loss=0.0770786
# step 80, loss=0.070392
# step 90, loss=0.0657873
# step 100, loss=0.0615891
# [['adv', '1: probability: 0.94, label: wild boar, boar, Sus scrofa', '2: probability: 0.04, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '5: probability: 0.00, label: hyena, hyaena']]
# [['img_path', '1: probability: 1.00, label: slide rule, slipstick', '2: probability: 0.00, label: rule, ruler', '3: probability: 0.00, label: Band Aid', '4: probability: 0.00, label: harmonica, mouth organ, harp, mouth harp', '5: probability: 0.00, label: rubber eraser, rubber, pencil eraser']]
# step 10, loss=3.80366
# step 20, loss=0.706193
# step 30, loss=0.201538
# step 40, loss=0.116001
# step 50, loss=0.0914522
# step 60, loss=0.0781515
# step 70, loss=0.0663819
# step 80, loss=0.0588909
# step 90, loss=0.0533892
# step 100, loss=0.050949
# [['adv', '1: probability: 0.95, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: American black bear, black bear, Ursus americanus, Euarctos americanus', '5: probability: 0.00, label: cinema, movie theater, movie theatre, movie house, picture palace']]
# [['img_path', '1: probability: 0.96, label: slide rule, slipstick', '2: probability: 0.03, label: rule, ruler', '3: probability: 0.00, label: harmonica, mouth organ, harp, mouth harp', '4: probability: 0.00, label: syringe', '5: probability: 0.00, label: liner, ocean liner']]
# step 10, loss=1.70831
# step 20, loss=0.0148375
# step 30, loss=0.00935079
# step 40, loss=0.00714888
# step 50, loss=0.00586195
# step 60, loss=0.00496808
# step 70, loss=0.00432674
# step 80, loss=0.00386551
# step 90, loss=0.0035067
# step 100, loss=0.00321776
# [['adv', '1: probability: 1.00, label: wild boar, boar, Sus scrofa', '2: probability: 0.00, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: mongoose', '4: probability: 0.00, label: brown bear, bruin, Ursus arctos', '5: probability: 0.00, label: warthog']]
# [['img_path', '1: probability: 1.00, label: slide rule, slipstick', '2: probability: 0.00, label: rule, ruler', '3: probability: 0.00, label: fountain pen', '4: probability: 0.00, label: scale, weighing machine', '5: probability: 0.00, label: scabbard']]
# step 10, loss=3.36369
# step 20, loss=2.33034
# step 30, loss=0.0535951
# step 40, loss=0.0294502
# step 50, loss=0.0226574
# step 60, loss=0.0190784
# step 70, loss=0.0166542
# step 80, loss=0.014934
# step 90, loss=0.0135756
# step 100, loss=0.0124074
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: beaver', '5: probability: 0.00, label: brown bear, bruin, Ursus arctos']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: minibus', '3: probability: 0.00, label: trolleybus, trolley coach, trackless trolley', '4: probability: 0.00, label: passenger car, coach, carriage', '5: probability: 0.00, label: lifeboat']]
# step 10, loss=4.06836
# step 20, loss=2.11831
# step 30, loss=1.20937
# step 40, loss=0.817317
# step 50, loss=0.592144
# step 60, loss=0.503321
# step 70, loss=0.463568
# step 80, loss=0.417113
# step 90, loss=0.391717
# step 100, loss=0.371951
# [['adv', '1: probability: 0.69, label: wild boar, boar, Sus scrofa', '2: probability: 0.09, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.03, label: school bus', '4: probability: 0.01, label: snowplow, snowplough', '5: probability: 0.01, label: minibus']]
# [['img_path', '1: probability: 0.92, label: school bus', '2: probability: 0.01, label: minibus', '3: probability: 0.00, label: ambulance', '4: probability: 0.00, label: cab, hack, taxi, taxicab', '5: probability: 0.00, label: fire engine, fire truck']]
# step 10, loss=2.75675
# step 20, loss=0.771494
# step 30, loss=0.146292
# step 40, loss=0.0984015
# step 50, loss=0.077357
# step 60, loss=0.0656383
# step 70, loss=0.0575427
# step 80, loss=0.0516563
# step 90, loss=0.0473427
# step 100, loss=0.043955
# [['adv', '1: probability: 0.96, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: school bus', '5: probability: 0.00, label: minibus']]
# [['img_path', '1: probability: 0.91, label: school bus', '2: probability: 0.02, label: minibus', '3: probability: 0.02, label: moving van', '4: probability: 0.01, label: ambulance', '5: probability: 0.00, label: fire engine, fire truck']]
# step 10, loss=3.17501
# step 20, loss=1.83186
# step 30, loss=1.16958
# step 40, loss=0.828739
# step 50, loss=0.76856
# step 60, loss=0.618455
# step 70, loss=0.555941
# step 80, loss=0.529643
# step 90, loss=0.511133
# step 100, loss=0.484198
# [['adv', '1: probability: 0.63, label: wild boar, boar, Sus scrofa', '2: probability: 0.12, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.03, label: moving van', '4: probability: 0.01, label: snowplow, snowplough', '5: probability: 0.01, label: ambulance']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: cab, hack, taxi, taxicab', '3: probability: 0.00, label: lifeboat', '4: probability: 0.00, label: trolleybus, trolley coach, trackless trolley', '5: probability: 0.00, label: passenger car, coach, carriage']]
# step 10, loss=5.15605
# step 20, loss=4.13763
# step 30, loss=3.62951
# step 40, loss=3.29967
# step 50, loss=3.09274
# step 60, loss=2.97705
# step 70, loss=2.7892
# step 80, loss=2.90635
# step 90, loss=2.74775
# step 100, loss=2.73166
# [['adv', '1: probability: 0.16, label: minibus', '2: probability: 0.10, label: warthog', '3: probability: 0.07, label: wild boar, boar, Sus scrofa', '4: probability: 0.07, label: school bus', '5: probability: 0.05, label: hog, pig, grunter, squealer, Sus scrofa']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: crane', '3: probability: 0.00, label: cab, hack, taxi, taxicab', '4: probability: 0.00, label: trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi', '5: probability: 0.00, label: minibus']]
# step 10, loss=3.37226
# step 20, loss=1.87386
# step 30, loss=1.22166
# step 40, loss=0.805221
# step 50, loss=0.548947
# step 60, loss=0.419497
# step 70, loss=0.357833
# step 80, loss=0.31789
# step 90, loss=0.28444
# step 100, loss=0.257456
# [['adv', '1: probability: 0.77, label: wild boar, boar, Sus scrofa', '2: probability: 0.09, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.02, label: warthog', '4: probability: 0.01, label: snowplow, snowplough', '5: probability: 0.01, label: school bus']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: teddy, teddy bear', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: pencil box, pencil case', '5: probability: 0.00, label: packet']]
# step 10, loss=0.124136
# step 20, loss=0.0293887
# step 30, loss=0.0205881
# step 40, loss=0.0164057
# step 50, loss=0.0139766
# step 60, loss=0.0123296
# step 70, loss=0.0110666
# step 80, loss=0.0100864
# step 90, loss=0.0092791
# step 100, loss=0.00860861
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: Indian elephant, Elephas maximus', '5: probability: 0.00, label: beaver']]
# [['img_path', '1: probability: 0.95, label: Christmas stocking', '2: probability: 0.04, label: sock', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: bib', '5: probability: 0.00, label: purse']]
# step 10, loss=3.84963
# step 20, loss=1.85968
# step 30, loss=0.0648372
# step 40, loss=0.0426519
# step 50, loss=0.0346963
# step 60, loss=0.0302045
# step 70, loss=0.0273126
# step 80, loss=0.0249899
# step 90, loss=0.023303
# step 100, loss=0.0218854
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: clog, geta, patten, sabot', '5: probability: 0.00, label: Irish wolfhound']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: sock', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: teddy, teddy bear', '5: probability: 0.00, label: pillow']]
# step 10, loss=2.10798
# step 20, loss=0.276797
# step 30, loss=0.152195
# step 40, loss=0.120543
# step 50, loss=0.102721
# step 60, loss=0.0909732
# step 70, loss=0.0828929
# step 80, loss=0.0769779
# step 90, loss=0.0712581
# step 100, loss=0.0675858
# [['adv', '1: probability: 0.93, label: wild boar, boar, Sus scrofa', '2: probability: 0.04, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: shovel', '4: probability: 0.00, label: dogsled, dog sled, dog sleigh', '5: probability: 0.00, label: warthog']]
# [['img_path', '1: probability: 0.94, label: Christmas stocking', '2: probability: 0.01, label: pillow', '3: probability: 0.00, label: mailbag, postbag', '4: probability: 0.00, label: packet', '5: probability: 0.00, label: purse']]
# step 10, loss=2.96727
# step 20, loss=0.54184
# step 30, loss=0.140396
# step 40, loss=0.105243
# step 50, loss=0.0855094
# step 60, loss=0.0729406
# step 70, loss=0.0676691
# step 80, loss=0.0612565
# step 90, loss=0.0583461
# step 100, loss=0.0540618
# [['adv', '1: probability: 0.95, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: mailbox, letter box', '4: probability: 0.00, label: ski', '5: probability: 0.00, label: warthog']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: apron', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: flagpole, flagstaff', '5: probability: 0.00, label: brassiere, bra, bandeau']]
# step 10, loss=3.8769
# step 20, loss=2.38292
# step 30, loss=1.79032
# step 40, loss=1.67441
# step 50, loss=0.798496
# step 60, loss=0.633306
# step 70, loss=0.619126
# step 80, loss=0.351005
# step 90, loss=0.308038
# step 100, loss=0.281853
# [['adv', '1: probability: 0.75, label: wild boar, boar, Sus scrofa', '2: probability: 0.12, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.01, label: warthog', '4: probability: 0.01, label: Christmas stocking', '5: probability: 0.00, label: clog, geta, patten, sabot']]
# [['img_path', '1: probability: 1.00, label: bullet train, bullet', '2: probability: 0.00, label: bobsled, bobsleigh, bob', '3: probability: 0.00, label: limousine, limo', '4: probability: 0.00, label: sports car, sport car', '5: probability: 0.00, label: streetcar, tram, tramcar, trolley, trolley car']]
# step 10, loss=0.52511
# step 20, loss=0.12132
# step 30, loss=0.0845243
# step 40, loss=0.0677092
# step 50, loss=0.0583192
# step 60, loss=0.0515876
# step 70, loss=0.0464529
# step 80, loss=0.0428685
# step 90, loss=0.0392899
# step 100, loss=0.0366575
# [['adv', '1: probability: 0.96, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: bobsled, bobsleigh, bob', '5: probability: 0.00, label: bullet train, bullet']]
# [['img_path', '1: probability: 0.98, label: bullet train, bullet', '2: probability: 0.00, label: limousine, limo', '3: probability: 0.00, label: bobsled, bobsleigh, bob', '4: probability: 0.00, label: solar dish, solar collector, solar furnace', '5: probability: 0.00, label: convertible']]
# step 10, loss=1.40183
# step 20, loss=0.661793
# step 30, loss=0.488923
# step 40, loss=0.376526
# step 50, loss=0.328171
# step 60, loss=0.292762
# step 70, loss=0.259677
# step 80, loss=0.237342
# step 90, loss=0.223965
# step 100, loss=0.207674
# [['adv', '1: probability: 0.81, label: wild boar, boar, Sus scrofa', '2: probability: 0.09, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.01, label: bullet train, bullet', '4: probability: 0.01, label: warthog', '5: probability: 0.01, label: bobsled, bobsleigh, bob']]
# [['img_path', '1: probability: 0.91, label: bullet train, bullet', '2: probability: 0.00, label: speedboat', '3: probability: 0.00, label: aircraft carrier, carrier, flattop, attack aircraft carrier', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: warplane, military plane']]
# step 10, loss=3.96031
# step 20, loss=2.72223
# step 30, loss=2.0932
# step 40, loss=1.80668
# step 50, loss=1.56674
# step 60, loss=1.50731
# step 70, loss=1.43379
# step 80, loss=1.34167
# step 90, loss=1.32447
# step 100, loss=1.13203
# [['adv', '1: probability: 0.32, label: wild boar, boar, Sus scrofa', '2: probability: 0.17, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.12, label: bullet train, bullet', '4: probability: 0.08, label: bobsled, bobsleigh, bob', '5: probability: 0.01, label: snowmobile']]
# [['img_path', '1: probability: 0.99, label: bullet train, bullet', '2: probability: 0.01, label: mouse, computer mouse', '3: probability: 0.00, label: passenger car, coach, carriage', '4: probability: 0.00, label: limousine, limo', '5: probability: 0.00, label: sports car, sport car']]
# step 10, loss=0.676129
# step 20, loss=0.169444
# step 30, loss=0.118122
# step 40, loss=0.0961466
# step 50, loss=0.0811814
# step 60, loss=0.0725614
# step 70, loss=0.0654928
# step 80, loss=0.0603104
# step 90, loss=0.0555792
# step 100, loss=0.0514217
# [['adv', '1: probability: 0.95, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.01, label: warthog', '4: probability: 0.00, label: bullet train, bullet', '5: probability: 0.00, label: clog, geta, patten, sabot']]
# [['img_path', '1: probability: 0.88, label: bullet train, bullet', '2: probability: 0.04, label: warplane, military plane', '3: probability: 0.01, label: wing', '4: probability: 0.01, label: projectile, missile', '5: probability: 0.01, label: bobsled, bobsleigh, bob']]
# step 10, loss=0.761612
# step 20, loss=0.0824343
# step 30, loss=0.0499174
# step 40, loss=0.0366529
# step 50, loss=0.0298348
# step 60, loss=0.0256036
# step 70, loss=0.0224565
# step 80, loss=0.0200315
# step 90, loss=0.0181306
# step 100, loss=0.0166819
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: bullet train, bullet', '4: probability: 0.00, label: bobsled, bobsleigh, bob', '5: probability: 0.00, label: snowmobile']]
# [['img_path', '1: probability: 0.99, label: weevil', '2: probability: 0.00, label: ground beetle, carabid beetle', '3: probability: 0.00, label: leaf beetle, chrysomelid', '4: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle', '5: probability: 0.00, label: dung beetle']]
# step 10, loss=0.151659
# step 20, loss=0.070962
# step 30, loss=0.0506025
# step 40, loss=0.0408368
# step 50, loss=0.0348265
# step 60, loss=0.0305685
# step 70, loss=0.0273728
# step 80, loss=0.0249624
# step 90, loss=0.0230531
# step 100, loss=0.021458
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: beaver', '5: probability: 0.00, label: Irish wolfhound']]
# [['img_path', '1: probability: 0.98, label: weevil', '2: probability: 0.01, label: leaf beetle, chrysomelid', '3: probability: 0.00, label: ground beetle, carabid beetle', '4: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle', '5: probability: 0.00, label: dung beetle']]
# step 10, loss=1.7704
# step 20, loss=0.510185
# step 30, loss=0.0591703
# step 40, loss=0.0356289
# step 50, loss=0.0274697
# step 60, loss=0.0233512
# step 70, loss=0.0203091
# step 80, loss=0.0180188
# step 90, loss=0.0164554
# step 100, loss=0.0151421
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: beaver', '5: probability: 0.00, label: brown bear, bruin, Ursus arctos']]
# [['img_path', '1: probability: 0.98, label: weevil', '2: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle', '3: probability: 0.00, label: ground beetle, carabid beetle', '4: probability: 0.00, label: leaf beetle, chrysomelid', '5: probability: 0.00, label: cricket']]
# step 10, loss=1.39274
# step 20, loss=0.110347
# step 30, loss=0.0706675
# step 40, loss=0.0551031
# step 50, loss=0.0464353
# step 60, loss=0.0404164
# step 70, loss=0.0360529
# step 80, loss=0.0327112
# step 90, loss=0.0300921
# step 100, loss=0.0279558
# [['adv', '1: probability: 0.97, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: mongoose', '4: probability: 0.00, label: weevil', '5: probability: 0.00, label: warthog']]
# [['img_path', '1: probability: 0.98, label: weevil', '2: probability: 0.00, label: broccoli', '3: probability: 0.00, label: leaf beetle, chrysomelid', '4: probability: 0.00, label: dung beetle', '5: probability: 0.00, label: leafhopper']]
# step 10, loss=0.133804
# step 20, loss=0.0615233
# step 30, loss=0.0437766
# step 40, loss=0.0348237
# step 50, loss=0.0289763
# step 60, loss=0.0253547
# step 70, loss=0.0225752
# step 80, loss=0.0204599
# step 90, loss=0.0188519
# step 100, loss=0.017437
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: beaver', '5: probability: 0.00, label: porcupine, hedgehog']]
# [['img_path', '1: probability: 0.98, label: weevil', '2: probability: 0.00, label: dung beetle', '3: probability: 0.00, label: ground beetle, carabid beetle', '4: probability: 0.00, label: leaf beetle, chrysomelid', '5: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle']]
# step 10, loss=0.0495412
# step 20, loss=0.0262381
# step 30, loss=0.0188723
# step 40, loss=0.0149883
# step 50, loss=0.0127676
# step 60, loss=0.0112677
# step 70, loss=0.010074
# step 80, loss=0.00909661
# step 90, loss=0.00833249
# step 100, loss=0.00769591
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: ibex, Capra ibex', '5: probability: 0.00, label: timber wolf, grey wolf, gray wolf, Canis lupus']]
# [['img_path', '1: probability: 0.93, label: cheeseburger', '2: probability: 0.03, label: hotdog, hot dog, red hot', '3: probability: 0.01, label: bagel, beigel', '4: probability: 0.00, label: French loaf', '5: probability: 0.00, label: pretzel']]
# step 10, loss=0.0483023
# step 20, loss=0.022154
# step 30, loss=0.0154331
# step 40, loss=0.0122085
# step 50, loss=0.0101856
# step 60, loss=0.00876603
# step 70, loss=0.00771259
# step 80, loss=0.00692172
# step 90, loss=0.00628376
# step 100, loss=0.005765
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: chocolate sauce, chocolate syrup', '3: probability: 0.00, label: soap dispenser', '4: probability: 0.00, label: bottlecap', '5: probability: 0.00, label: ice cream, icecream']]
# [['img_path', '1: probability: 0.94, label: cheeseburger', '2: probability: 0.01, label: meat loaf, meatloaf', '3: probability: 0.01, label: guacamole', '4: probability: 0.01, label: plate', '5: probability: 0.01, label: bagel, beigel']]
# step 10, loss=0.0119751
# step 20, loss=0.00587285
# step 30, loss=0.00413029
# step 40, loss=0.00324592
# step 50, loss=0.00268314
# step 60, loss=0.00230737
# step 70, loss=0.00203248
# step 80, loss=0.00182486
# step 90, loss=0.00165992
# step 100, loss=0.00152793
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: zucchini, courgette', '4: probability: 0.00, label: teapot', '5: probability: 0.00, label: ice cream, icecream']]
# [['img_path', '1: probability: 0.99, label: cheeseburger', '2: probability: 0.00, label: bagel, beigel', '3: probability: 0.00, label: guacamole', '4: probability: 0.00, label: hotdog, hot dog, red hot', '5: probability: 0.00, label: meat loaf, meatloaf']]
# step 10, loss=0.0857579
# step 20, loss=0.0339076
# step 30, loss=0.0233007
# step 40, loss=0.0182728
# step 50, loss=0.0151082
# step 60, loss=0.0128775
# step 70, loss=0.0112394
# step 80, loss=0.0100345
# step 90, loss=0.00910889
# step 100, loss=0.00838096
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: vase', '4: probability: 0.00, label: soap dispenser', '5: probability: 0.00, label: pitcher, ewer']]
# [['img_path', '1: probability: 0.94, label: cheeseburger', '2: probability: 0.01, label: bagel, beigel', '3: probability: 0.01, label: burrito', '4: probability: 0.01, label: potpie', '5: probability: 0.00, label: guacamole']]
# step 10, loss=0.300672
# step 20, loss=0.031842
# step 30, loss=0.0183477
# step 40, loss=0.0134494
# step 50, loss=0.010708
# step 60, loss=0.00876248
# step 70, loss=0.00734297
# step 80, loss=0.00630307
# step 90, loss=0.00552899
# step 100, loss=0.00493451
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: ice cream, icecream', '4: probability: 0.00, label: cheeseburger', '5: probability: 0.00, label: bakery, bakeshop, bakehouse']]
# [['img_path', '1: probability: 0.97, label: cheeseburger', '2: probability: 0.01, label: bagel, beigel', '3: probability: 0.00, label: bakery, bakeshop, bakehouse', '4: probability: 0.00, label: guacamole', '5: probability: 0.00, label: French loaf']]
# step 10, loss=0.0629067
# step 20, loss=0.0300863
# step 30, loss=0.0210383
# step 40, loss=0.0166716
# step 50, loss=0.0140665
# step 60, loss=0.0122569
# step 70, loss=0.0108916
# step 80, loss=0.00983087
# step 90, loss=0.00899513
# step 100, loss=0.00830388
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: thimble', '4: probability: 0.00, label: candle, taper, wax light', '5: probability: 0.00, label: vase']]
# [['img_path', '1: probability: 0.87, label: colobus, colobus monkey', '2: probability: 0.02, label: gibbon, Hylobates lar', '3: probability: 0.00, label: guenon, guenon monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: giant panda, panda, panda bear, coon bear, Ailuropoda melanoleuca']]
# step 10, loss=0.581435
# step 20, loss=0.0434327
# step 30, loss=0.027149
# step 40, loss=0.0201464
# step 50, loss=0.0163417
# step 60, loss=0.0138446
# step 70, loss=0.0120619
# step 80, loss=0.0107282
# step 90, loss=0.00969169
# step 100, loss=0.00886434
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: thimble', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: colobus, colobus monkey']]
# [['img_path', '1: probability: 0.92, label: colobus, colobus monkey', '2: probability: 0.01, label: gibbon, Hylobates lar', '3: probability: 0.01, label: guenon, guenon monkey', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: skunk, polecat, wood pussy']]
# step 10, loss=1.2482
# step 20, loss=0.104945
# step 30, loss=0.0269118
# step 40, loss=0.0173374
# step 50, loss=0.0140501
# step 60, loss=0.0110403
# step 70, loss=0.00980277
# step 80, loss=0.00876012
# step 90, loss=0.00796346
# step 100, loss=0.00735244
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: titi, titi monkey', '3: probability: 0.00, label: thimble', '4: probability: 0.00, label: colobus, colobus monkey', '5: probability: 0.00, label: soap dispenser']]
# [['img_path', '1: probability: 0.96, label: colobus, colobus monkey', '2: probability: 0.01, label: guenon, guenon monkey', '3: probability: 0.00, label: langur', '4: probability: 0.00, label: gibbon, Hylobates lar', '5: probability: 0.00, label: titi, titi monkey']]
# step 10, loss=0.942803
# step 20, loss=0.0474871
# step 30, loss=0.0305959
# step 40, loss=0.0231098
# step 50, loss=0.0189743
# step 60, loss=0.0162491
# step 70, loss=0.0143163
# step 80, loss=0.0128279
# step 90, loss=0.0116217
# step 100, loss=0.0106245
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: langur', '4: probability: 0.00, label: titi, titi monkey', '5: probability: 0.00, label: colobus, colobus monkey']]
# [['img_path', '1: probability: 0.85, label: colobus, colobus monkey', '2: probability: 0.04, label: guenon, guenon monkey', '3: probability: 0.01, label: gibbon, Hylobates lar', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: siamang, Hylobates syndactylus, Symphalangus syndactylus']]
# step 10, loss=0.396405
# step 20, loss=0.0251096
# step 30, loss=0.0160341
# step 40, loss=0.0122459
# step 50, loss=0.0100544
# step 60, loss=0.00857363
# step 70, loss=0.00753833
# step 80, loss=0.00670292
# step 90, loss=0.00606269
# step 100, loss=0.00556965
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: baboon', '3: probability: 0.00, label: teapot', '4: probability: 0.00, label: guenon, guenon monkey', '5: probability: 0.00, label: thimble']]
# [['img_path', '1: probability: 0.97, label: colobus, colobus monkey', '2: probability: 0.01, label: guenon, guenon monkey', '3: probability: 0.00, label: gibbon, Hylobates lar', '4: probability: 0.00, label: langur', '5: probability: 0.00, label: indri, indris, Indri indri, Indri brevicaudatus']]
# step 10, loss=0.248223
# step 20, loss=0.0637384
# step 30, loss=0.0441568
# step 40, loss=0.0350706
# step 50, loss=0.0299188
# step 60, loss=0.026094
# step 70, loss=0.0233638
# step 80, loss=0.0212294
# step 90, loss=0.0195261
# step 100, loss=0.0180822
# [['adv', '1: probability: 0.98, label: saltshaker, salt shaker', '2: probability: 0.00, label: colobus, colobus monkey', '3: probability: 0.00, label: cocktail shaker', '4: probability: 0.00, label: lighter, light, igniter, ignitor', '5: probability: 0.00, label: guenon, guenon monkey']]
# [['img_path', '1: probability: 0.99, label: jackfruit, jak, jack', '2: probability: 0.00, label: fig', '3: probability: 0.00, label: custard apple', '4: probability: 0.00, label: lemon', '5: probability: 0.00, label: green snake, grass snake']]
# step 10, loss=0.019433
# step 20, loss=0.00840957
# step 30, loss=0.00588589
# step 40, loss=0.00465666
# step 50, loss=0.00391004
# step 60, loss=0.00341178
# step 70, loss=0.00303725
# step 80, loss=0.00274626
# ...
# step 10, loss=0.0111801
# step 20, loss=0.00569957
# step 30, loss=0.00412399
# step 40, loss=0.00331495
# step 50, loss=0.00278336
# step 60, loss=0.00239847
# step 70, loss=0.00211159
# step 80, loss=0.00188745
# step 90, loss=0.00171074
# step 100, loss=0.00157292
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: perfume, essence', '4: probability: 0.00, label: thimble', '5: probability: 0.00, label: pill bottle']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: minibus', '3: probability: 0.00, label: trolleybus, trolley coach, trackless trolley', '4: probability: 0.00, label: passenger car, coach, carriage', '5: probability: 0.00, label: lifeboat']]
# step 10, loss=4.1643
# step 20, loss=3.23032
# step 30, loss=2.66026
# step 40, loss=2.52534
# step 50, loss=2.37738
# step 60, loss=2.18585
# step 70, loss=1.99707
# step 80, loss=2.09108
# step 90, loss=1.91175
# step 100, loss=1.8017
# [['adv', '1: probability: 0.18, label: saltshaker, salt shaker', '2: probability: 0.15, label: school bus', '3: probability: 0.01, label: puck, hockey puck', '4: probability: 0.01, label: buckle', '5: probability: 0.01, label: minibus']]
# [['img_path', '1: probability: 0.92, label: school bus', '2: probability: 0.01, label: minibus', '3: probability: 0.00, label: ambulance', '4: probability: 0.00, label: cab, hack, taxi, taxicab', '5: probability: 0.00, label: fire engine, fire truck']]
# step 10, loss=3.30116
# step 20, loss=2.11167
# step 30, loss=1.0056
# step 40, loss=0.876844
# step 50, loss=0.319303
# step 60, loss=0.312944
# step 70, loss=0.179013
# step 80, loss=0.152387
# step 90, loss=0.0963888
# step 100, loss=0.0884276
# [['adv', '1: probability: 0.92, label: saltshaker, salt shaker', '2: probability: 0.01, label: school bus', '3: probability: 0.00, label: thimble', '4: probability: 0.00, label: shopping cart', '5: probability: 0.00, label: candle, taper, wax light']]
# [['img_path', '1: probability: 0.91, label: school bus', '2: probability: 0.02, label: minibus', '3: probability: 0.02, label: moving van', '4: probability: 0.01, label: ambulance', '5: probability: 0.00, label: fire engine, fire truck']]
# step 10, loss=3.41281
# step 20, loss=1.99605
# step 30, loss=1.23324
# step 40, loss=0.907514
# step 50, loss=0.565134
# step 60, loss=0.333286
# step 70, loss=0.231625
# step 80, loss=0.188733
# step 90, loss=0.174507
# step 100, loss=0.148015
# [['adv', '1: probability: 0.86, label: saltshaker, salt shaker', '2: probability: 0.02, label: school bus', '3: probability: 0.01, label: gas pump, gasoline pump, petrol pump, island dispenser', '4: probability: 0.01, label: ambulance', '5: probability: 0.00, label: cab, hack, taxi, taxicab']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: cab, hack, taxi, taxicab', '3: probability: 0.00, label: lifeboat', '4: probability: 0.00, label: trolleybus, trolley coach, trackless trolley', '5: probability: 0.00, label: passenger car, coach, carriage']]
# step 10, loss=3.28186
# step 20, loss=2.12432
# step 30, loss=1.72391
# step 40, loss=1.42489
# step 50, loss=1.29757
# step 60, loss=1.14732
# step 70, loss=1.12503
# step 80, loss=1.02351
# step 90, loss=0.981129
# step 100, loss=0.932816
# [['adv', '1: probability: 0.40, label: saltshaker, salt shaker', '2: probability: 0.08, label: school bus', '3: probability: 0.04, label: cab, hack, taxi, taxicab', '4: probability: 0.02, label: minibus', '5: probability: 0.02, label: fire engine, fire truck']]
# [['img_path', '1: probability: 1.00, label: school bus', '2: probability: 0.00, label: crane', '3: probability: 0.00, label: cab, hack, taxi, taxicab', '4: probability: 0.00, label: trailer truck, tractor trailer, trucking rig, rig, articulated lorry, semi', '5: probability: 0.00, label: minibus']]
# step 10, loss=3.51306
# step 20, loss=1.7028
# step 30, loss=0.452903
# step 40, loss=0.265267
# step 50, loss=0.160978
# step 60, loss=0.136085
# step 70, loss=0.124569
# step 80, loss=0.10584
# step 90, loss=0.0983003
# step 100, loss=0.0912283
# [['adv', '1: probability: 0.91, label: saltshaker, salt shaker', '2: probability: 0.00, label: tow truck, tow car, wrecker', '3: probability: 0.00, label: cab, hack, taxi, taxicab', '4: probability: 0.00, label: school bus', '5: probability: 0.00, label: snowplow, snowplough']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: teddy, teddy bear', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: pencil box, pencil case', '5: probability: 0.00, label: packet']]
# step 10, loss=0.00835779
# step 20, loss=0.00467778
# step 30, loss=0.00337888
# step 40, loss=0.00266388
# step 50, loss=0.0022121
# step 60, loss=0.00190541
# step 70, loss=0.00167777
# step 80, loss=0.00150579
# step 90, loss=0.0013739
# step 100, loss=0.00126532
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: water bottle', '4: probability: 0.00, label: soap dispenser', '5: probability: 0.00, label: cocktail shaker']]
# [['img_path', '1: probability: 0.95, label: Christmas stocking', '2: probability: 0.04, label: sock', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: bib', '5: probability: 0.00, label: purse']]
# step 10, loss=0.00598057
# step 20, loss=0.00322275
# step 30, loss=0.00237136
# step 40, loss=0.0018928
# step 50, loss=0.00158732
# step 60, loss=0.00135116
# step 70, loss=0.0011765
# step 80, loss=0.00104647
# step 90, loss=0.000944883
# step 100, loss=0.000866038
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: vase', '4: probability: 0.00, label: eggnog', '5: probability: 0.00, label: pitcher, ewer']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: sock', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: teddy, teddy bear', '5: probability: 0.00, label: pillow']]
# step 10, loss=0.0383877
# step 20, loss=0.0200639
# step 30, loss=0.0143431
# step 40, loss=0.0115149
# step 50, loss=0.00974493
# step 60, loss=0.00851536
# step 70, loss=0.00760174
# step 80, loss=0.00688111
# step 90, loss=0.00630876
# step 100, loss=0.00583351
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: pill bottle', '4: probability: 0.00, label: vase', '5: probability: 0.00, label: lighter, light, igniter, ignitor']]
# [['img_path', '1: probability: 0.94, label: Christmas stocking', '2: probability: 0.01, label: pillow', '3: probability: 0.00, label: mailbag, postbag', '4: probability: 0.00, label: packet', '5: probability: 0.00, label: purse']]
# step 10, loss=0.0967837
# step 20, loss=0.0446455
# step 30, loss=0.031426
# step 40, loss=0.0246857
# step 50, loss=0.0205863
# step 60, loss=0.0176959
# step 70, loss=0.0157362
# step 80, loss=0.0142499
# step 90, loss=0.0130467
# step 100, loss=0.0120414
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: perfume, essence', '3: probability: 0.00, label: soap dispenser', '4: probability: 0.00, label: water bottle', '5: probability: 0.00, label: coffeepot']]
# [['img_path', '1: probability: 1.00, label: Christmas stocking', '2: probability: 0.00, label: apron', '3: probability: 0.00, label: sock', '4: probability: 0.00, label: flagpole, flagstaff', '5: probability: 0.00, label: brassiere, bra, bandeau']]
# step 10, loss=1.00083
# step 20, loss=0.0359429
# step 30, loss=0.0227314
# step 40, loss=0.0177699
# step 50, loss=0.0150443
# step 60, loss=0.0131158
# step 70, loss=0.0117557
# step 80, loss=0.0107097
# step 90, loss=0.00985672
# step 100, loss=0.00913984
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: coffeepot', '3: probability: 0.00, label: thimble', '4: probability: 0.00, label: soap dispenser', '5: probability: 0.00, label: pitcher, ewer']]
# [['img_path', '1: probability: 1.00, label: bullet train, bullet', '2: probability: 0.00, label: bobsled, bobsleigh, bob', '3: probability: 0.00, label: limousine, limo', '4: probability: 0.00, label: sports car, sport car', '5: probability: 0.00, label: streetcar, tram, tramcar, trolley, trolley car']]
# step 10, loss=0.0199849
# step 20, loss=0.0105646
# step 30, loss=0.00759109
# step 40, loss=0.00607821
# step 50, loss=0.00511658
# step 60, loss=0.00444377
# step 70, loss=0.00394258
# step 80, loss=0.00354365
# step 90, loss=0.00319554
# step 100, loss=0.00291804
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: piggy bank, penny bank', '4: probability: 0.00, label: thimble', '5: probability: 0.00, label: pitcher, ewer']]
# [['img_path', '1: probability: 0.98, label: bullet train, bullet', '2: probability: 0.00, label: limousine, limo', '3: probability: 0.00, label: bobsled, bobsleigh, bob', '4: probability: 0.00, label: solar dish, solar collector, solar furnace', '5: probability: 0.00, label: convertible']]
# step 10, loss=1.71041
# step 20, loss=0.127244
# step 30, loss=0.0773489
# step 40, loss=0.0579388
# step 50, loss=0.0471159
# step 60, loss=0.0396474
# step 70, loss=0.0339053
# step 80, loss=0.0297562
# step 90, loss=0.0265618
# step 100, loss=0.0241202
# [['adv', '1: probability: 0.98, label: saltshaker, salt shaker', '2: probability: 0.00, label: bullet train, bullet', '3: probability: 0.00, label: piggy bank, penny bank', '4: probability: 0.00, label: teapot', '5: probability: 0.00, label: tow truck, tow car, wrecker']]
# [['img_path', '1: probability: 0.91, label: bullet train, bullet', '2: probability: 0.00, label: speedboat', '3: probability: 0.00, label: aircraft carrier, carrier, flattop, attack aircraft carrier', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: warplane, military plane']]
# step 10, loss=2.85939
# step 20, loss=0.436905
# step 30, loss=0.135932
# step 40, loss=0.0885106
# step 50, loss=0.0694614
# step 60, loss=0.0576757
# step 70, loss=0.0498405
# step 80, loss=0.0443808
# step 90, loss=0.04022
# step 100, loss=0.0369322
# [['adv', '1: probability: 0.96, label: saltshaker, salt shaker', '2: probability: 0.00, label: bullet train, bullet', '3: probability: 0.00, label: cocktail shaker', '4: probability: 0.00, label: perfume, essence', '5: probability: 0.00, label: coffeepot']]
# [['img_path', '1: probability: 0.99, label: bullet train, bullet', '2: probability: 0.01, label: mouse, computer mouse', '3: probability: 0.00, label: passenger car, coach, carriage', '4: probability: 0.00, label: limousine, limo', '5: probability: 0.00, label: sports car, sport car']]
# step 10, loss=0.0309701
# step 20, loss=0.0135823
# step 30, loss=0.00925182
# step 40, loss=0.00712947
# step 50, loss=0.00589063
# step 60, loss=0.00507033
# step 70, loss=0.00447285
# step 80, loss=0.00401168
# step 90, loss=0.00364342
# step 100, loss=0.00333931
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: coffeepot', '4: probability: 0.00, label: pitcher, ewer', '5: probability: 0.00, label: water jug']]
# [['img_path', '1: probability: 0.88, label: bullet train, bullet', '2: probability: 0.04, label: warplane, military plane', '3: probability: 0.01, label: wing', '4: probability: 0.01, label: projectile, missile', '5: probability: 0.01, label: bobsled, bobsleigh, bob']]
# step 10, loss=0.0370825
# step 20, loss=0.0134794
# step 30, loss=0.00916677
# step 40, loss=0.00710319
# step 50, loss=0.00586088
# step 60, loss=0.00502099
# step 70, loss=0.00441992
# step 80, loss=0.00394578
# step 90, loss=0.00356301
# step 100, loss=0.00326042
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: pop bottle, soda bottle', '3: probability: 0.00, label: ocarina, sweet potato', '4: probability: 0.00, label: cocktail shaker', '5: probability: 0.00, label: fountain pen']]
# [['img_path', '1: probability: 0.99, label: weevil', '2: probability: 0.00, label: ground beetle, carabid beetle', '3: probability: 0.00, label: leaf beetle, chrysomelid', '4: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle', '5: probability: 0.00, label: dung beetle']]
# step 10, loss=0.784219
# step 20, loss=0.0464982
# step 30, loss=0.0283705
# step 40, loss=0.0220496
# step 50, loss=0.0181823
# step 60, loss=0.0158118
# step 70, loss=0.0140813
# step 80, loss=0.0126738
# step 90, loss=0.0116073
# step 100, loss=0.0107153
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: weevil', '4: probability: 0.00, label: wolf spider, hunting spider', '5: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle']]
# [['img_path', '1: probability: 0.98, label: weevil', '2: probability: 0.01, label: leaf beetle, chrysomelid', '3: probability: 0.00, label: ground beetle, carabid beetle', '4: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle', '5: probability: 0.00, label: dung beetle']]
# step 10, loss=1.12903
# step 20, loss=0.0123807
# step 30, loss=0.00744982
# step 40, loss=0.00556076
# step 50, loss=0.00453337
# step 60, loss=0.00385245
# step 70, loss=0.0033948
# step 80, loss=0.00304426
# step 90, loss=0.00275827
# step 100, loss=0.00252916
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: eggnog', '3: probability: 0.00, label: thimble', '4: probability: 0.00, label: weevil', '5: probability: 0.00, label: pop bottle, soda bottle']]
# [['img_path', '1: probability: 0.98, label: weevil', '2: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle', '3: probability: 0.00, label: ground beetle, carabid beetle', '4: probability: 0.00, label: leaf beetle, chrysomelid', '5: probability: 0.00, label: cricket']]
# step 10, loss=0.021061
# step 20, loss=0.00995693
# step 30, loss=0.00700399
# step 40, loss=0.00554322
# step 50, loss=0.00460694
# step 60, loss=0.00396727
# step 70, loss=0.00347986
# step 80, loss=0.0030994
# step 90, loss=0.00278918
# step 100, loss=0.00253475
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: weevil', '4: probability: 0.00, label: pop bottle, soda bottle', '5: probability: 0.00, label: perfume, essence']]
# [['img_path', '1: probability: 0.98, label: weevil', '2: probability: 0.00, label: broccoli', '3: probability: 0.00, label: leaf beetle, chrysomelid', '4: probability: 0.00, label: dung beetle', '5: probability: 0.00, label: leafhopper']]
# step 10, loss=0.585154
# step 20, loss=0.0197753
# step 30, loss=0.0124527
# step 40, loss=0.00950773
# step 50, loss=0.00783135
# step 60, loss=0.0066019
# step 70, loss=0.00570645
# step 80, loss=0.00509832
# step 90, loss=0.00463032
# step 100, loss=0.00423618
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: soap dispenser', '4: probability: 0.00, label: cup', '5: probability: 0.00, label: vase']]
# [['img_path', '1: probability: 0.98, label: weevil', '2: probability: 0.00, label: dung beetle', '3: probability: 0.00, label: ground beetle, carabid beetle', '4: probability: 0.00, label: leaf beetle, chrysomelid', '5: probability: 0.00, label: long-horned beetle, longicorn, longicorn beetle']]
# step 10, loss=0.0219474
# step 20, loss=0.005561
# step 30, loss=0.00371991
# step 40, loss=0.00289093
# step 50, loss=0.00238646
# step 60, loss=0.00203985
# step 70, loss=0.00178976
# step 80, loss=0.00159268
# step 90, loss=0.00144282
# step 100, loss=0.00132354
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: pitcher, ewer', '4: probability: 0.00, label: pop bottle, soda bottle', '5: probability: 0.00, label: vase']]

# %%
# Run across each dir and get the similar images predicitons
for advi in [5, 342, 773]:
    demo_target = advi # "guacamole"
    for file in sorted(listdir("/home/w266ajh/Documents/top5gen/data_imageparts/")):
        if not file.endswith('.jpg'): continue

        # Get image and write out the results
    #     img_path, _ = urlretrieve("file:///home/w266ajh/Documents/top5gen/data_imageparts_1/" + file) #urlretrieve('http://www.anishathalye.com/media/2017/07/25/cat.jpg')
    #     img_class = 281
        img = PIL.Image.open("/home/w266ajh/Documents/top5gen/data_imageparts/" + file)
        big_dim = max(img.width, img.height)
        wide = img.width > img.height
        new_w = 224 if not wide else int(img.width * 224 / img.height)
        new_h = 224 if wide else int(img.height * 224 / img.width)
        img = img.resize((new_w, new_h)).crop((0, 0, 224, 224))
        img = (np.asarray(img) / 255.0).astype(np.float32)
        with open("adv_input", "w") as out:
            out.write(str(img))

        print(get_top_five("", img))
        with open("predictions_" + str(advi) + ".csv", 'a+') as f:
            for val in get_top_five("/home/w266ajh/Documents/top5gen/data_imageparts/" + file, img)[0]:
                f.write(val + ';')
            f.write('\n')

        # Generate the adversarial ###
        x = tf.placeholder(tf.float32, (224, 224, 3))

        x_hat = image # our trainable adversarial input
        assign_op = tf.assign(x_hat, x)

        learning_rate = tf.placeholder(tf.float32, ())
        y_hat = tf.placeholder(tf.int32, ())

        labels = tf.one_hot(y_hat, 1000)
        loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=[labels])
        optim_step = tf.train.GradientDescentOptimizer(
            learning_rate).minimize(loss, var_list=[x_hat])

        epsilon = tf.placeholder(tf.float32, ())

        below = x - epsilon
        above = x + epsilon
        projected = tf.clip_by_value(tf.clip_by_value(x_hat, below, above), 0, 1)
        with tf.control_dependencies([projected]):
            project_step = tf.assign(x_hat, projected)

        demo_epsilon = 2.0/255.0 # a really small perturbation
        demo_lr = 1e-1
        demo_steps = 100

        # initialization step
        sess.run(assign_op, feed_dict={x: img})

        # projected gradient descent
        for i in range(demo_steps):
            # gradient descent step
            _, loss_value = sess.run(
                [optim_step, loss],
                feed_dict={learning_rate: demo_lr, y_hat: demo_target})
            # project step
            sess.run(project_step, feed_dict={x: img, epsilon: demo_epsilon})
            if (i+1) % 10 == 0:
                print('step %d, loss=%g' % (i+1, loss_value))


        adv = x_hat.eval() # retrieve the adversarial example
        from skimage.io import imsave
        imsave("adv.png", adv, plugin='pil', format_str='png')
        # with open("adv_output.txt", 'w') as out:
        #     out.write(str(a) for a in adv)
        np.set_printoptions(threshold=np.nan)
        with open("adv_output.txt", "w") as out:
            out.write(str(adv))

        ###

        # Get the adv prediction
        print(get_top_five("adv", adv))

        with open("predictions_" + str(advi) + ".csv", 'a+') as f:
            for val in get_top_five("adv", adv)[0]:
                f.write(val + ';')
            f.write('\n')
# Out:
# [['', '1: probability: 0.97, label: barn', '2: probability: 0.03, label: boathouse', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: church, church building', '5: probability: 0.00, label: lumbermill, sawmill']]
# step 10, loss=5.66951
# step 20, loss=3.52408
# step 30, loss=1.21077
# step 40, loss=0.421323
# step 50, loss=0.285439
# step 60, loss=0.23289
# step 70, loss=0.20112
# step 80, loss=0.183152
# step 90, loss=0.170336
# step 100, loss=0.160117
# /home/w266ajh/.local/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float32 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# [['adv', '1: probability: 0.85, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.04, label: stingray', '3: probability: 0.01, label: boathouse', '4: probability: 0.01, label: barn', '5: probability: 0.00, label: snail']]
# [['', '1: probability: 0.98, label: barn', '2: probability: 0.01, label: boathouse', '3: probability: 0.00, label: church, church building', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: solar dish, solar collector, solar furnace']]
# step 10, loss=2.403
# step 20, loss=0.103727
# step 30, loss=0.054339
# step 40, loss=0.0412311
# step 50, loss=0.0338264
# step 60, loss=0.0293768
# step 70, loss=0.026533
# step 80, loss=0.0240503
# step 90, loss=0.0221912
# step 100, loss=0.0206803
# [['adv', '1: probability: 0.98, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: barn', '4: probability: 0.00, label: tiger shark, Galeocerdo cuvieri', '5: probability: 0.00, label: broom']]
# [['', '1: probability: 0.97, label: barn', '2: probability: 0.02, label: boathouse', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: church, church building']]
# step 10, loss=0.872921
# step 20, loss=0.0433776
# step 30, loss=0.026627
# step 40, loss=0.0201252
# step 50, loss=0.0163831
# step 60, loss=0.0138971
# step 70, loss=0.0121059
# step 80, loss=0.0107492
# step 90, loss=0.00964883
# step 100, loss=0.00875752
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: barn', '5: probability: 0.00, label: monastery']]
# [['', '1: probability: 0.99, label: barn', '2: probability: 0.00, label: boathouse', '3: probability: 0.00, label: greenhouse, nursery, glasshouse', '4: probability: 0.00, label: lumbermill, sawmill', '5: probability: 0.00, label: worm fence, snake fence, snake-rail fence, Virginia fence']]
# step 10, loss=0.437344
# step 20, loss=0.101091
# step 30, loss=0.0624211
# step 40, loss=0.0469263
# step 50, loss=0.0380219
# step 60, loss=0.0321007
# step 70, loss=0.028038
# step 80, loss=0.0250233
# step 90, loss=0.0227334
# step 100, loss=0.0209946
# [['adv', '1: probability: 0.98, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: barn', '4: probability: 0.00, label: viaduct', '5: probability: 0.00, label: lumbermill, sawmill']]
# [['', '1: probability: 0.97, label: barn', '2: probability: 0.01, label: church, church building', '3: probability: 0.00, label: boathouse', '4: probability: 0.00, label: worm fence, snake fence, snake-rail fence, Virginia fence', '5: probability: 0.00, label: thatch, thatched roof']]
# step 10, loss=0.0319087
# step 20, loss=0.0156399
# step 30, loss=0.0111845
# step 40, loss=0.0090314
# step 50, loss=0.00771779
# step 60, loss=0.00677041
# step 70, loss=0.00606778
# step 80, loss=0.00551263
# step 90, loss=0.00507566
# step 100, loss=0.00471789
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: submarine, pigboat, sub, U-boat', '4: probability: 0.00, label: quail', '5: probability: 0.00, label: planetarium']]
# [['', '1: probability: 0.98, label: dam, dike, dyke', '2: probability: 0.01, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: dock, dockage, docking facility', '5: probability: 0.00, label: container ship, containership, container vessel']]
# step 10, loss=2.34488
# step 20, loss=0.194543
# step 30, loss=0.106497
# step 40, loss=0.0778008
# step 50, loss=0.0612977
# step 60, loss=0.0504928
# step 70, loss=0.0431873
# step 80, loss=0.038259
# step 90, loss=0.0346118
# step 100, loss=0.0316125
# [['adv', '1: probability: 0.97, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: tiger shark, Galeocerdo cuvieri', '4: probability: 0.00, label: dam, dike, dyke', '5: probability: 0.00, label: plow, plough']]
# [['', '1: probability: 0.99, label: dam, dike, dyke', '2: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: barn']]
# step 10, loss=4.39574
# step 20, loss=0.131935
# step 30, loss=0.0238472
# step 40, loss=0.0169576
# step 50, loss=0.0137107
# step 60, loss=0.0116536
# step 70, loss=0.0102006
# step 80, loss=0.00914799
# step 90, loss=0.00836192
# step 100, loss=0.0077424
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: ringlet, ringlet butterfly', '4: probability: 0.00, label: barracouta, snoek', '5: probability: 0.00, label: sturgeon']]
# [['', '1: probability: 1.00, label: dam, dike, dyke', '2: probability: 0.00, label: suspension bridge', '3: probability: 0.00, label: viaduct', '4: probability: 0.00, label: pier', '5: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty']]
# step 10, loss=0.00750744
# step 20, loss=0.00340371
# step 30, loss=0.00238016
# step 40, loss=0.00188483
# step 50, loss=0.00158935
# step 60, loss=0.00138366
# step 70, loss=0.00122198
# step 80, loss=0.0010947
# step 90, loss=0.000989186
# step 100, loss=0.000904747
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: jackfruit, jak, jack', '5: probability: 0.00, label: triceratops']]
# [['', '1: probability: 0.96, label: dam, dike, dyke', '2: probability: 0.03, label: wreck', '3: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '4: probability: 0.00, label: cliff, drop, drop-off', '5: probability: 0.00, label: park bench']]
# step 10, loss=0.035936
# step 20, loss=0.0191777
# step 30, loss=0.0136618
# step 40, loss=0.0107664
# step 50, loss=0.00888785
# step 60, loss=0.00760162
# step 70, loss=0.0066745
# step 80, loss=0.00595948
# step 90, loss=0.00539786
# step 100, loss=0.00493487
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: eel', '4: probability: 0.00, label: loggerhead, loggerhead turtle, Caretta caretta', '5: probability: 0.00, label: leatherback turtle, leatherback, leathery turtle, Dermochelys coriacea']]
# [['', '1: probability: 0.97, label: dam, dike, dyke', '2: probability: 0.01, label: fountain', '3: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '4: probability: 0.00, label: fireboat', '5: probability: 0.00, label: castle']]
# step 10, loss=0.0130546
# step 20, loss=0.00646689
# step 30, loss=0.00459638
# step 40, loss=0.00365447
# step 50, loss=0.00305329
# step 60, loss=0.00265199
# step 70, loss=0.00236743
# step 80, loss=0.00214799
# step 90, loss=0.00196871
# step 100, loss=0.00181962
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: sturgeon', '5: probability: 0.00, label: palace']]
# [['', '1: probability: 0.85, label: refrigerator, icebox', '2: probability: 0.04, label: medicine chest, medicine cabinet', '3: probability: 0.01, label: grocery store, grocery, food market, market', '4: probability: 0.01, label: tobacco shop, tobacconist shop, tobacconist', '5: probability: 0.01, label: bakery, bakeshop, bakehouse']]
# step 10, loss=4.4693
# step 20, loss=0.285187
# step 30, loss=0.117383
# step 40, loss=0.0830119
# step 50, loss=0.063934
# step 60, loss=0.0536366
# step 70, loss=0.0471323
# step 80, loss=0.0421361
# step 90, loss=0.0382959
# step 100, loss=0.0353233
# [['adv', '1: probability: 0.97, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: submarine, pigboat, sub, U-boat', '4: probability: 0.00, label: hammerhead, hammerhead shark', '5: probability: 0.00, label: tiger shark, Galeocerdo cuvieri']]
# [['', '1: probability: 0.94, label: refrigerator, icebox', '2: probability: 0.03, label: bakery, bakeshop, bakehouse', '3: probability: 0.00, label: shopping basket', '4: probability: 0.00, label: shopping cart', '5: probability: 0.00, label: dishwasher, dish washer, dishwashing machine']]
# step 10, loss=0.01941
# step 20, loss=0.00972368
# step 30, loss=0.00685684
# step 40, loss=0.00536004
# step 50, loss=0.00443736
# step 60, loss=0.00380115
# step 70, loss=0.00332755
# step 80, loss=0.00295441
# step 90, loss=0.00266304
# step 100, loss=0.00243118
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: jackfruit, jak, jack', '4: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '5: probability: 0.00, label: snail']]
# [['', '1: probability: 0.92, label: refrigerator, icebox', '2: probability: 0.05, label: washer, automatic washer, washing machine', '3: probability: 0.01, label: safe', '4: probability: 0.00, label: photocopier', '5: probability: 0.00, label: dishwasher, dish washer, dishwashing machine']]
# step 10, loss=1.90054
# step 20, loss=0.0579397
# step 30, loss=0.0348505
# step 40, loss=0.0265588
# step 50, loss=0.0217521
# step 60, loss=0.0189774
# step 70, loss=0.0170904
# step 80, loss=0.0156288
# step 90, loss=0.0145283
# step 100, loss=0.0136472
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: safe', '4: probability: 0.00, label: refrigerator, icebox', '5: probability: 0.00, label: dugong, Dugong dugon']]
# [['', '1: probability: 1.00, label: refrigerator, icebox', '2: probability: 0.00, label: vending machine', '3: probability: 0.00, label: medicine chest, medicine cabinet', '4: probability: 0.00, label: bakery, bakeshop, bakehouse', '5: probability: 0.00, label: confectionery, confectionary, candy store']]
# step 10, loss=4.70201
# step 20, loss=2.69537
# step 30, loss=0.842008
# step 40, loss=0.407268
# step 50, loss=0.171599
# step 60, loss=0.125612
# step 70, loss=0.101377
# step 80, loss=0.0881827
# step 90, loss=0.0790839
# step 100, loss=0.0720841
# [['adv', '1: probability: 0.93, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: slot, one-armed bandit', '4: probability: 0.00, label: refrigerator, icebox', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# [['', '1: probability: 0.92, label: refrigerator, icebox', '2: probability: 0.01, label: vending machine', '3: probability: 0.01, label: toyshop', '4: probability: 0.01, label: confectionery, confectionary, candy store', '5: probability: 0.00, label: grocery store, grocery, food market, market']]
# step 10, loss=4.81845
# step 20, loss=3.4325
# step 30, loss=2.39505
# step 40, loss=1.84342
# step 50, loss=1.31092
# step 60, loss=0.405175
# step 70, loss=0.211295
# step 80, loss=0.147833
# step 90, loss=0.126865
# step 100, loss=0.11742
# [['adv', '1: probability: 0.89, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: rotisserie', '4: probability: 0.00, label: oscilloscope, scope, cathode-ray oscilloscope, CRO', '5: probability: 0.00, label: sturgeon']]
# [['', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: parking meter', '4: probability: 0.00, label: vending machine', '5: probability: 0.00, label: golfcart, golf cart']]
# step 10, loss=3.79183
# step 20, loss=1.63663
# step 30, loss=0.199547
# step 40, loss=0.120481
# step 50, loss=0.0941989
# step 60, loss=0.0799114
# step 70, loss=0.0713395
# step 80, loss=0.0652704
# step 90, loss=0.0597606
# step 100, loss=0.0556173
# [['adv', '1: probability: 0.95, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.02, label: stingray', '3: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '4: probability: 0.00, label: pick, plectrum, plectron', '5: probability: 0.00, label: pay-phone, pay-station']]
# [['', '1: probability: 0.87, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.05, label: pay-phone, pay-station', '3: probability: 0.05, label: vending machine', '4: probability: 0.00, label: parking meter', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# step 10, loss=3.99444
# step 20, loss=2.88875
# step 30, loss=2.24506
# step 40, loss=1.45161
# step 50, loss=1.11396
# step 60, loss=0.958468
# step 70, loss=0.968336
# step 80, loss=0.698969
# step 90, loss=0.718846
# step 100, loss=0.625113
# [['adv', '1: probability: 0.56, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.04, label: gas pump, gasoline pump, petrol pump, island dispenser', '3: probability: 0.03, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '4: probability: 0.02, label: stingray', '5: probability: 0.02, label: vending machine']]
# [['', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: vending machine', '3: probability: 0.00, label: mailbox, letter box', '4: probability: 0.00, label: scale, weighing machine', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# step 10, loss=4.13977
# step 20, loss=2.61881
# step 30, loss=2.6503
# step 40, loss=0.563255
# step 50, loss=0.344234
# step 60, loss=0.0940984
# step 70, loss=0.064593
# step 80, loss=0.052986
# step 90, loss=0.0447259
# step 100, loss=0.0412997
# [['adv', '1: probability: 0.96, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: gas pump, gasoline pump, petrol pump, island dispenser', '3: probability: 0.00, label: stingray', '4: probability: 0.00, label: safe', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# [['', '1: probability: 1.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.00, label: mailbox, letter box', '3: probability: 0.00, label: ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', '4: probability: 0.00, label: vending machine', '5: probability: 0.00, label: golfcart, golf cart']]
# step 10, loss=4.24913
# step 20, loss=0.281543
# step 30, loss=0.0377997
# step 40, loss=0.0246095
# step 50, loss=0.0192357
# step 60, loss=0.0159588
# step 70, loss=0.0138735
# step 80, loss=0.012245
# step 90, loss=0.0111459
# step 100, loss=0.0102057
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: gas pump, gasoline pump, petrol pump, island dispenser', '4: probability: 0.00, label: sturgeon', '5: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM']]
# [['', '1: probability: 0.93, label: gas pump, gasoline pump, petrol pump, island dispenser', '2: probability: 0.02, label: ashcan, trash can, garbage can, wastebin, ash bin, ash-bin, ashbin, dustbin, trash barrel, trash bin', '3: probability: 0.02, label: vending machine', '4: probability: 0.01, label: mailbox, letter box', '5: probability: 0.00, label: parking meter']]
# step 10, loss=1.94671
# step 20, loss=0.16784
# step 30, loss=0.0939942
# step 40, loss=0.0722299
# step 50, loss=0.060493
# step 60, loss=0.0529362
# step 70, loss=0.0478518
# step 80, loss=0.0433969
# step 90, loss=0.0403525
# step 100, loss=0.0373834
# [['adv', '1: probability: 0.96, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: cash machine, cash dispenser, automated teller machine, automatic teller machine, automated teller, automatic teller, ATM', '4: probability: 0.00, label: oscilloscope, scope, cathode-ray oscilloscope, CRO', '5: probability: 0.00, label: safe']]
# [['', '1: probability: 1.00, label: mashed potato', '2: probability: 0.00, label: meat loaf, meatloaf', '3: probability: 0.00, label: cauliflower', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: red wolf, maned wolf, Canis rufus, Canis niger']]
# step 10, loss=0.0188879
# step 20, loss=0.0110044
# step 30, loss=0.00823554
# step 40, loss=0.00673489
# step 50, loss=0.00573478
# step 60, loss=0.00503071
# step 70, loss=0.00448958
# step 80, loss=0.00406618
# step 90, loss=0.00371552
# step 100, loss=0.0034283
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: brain coral', '5: probability: 0.00, label: tick']]
# [['', '1: probability: 0.99, label: mashed potato', '2: probability: 0.01, label: cauliflower', '3: probability: 0.00, label: red wolf, maned wolf, Canis rufus, Canis niger', '4: probability: 0.00, label: meat loaf, meatloaf', '5: probability: 0.00, label: ice cream, icecream']]
# step 10, loss=0.0109109
# step 20, loss=0.00558424
# step 30, loss=0.00410441
# step 40, loss=0.00333218
# step 50, loss=0.0028485
# step 60, loss=0.00251144
# step 70, loss=0.0022548
# step 80, loss=0.00205532
# step 90, loss=0.00189137
# step 100, loss=0.00175596
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa', '5: probability: 0.00, label: mushroom']]
# [['', '1: probability: 0.99, label: mashed potato', '2: probability: 0.01, label: cauliflower', '3: probability: 0.00, label: red wolf, maned wolf, Canis rufus, Canis niger', '4: probability: 0.00, label: meat loaf, meatloaf', '5: probability: 0.00, label: ice cream, icecream']]
# step 10, loss=0.0109109
# step 20, loss=0.00558424
# step 30, loss=0.00410441
# step 40, loss=0.00333218
# step 50, loss=0.0028485
# step 60, loss=0.00251144
# step 70, loss=0.0022548
# step 80, loss=0.00205532
# step 90, loss=0.00189137
# step 100, loss=0.00175596
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa', '5: probability: 0.00, label: mushroom']]
# [['', '1: probability: 0.99, label: mashed potato', '2: probability: 0.01, label: cauliflower', '3: probability: 0.00, label: dough', '4: probability: 0.00, label: ice cream, icecream', '5: probability: 0.00, label: red wolf, maned wolf, Canis rufus, Canis niger']]
# step 10, loss=0.0123152
# step 20, loss=0.00565477
# step 30, loss=0.00398686
# step 40, loss=0.00314171
# step 50, loss=0.00261834
# step 60, loss=0.00226872
# step 70, loss=0.00200488
# step 80, loss=0.00180475
# step 90, loss=0.00164707
# step 100, loss=0.00151841
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: jellyfish', '4: probability: 0.00, label: sturgeon', '5: probability: 0.00, label: puffer, pufferfish, blowfish, globefish']]
# [['', '1: probability: 0.96, label: mashed potato', '2: probability: 0.01, label: ice cream, icecream', '3: probability: 0.01, label: cauliflower', '4: probability: 0.00, label: dough', '5: probability: 0.00, label: meat loaf, meatloaf']]
# step 10, loss=0.0139811
# step 20, loss=0.00802436
# step 30, loss=0.00599029
# step 40, loss=0.00490142
# step 50, loss=0.00421433
# step 60, loss=0.00372633
# step 70, loss=0.00334371
# step 80, loss=0.00303879
# step 90, loss=0.00279168
# step 100, loss=0.00258588
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: starfish, sea star', '5: probability: 0.00, label: sea slug, nudibranch']]
# [['', '1: probability: 0.46, label: steel arch bridge', '2: probability: 0.34, label: pier', '3: probability: 0.04, label: suspension bridge', '4: probability: 0.03, label: greenhouse, nursery, glasshouse', '5: probability: 0.02, label: crane']]
# step 10, loss=0.00791993
# step 20, loss=0.00427487
# step 30, loss=0.00311331
# step 40, loss=0.0025225
# step 50, loss=0.00215263
# step 60, loss=0.0018884
# step 70, loss=0.00170479
# step 80, loss=0.00155388
# step 90, loss=0.00142223
# step 100, loss=0.00131556
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: dugong, Dugong dugon', '5: probability: 0.00, label: jellyfish']]
# [['', '1: probability: 0.54, label: pier', '2: probability: 0.29, label: viaduct', '3: probability: 0.05, label: steel arch bridge', '4: probability: 0.02, label: suspension bridge', '5: probability: 0.01, label: crane']]
# step 10, loss=1.33641
# step 20, loss=0.32343
# step 30, loss=0.0603554
# step 40, loss=0.0438648
# step 50, loss=0.0374707
# step 60, loss=0.0322754
# step 70, loss=0.0286731
# step 80, loss=0.0262829
# step 90, loss=0.0239878
# step 100, loss=0.0222995
# [['adv', '1: probability: 0.98, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: jellyfish', '4: probability: 0.00, label: dugong, Dugong dugon', '5: probability: 0.00, label: bubble']]
# [['', '1: probability: 0.16, label: pier', '2: probability: 0.05, label: sandbar, sand bar', '3: probability: 0.03, label: bell cote, bell cot', '4: probability: 0.02, label: wreck', '5: probability: 0.02, label: patio, terrace']]
# step 10, loss=0.00595604
# step 20, loss=0.00353165
# step 30, loss=0.00264557
# step 40, loss=0.00215548
# step 50, loss=0.00183426
# step 60, loss=0.00161505
# step 70, loss=0.00145449
# step 80, loss=0.00132806
# step 90, loss=0.00123008
# step 100, loss=0.00114637
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: dugong, Dugong dugon', '4: probability: 0.00, label: sturgeon', '5: probability: 0.00, label: gong, tam-tam']]
# [['', '1: probability: 0.88, label: pier', '2: probability: 0.07, label: steel arch bridge', '3: probability: 0.04, label: suspension bridge', '4: probability: 0.00, label: crane', '5: probability: 0.00, label: viaduct']]
# step 10, loss=2.74444
# step 20, loss=0.0663703
# step 30, loss=0.0361234
# step 40, loss=0.0273482
# step 50, loss=0.0228491
# step 60, loss=0.0199572
# step 70, loss=0.0178655
# step 80, loss=0.0163291
# step 90, loss=0.0150575
# step 100, loss=0.0139848
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: sturgeon', '4: probability: 0.00, label: pier', '5: probability: 0.00, label: dugong, Dugong dugon']]
# [['', '1: probability: 0.96, label: pier', '2: probability: 0.01, label: steel arch bridge', '3: probability: 0.00, label: crane', '4: probability: 0.00, label: dock, dockage, docking facility', '5: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty']]
# step 10, loss=0.0123585
# step 20, loss=0.00604349
# step 30, loss=0.00435369
# step 40, loss=0.00347012
# step 50, loss=0.00292326
# step 60, loss=0.00253832
# step 70, loss=0.00225016
# step 80, loss=0.0020251
# step 90, loss=0.0018408
# step 100, loss=0.0016886
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: sturgeon', '4: probability: 0.00, label: jellyfish', '5: probability: 0.00, label: dugong, Dugong dugon']]
# [['', '1: probability: 1.00, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: projector', '3: probability: 0.00, label: reflex camera', '4: probability: 0.00, label: joystick', '5: probability: 0.00, label: CD player']]
# step 10, loss=3.67826
# step 20, loss=2.38641
# step 30, loss=1.04755
# step 40, loss=0.499904
# step 50, loss=0.00458736
# step 60, loss=0.00305852
# step 70, loss=0.00241703
# step 80, loss=0.00203688
# step 90, loss=0.00178797
# step 100, loss=0.00161077
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: jellyfish', '5: probability: 0.00, label: pick, plectrum, plectron']]
# [['', '1: probability: 0.98, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: tape player', '3: probability: 0.00, label: cassette player', '4: probability: 0.00, label: radio, wireless', '5: probability: 0.00, label: reflex camera']]
# step 10, loss=0.197856
# step 20, loss=0.0190812
# step 30, loss=0.0125927
# step 40, loss=0.00987797
# step 50, loss=0.00823483
# step 60, loss=0.00718403
# step 70, loss=0.00641371
# step 80, loss=0.00580921
# step 90, loss=0.00532305
# step 100, loss=0.00492562
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: sturgeon', '4: probability: 0.00, label: waffle iron', '5: probability: 0.00, label: dugong, Dugong dugon']]
# [['', '1: probability: 0.83, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.15, label: projector', '3: probability: 0.00, label: loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', '4: probability: 0.00, label: CD player', '5: probability: 0.00, label: tape player']]
# step 10, loss=2.00754
# step 20, loss=0.0108072
# step 30, loss=0.00686844
# step 40, loss=0.00559882
# step 50, loss=0.00485551
# step 60, loss=0.0042998
# step 70, loss=0.00388213
# step 80, loss=0.00354887
# step 90, loss=0.00327907
# step 100, loss=0.00305448
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: rock beauty, Holocanthus tricolor', '5: probability: 0.00, label: CD player']]
# [['', '1: probability: 0.99, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: reflex camera', '3: probability: 0.00, label: projector', '4: probability: 0.00, label: lens cap, lens cover', '5: probability: 0.00, label: iPod']]
# step 10, loss=4.31716
# step 20, loss=2.92913
# step 30, loss=1.95716
# step 40, loss=1.17545
# step 50, loss=0.298247
# step 60, loss=0.0894138
# step 70, loss=0.0636779
# step 80, loss=0.0508132
# step 90, loss=0.044909
# step 100, loss=0.0388045
# [['adv', '1: probability: 0.96, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.01, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: rock beauty, Holocanthus tricolor', '5: probability: 0.00, label: gong, tam-tam']]
# [['', '1: probability: 0.96, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.01, label: reflex camera', '3: probability: 0.00, label: projector', '4: probability: 0.00, label: espresso maker', '5: probability: 0.00, label: radio, wireless']]
# step 10, loss=3.66739
# step 20, loss=2.48824
# step 30, loss=1.77228
# step 40, loss=0.452718
# step 50, loss=0.18994
# step 60, loss=0.130172
# step 70, loss=0.106382
# step 80, loss=0.0951196
# step 90, loss=0.0831519
# step 100, loss=0.0757098
# [['adv', '1: probability: 0.93, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: safe', '3: probability: 0.00, label: radio, wireless', '4: probability: 0.00, label: stingray', '5: probability: 0.00, label: waffle iron']]
# [['', '1: probability: 0.99, label: pencil sharpener', '2: probability: 0.00, label: rubber eraser, rubber, pencil eraser', '3: probability: 0.00, label: switch, electric switch, electrical switch', '4: probability: 0.00, label: lighter, light, igniter, ignitor', '5: probability: 0.00, label: Polaroid camera, Polaroid Land camera']]
# step 10, loss=0.0174485
# step 20, loss=0.0093835
# step 30, loss=0.00699026
# step 40, loss=0.00576322
# step 50, loss=0.00495171
# step 60, loss=0.00435096
# step 70, loss=0.00387905
# step 80, loss=0.00351882
# step 90, loss=0.00322394
# step 100, loss=0.00298876
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: ringlet, ringlet butterfly', '4: probability: 0.00, label: pick, plectrum, plectron', '5: probability: 0.00, label: puffer, pufferfish, blowfish, globefish']]
# [['', '1: probability: 1.00, label: pencil sharpener', '2: probability: 0.00, label: washbasin, handbasin, washbowl, lavabo, wash-hand basin', '3: probability: 0.00, label: lighter, light, igniter, ignitor', '4: probability: 0.00, label: switch, electric switch, electrical switch', '5: probability: 0.00, label: combination lock']]
# step 10, loss=0.0913255
# step 20, loss=0.0273962
# step 30, loss=0.0188952
# step 40, loss=0.0149631
# step 50, loss=0.0126646
# step 60, loss=0.011102
# step 70, loss=0.00987856
# step 80, loss=0.00894114
# step 90, loss=0.00822762
# step 100, loss=0.00766148
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: broom', '4: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '5: probability: 0.00, label: tiger shark, Galeocerdo cuvieri']]
# [['', '1: probability: 0.93, label: pencil sharpener', '2: probability: 0.01, label: whistle', "3: probability: 0.00, label: plane, carpenter's plane, woodworking plane", '4: probability: 0.00, label: lighter, light, igniter, ignitor', '5: probability: 0.00, label: holster']]
# step 10, loss=0.204486
# step 20, loss=0.0753233
# step 30, loss=0.0503818
# step 40, loss=0.0389534
# step 50, loss=0.0324994
# step 60, loss=0.0279064
# step 70, loss=0.0243976
# step 80, loss=0.0218342
# step 90, loss=0.019733
# step 100, loss=0.0178719
# [['adv', '1: probability: 0.98, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: mitten', '4: probability: 0.00, label: sandal', '5: probability: 0.00, label: pick, plectrum, plectron']]
# [['', '1: probability: 1.00, label: pencil sharpener', '2: probability: 0.00, label: cassette', '3: probability: 0.00, label: mousetrap', '4: probability: 0.00, label: rubber eraser, rubber, pencil eraser', '5: probability: 0.00, label: switch, electric switch, electrical switch']]
# step 10, loss=2.67184
# step 20, loss=0.0873996
# step 30, loss=0.0369589
# step 40, loss=0.0267352
# step 50, loss=0.021775
# step 60, loss=0.0188394
# step 70, loss=0.0167315
# step 80, loss=0.0150825
# step 90, loss=0.0138224
# step 100, loss=0.0127829
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: tiger shark, Galeocerdo cuvieri', '5: probability: 0.00, label: rock beauty, Holocanthus tricolor']]
# [['', '1: probability: 0.95, label: pencil sharpener', '2: probability: 0.01, label: rubber eraser, rubber, pencil eraser', '3: probability: 0.01, label: lighter, light, igniter, ignitor', '4: probability: 0.00, label: switch, electric switch, electrical switch', '5: probability: 0.00, label: pencil box, pencil case']]
# step 10, loss=2.88914
# step 20, loss=0.028738
# step 30, loss=0.0140424
# step 40, loss=0.0102404
# step 50, loss=0.00841749
# step 60, loss=0.00727161
# step 70, loss=0.00642816
# step 80, loss=0.00571178
# step 90, loss=0.00514493
# step 100, loss=0.00475289
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: conch', '4: probability: 0.00, label: tiger shark, Galeocerdo cuvieri', '5: probability: 0.00, label: hammerhead, hammerhead shark']]
# [['', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '4: probability: 0.00, label: reflex camera', '5: probability: 0.00, label: joystick']]
# step 10, loss=4.63937
# step 20, loss=2.78959
# step 30, loss=1.61471
# step 40, loss=0.00827137
# step 50, loss=0.00528451
# step 60, loss=0.00417029
# step 70, loss=0.00355208
# step 80, loss=0.00312685
# step 90, loss=0.00280511
# step 100, loss=0.00255045
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: dial telephone, dial phone', '4: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '5: probability: 0.00, label: projector']]
# [['', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: hard disc, hard disk, fixed disk', '4: probability: 0.00, label: iron, smoothing iron', '5: probability: 0.00, label: magnetic compass']]
# step 10, loss=0.0792733
# step 20, loss=0.0230033
# step 30, loss=0.0159698
# step 40, loss=0.0126817
# step 50, loss=0.0106634
# step 60, loss=0.00929268
# step 70, loss=0.00828106
# step 80, loss=0.00748366
# step 90, loss=0.00685222
# step 100, loss=0.00634252
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: gong, tam-tam', '4: probability: 0.00, label: toilet seat', '5: probability: 0.00, label: dial telephone, dial phone']]
# [['', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: iron, smoothing iron', '4: probability: 0.00, label: iPod', '5: probability: 0.00, label: hard disc, hard disk, fixed disk']]
# step 10, loss=2.33434
# step 20, loss=0.0571276
# step 30, loss=0.0325447
# step 40, loss=0.0242768
# step 50, loss=0.0198911
# step 60, loss=0.0171006
# step 70, loss=0.0151791
# step 80, loss=0.0137067
# step 90, loss=0.0125624
# step 100, loss=0.0116776
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: gong, tam-tam', '4: probability: 0.00, label: dial telephone, dial phone', '5: probability: 0.00, label: maze, labyrinth']]
# [['', '1: probability: 0.84, label: dial telephone, dial phone', '2: probability: 0.02, label: vacuum, vacuum cleaner', '3: probability: 0.01, label: hand blower, blow dryer, blow drier, hair dryer, hair drier', '4: probability: 0.01, label: reflex camera', '5: probability: 0.01, label: Polaroid camera, Polaroid Land camera']]
# step 10, loss=2.43751
# step 20, loss=0.0217577
# step 30, loss=0.0104381
# step 40, loss=0.00734545
# step 50, loss=0.0057599
# step 60, loss=0.00490759
# step 70, loss=0.00432449
# step 80, loss=0.00382288
# step 90, loss=0.00339682
# step 100, loss=0.00306731
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '4: probability: 0.00, label: projector', '5: probability: 0.00, label: dugong, Dugong dugon']]
# [['', '1: probability: 0.99, label: dial telephone, dial phone', '2: probability: 0.00, label: vacuum, vacuum cleaner', '3: probability: 0.00, label: iron, smoothing iron', '4: probability: 0.00, label: oxygen mask', '5: probability: 0.00, label: pay-phone, pay-station']]
# step 10, loss=0.0730066
# step 20, loss=0.0382149
# step 30, loss=0.0269515
# step 40, loss=0.0212188
# step 50, loss=0.0175744
# step 60, loss=0.0150675
# step 70, loss=0.0132883
# step 80, loss=0.011972
# step 90, loss=0.0109408
# step 100, loss=0.0101343
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: dugong, Dugong dugon', '4: probability: 0.00, label: sturgeon', '5: probability: 0.00, label: tiger shark, Galeocerdo cuvieri']]
# [['', '1: probability: 0.91, label: water tower', '2: probability: 0.01, label: mushroom', '3: probability: 0.01, label: golf ball', '4: probability: 0.00, label: ping-pong ball', '5: probability: 0.00, label: mosque']]
# step 10, loss=1.81994
# step 20, loss=0.015436
# step 30, loss=0.00899501
# step 40, loss=0.00672174
# step 50, loss=0.00546995
# step 60, loss=0.00469439
# step 70, loss=0.00413693
# step 80, loss=0.00371884
# step 90, loss=0.00338529
# step 100, loss=0.00311057
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: jellyfish', '4: probability: 0.00, label: dugong, Dugong dugon', '5: probability: 0.00, label: tiger shark, Galeocerdo cuvieri']]
# [['', '1: probability: 1.00, label: water tower', '2: probability: 0.00, label: balloon', '3: probability: 0.00, label: American black bear, black bear, Ursus americanus, Euarctos americanus', '4: probability: 0.00, label: radio telescope, radio reflector', '5: probability: 0.00, label: beacon, lighthouse, beacon light, pharos']]
# step 10, loss=4.51007
# step 20, loss=2.94507
# step 30, loss=0.0459687
# step 40, loss=0.0206791
# step 50, loss=0.0150402
# step 60, loss=0.0123438
# step 70, loss=0.0103662
# step 80, loss=0.00901911
# step 90, loss=0.00798794
# step 100, loss=0.00724652
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: jellyfish', '4: probability: 0.00, label: dugong, Dugong dugon', '5: probability: 0.00, label: tiger shark, Galeocerdo cuvieri']]
# [['', '1: probability: 0.94, label: water tower', '2: probability: 0.00, label: flagpole, flagstaff', '3: probability: 0.00, label: hand blower, blow dryer, blow drier, hair dryer, hair drier', '4: probability: 0.00, label: airship, dirigible', '5: probability: 0.00, label: spotlight, spot']]
# step 10, loss=1.96621
# step 20, loss=0.013115
# step 30, loss=0.00626446
# step 40, loss=0.00434526
# step 50, loss=0.00343222
# step 60, loss=0.00288654
# step 70, loss=0.00249278
# step 80, loss=0.00221412
# step 90, loss=0.00199762
# step 100, loss=0.00182474
# [['adv', '1: probability: 1.00, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.00, label: stingray', '3: probability: 0.00, label: tiger shark, Galeocerdo cuvieri', '4: probability: 0.00, label: hand blower, blow dryer, blow drier, hair dryer, hair drier', '5: probability: 0.00, label: puffer, pufferfish, blowfish, globefish']]
# [['', '1: probability: 0.93, label: water tower', '2: probability: 0.00, label: radio telescope, radio reflector', '3: probability: 0.00, label: folding chair', '4: probability: 0.00, label: planetarium', '5: probability: 0.00, label: solar dish, solar collector, solar furnace']]
# step 10, loss=1.61786
# step 20, loss=0.0729857
# step 30, loss=0.034839
# step 40, loss=0.0256682
# step 50, loss=0.0208694
# step 60, loss=0.0180828
# step 70, loss=0.0160727
# step 80, loss=0.0145973
# step 90, loss=0.0133805
# step 100, loss=0.0123937
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: tiger shark, Galeocerdo cuvieri', '4: probability: 0.00, label: puffer, pufferfish, blowfish, globefish', '5: probability: 0.00, label: dugong, Dugong dugon']]
# [['', '1: probability: 0.84, label: water tower', '2: probability: 0.07, label: beacon, lighthouse, beacon light, pharos', '3: probability: 0.00, label: missile', '4: probability: 0.00, label: balloon', '5: probability: 0.00, label: freight car']]
# step 10, loss=1.15619
# step 20, loss=0.0492699
# step 30, loss=0.0297015
# step 40, loss=0.0221728
# step 50, loss=0.0183034
# step 60, loss=0.0157362
# step 70, loss=0.0139282
# step 80, loss=0.0125219
# step 90, loss=0.0113585
# step 100, loss=0.0104786
# [['adv', '1: probability: 0.99, label: electric ray, crampfish, numbfish, torpedo', '2: probability: 0.01, label: stingray', '3: probability: 0.00, label: sturgeon', '4: probability: 0.00, label: whistle', '5: probability: 0.00, label: submarine, pigboat, sub, U-boat']]
# [['', '1: probability: 0.97, label: barn', '2: probability: 0.03, label: boathouse', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: church, church building', '5: probability: 0.00, label: lumbermill, sawmill']]
# step 10, loss=5.95274
# step 20, loss=5.18617
# step 30, loss=4.80158
# step 40, loss=4.50499
# step 50, loss=4.3569
# step 60, loss=4.18377
# step 70, loss=4.05143
# step 80, loss=3.97079
# step 90, loss=3.75206
# step 100, loss=3.74688
# [['adv', '1: probability: 0.12, label: boathouse', '2: probability: 0.11, label: barn', '3: probability: 0.04, label: lumbermill, sawmill', '4: probability: 0.03, label: worm fence, snake fence, snake-rail fence, Virginia fence', '5: probability: 0.03, label: wild boar, boar, Sus scrofa']]
# [['', '1: probability: 0.98, label: barn', '2: probability: 0.01, label: boathouse', '3: probability: 0.00, label: church, church building', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: solar dish, solar collector, solar furnace']]
# step 10, loss=0.449169
# step 20, loss=0.16903
# step 30, loss=0.121143
# step 40, loss=0.0989572
# step 50, loss=0.086482
# step 60, loss=0.0773549
# step 70, loss=0.0707369
# step 80, loss=0.0655182
# step 90, loss=0.0614327
# step 100, loss=0.0579501
# [['adv', '1: probability: 0.94, label: wild boar, boar, Sus scrofa', '2: probability: 0.03, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.01, label: warthog', '4: probability: 0.00, label: wallaby, brush kangaroo', '5: probability: 0.00, label: mongoose']]
# [['', '1: probability: 0.97, label: barn', '2: probability: 0.02, label: boathouse', '3: probability: 0.00, label: birdhouse', '4: probability: 0.00, label: thatch, thatched roof', '5: probability: 0.00, label: church, church building']]
# step 10, loss=3.49462
# step 20, loss=0.286009
# step 30, loss=0.171772
# step 40, loss=0.131582
# step 50, loss=0.109759
# step 60, loss=0.096395
# step 70, loss=0.0867185
# step 80, loss=0.0795973
# step 90, loss=0.0740015
# step 100, loss=0.0691112
# [['adv', '1: probability: 0.93, label: wild boar, boar, Sus scrofa', '2: probability: 0.05, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: American black bear, black bear, Ursus americanus, Euarctos americanus', '5: probability: 0.00, label: bison']]
# [['', '1: probability: 0.99, label: barn', '2: probability: 0.00, label: boathouse', '3: probability: 0.00, label: greenhouse, nursery, glasshouse', '4: probability: 0.00, label: lumbermill, sawmill', '5: probability: 0.00, label: worm fence, snake fence, snake-rail fence, Virginia fence']]
# step 10, loss=3.22016
# step 20, loss=1.87725
# step 30, loss=1.19073
# step 40, loss=0.714253
# step 50, loss=0.677215
# step 60, loss=0.529045
# step 70, loss=0.569316
# step 80, loss=0.448347
# step 90, loss=0.433537
# step 100, loss=0.432039
# [['adv', '1: probability: 0.65, label: wild boar, boar, Sus scrofa', '2: probability: 0.12, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.01, label: barn', '4: probability: 0.01, label: boathouse', '5: probability: 0.01, label: four-poster']]
# [['', '1: probability: 0.97, label: barn', '2: probability: 0.01, label: church, church building', '3: probability: 0.00, label: boathouse', '4: probability: 0.00, label: worm fence, snake fence, snake-rail fence, Virginia fence', '5: probability: 0.00, label: thatch, thatched roof']]
# step 10, loss=0.190523
# step 20, loss=0.0741693
# step 30, loss=0.0529248
# step 40, loss=0.0418444
# step 50, loss=0.0352247
# step 60, loss=0.0306637
# step 70, loss=0.0273902
# step 80, loss=0.0249054
# step 90, loss=0.0229136
# step 100, loss=0.0212813
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: armadillo', '5: probability: 0.00, label: wallaby, brush kangaroo']]
# [['', '1: probability: 0.98, label: dam, dike, dyke', '2: probability: 0.01, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: dock, dockage, docking facility', '5: probability: 0.00, label: container ship, containership, container vessel']]
# step 10, loss=3.26126
# step 20, loss=1.59868
# step 30, loss=0.725502
# step 40, loss=0.39944
# step 50, loss=0.262811
# step 60, loss=0.221521
# step 70, loss=0.182128
# step 80, loss=0.163805
# step 90, loss=0.153186
# step 100, loss=0.142849
# [['adv', '1: probability: 0.87, label: wild boar, boar, Sus scrofa', '2: probability: 0.06, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: dam, dike, dyke', '4: probability: 0.00, label: assault rifle, assault gun', '5: probability: 0.00, label: shovel']]
# [['', '1: probability: 0.99, label: dam, dike, dyke', '2: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty', '3: probability: 0.00, label: pier', '4: probability: 0.00, label: submarine, pigboat, sub, U-boat', '5: probability: 0.00, label: barn']]
# step 10, loss=0.395399
# step 20, loss=0.0889347
# step 30, loss=0.0602134
# step 40, loss=0.0466551
# step 50, loss=0.039504
# step 60, loss=0.0347747
# step 70, loss=0.0313385
# step 80, loss=0.0287152
# step 90, loss=0.0265837
# step 100, loss=0.0248535
# [['adv', '1: probability: 0.98, label: wild boar, boar, Sus scrofa', '2: probability: 0.02, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: porcupine, hedgehog', '5: probability: 0.00, label: wallaby, brush kangaroo']]
# [['', '1: probability: 1.00, label: dam, dike, dyke', '2: probability: 0.00, label: suspension bridge', '3: probability: 0.00, label: viaduct', '4: probability: 0.00, label: pier', '5: probability: 0.00, label: breakwater, groin, groyne, mole, bulwark, seawall, jetty']]
# step 10, loss=0.112054
# step 20, loss=0.0527619
# step 30, loss=0.0376724
# step 40, loss=0.0295391
# step 50, loss=0.0245879
# step 60, loss=0.0212414
# step 70, loss=0.0188805
# step 80, loss=0.0170712
# step 90, loss=0.0155683
# step 100, loss=0.014332
# [['adv', '1: probability: 0.99, label: wild boar, boar, Sus scrofa', '2: probability: 0.01, label: hog, pig, grunter, squealer, Sus scrofa', '3: probability: 0.00, label: warthog', '4: probability: 0.00, label: tarantula', '5: probability: 0.00, label: beaver']]
# ...
# [['', '1: probability: 1.00, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: projector', '3: probability: 0.00, label: reflex camera', '4: probability: 0.00, label: joystick', '5: probability: 0.00, label: CD player']]
# step 10, loss=2.20557
# step 20, loss=0.00738995
# step 30, loss=0.0044408
# step 40, loss=0.00331329
# step 50, loss=0.00271916
# step 60, loss=0.00233937
# step 70, loss=0.00207697
# step 80, loss=0.00188102
# step 90, loss=0.00172907
# step 100, loss=0.0016047
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: water bottle', '4: probability: 0.00, label: pill bottle', '5: probability: 0.00, label: pop bottle, soda bottle']]
# [['', '1: probability: 0.98, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: tape player', '3: probability: 0.00, label: cassette player', '4: probability: 0.00, label: radio, wireless', '5: probability: 0.00, label: reflex camera']]
# step 10, loss=0.0111102
# step 20, loss=0.00568997
# step 30, loss=0.00414346
# step 40, loss=0.00332292
# step 50, loss=0.00281605
# step 60, loss=0.00247553
# step 70, loss=0.00222364
# step 80, loss=0.00202712
# step 90, loss=0.00186282
# step 100, loss=0.00172692
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: lighter, light, igniter, ignitor', '3: probability: 0.00, label: water bottle', '4: probability: 0.00, label: perfume, essence', '5: probability: 0.00, label: cocktail shaker']]
# [['', '1: probability: 0.83, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.15, label: projector', '3: probability: 0.00, label: loudspeaker, speaker, speaker unit, loudspeaker system, speaker system', '4: probability: 0.00, label: CD player', '5: probability: 0.00, label: tape player']]
# step 10, loss=0.01853
# step 20, loss=0.00876993
# step 30, loss=0.00603247
# step 40, loss=0.00472607
# step 50, loss=0.00397713
# step 60, loss=0.00347035
# step 70, loss=0.00308633
# step 80, loss=0.00278538
# step 90, loss=0.00254248
# step 100, loss=0.00234317
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: pencil sharpener', '3: probability: 0.00, label: lighter, light, igniter, ignitor', '4: probability: 0.00, label: soap dispenser', '5: probability: 0.00, label: piggy bank, penny bank']]
# [['', '1: probability: 0.99, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.00, label: reflex camera', '3: probability: 0.00, label: projector', '4: probability: 0.00, label: lens cap, lens cover', '5: probability: 0.00, label: iPod']]
# step 10, loss=0.262786
# step 20, loss=0.0284448
# step 30, loss=0.0196901
# step 40, loss=0.0157265
# step 50, loss=0.0134412
# step 60, loss=0.0118173
# step 70, loss=0.0106315
# step 80, loss=0.00968838
# step 90, loss=0.00896666
# step 100, loss=0.00836488
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: piggy bank, penny bank', '3: probability: 0.00, label: joystick', '4: probability: 0.00, label: pencil sharpener', '5: probability: 0.00, label: pill bottle']]
# [['', '1: probability: 0.96, label: Polaroid camera, Polaroid Land camera', '2: probability: 0.01, label: reflex camera', '3: probability: 0.00, label: projector', '4: probability: 0.00, label: espresso maker', '5: probability: 0.00, label: radio, wireless']]
# step 10, loss=0.0808736
# step 20, loss=0.0381637
# step 30, loss=0.0276531
# step 40, loss=0.0223282
# step 50, loss=0.0189939
# step 60, loss=0.016575
# step 70, loss=0.0147637
# step 80, loss=0.0133908
# step 90, loss=0.0122863
# step 100, loss=0.0113703
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: pencil sharpener', '3: probability: 0.00, label: lighter, light, igniter, ignitor', '4: probability: 0.00, label: thimble', '5: probability: 0.00, label: perfume, essence']]
# [['', '1: probability: 0.99, label: pencil sharpener', '2: probability: 0.00, label: rubber eraser, rubber, pencil eraser', '3: probability: 0.00, label: switch, electric switch, electrical switch', '4: probability: 0.00, label: lighter, light, igniter, ignitor', '5: probability: 0.00, label: Polaroid camera, Polaroid Land camera']]
# step 10, loss=0.0170649
# step 20, loss=0.00904995
# step 30, loss=0.00648963
# step 40, loss=0.00522391
# step 50, loss=0.00441481
# step 60, loss=0.00382858
# step 70, loss=0.00339943
# step 80, loss=0.00307147
# step 90, loss=0.00281189
# step 100, loss=0.00259194
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: piggy bank, penny bank', '3: probability: 0.00, label: soap dispenser', '4: probability: 0.00, label: pencil sharpener', '5: probability: 0.00, label: rubber eraser, rubber, pencil eraser']]
# [['', '1: probability: 1.00, label: pencil sharpener', '2: probability: 0.00, label: washbasin, handbasin, washbowl, lavabo, wash-hand basin', '3: probability: 0.00, label: lighter, light, igniter, ignitor', '4: probability: 0.00, label: switch, electric switch, electrical switch', '5: probability: 0.00, label: combination lock']]
# step 10, loss=0.031014
# step 20, loss=0.0170205
# step 30, loss=0.0123954
# step 40, loss=0.0100361
# step 50, loss=0.00854325
# step 60, loss=0.00745408
# step 70, loss=0.00663885
# step 80, loss=0.00601008
# step 90, loss=0.00551749
# step 100, loss=0.00510876
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: pencil sharpener', '3: probability: 0.00, label: teapot', '4: probability: 0.00, label: bottlecap', '5: probability: 0.00, label: rubber eraser, rubber, pencil eraser']]
# [['', '1: probability: 0.93, label: pencil sharpener', '2: probability: 0.01, label: whistle', "3: probability: 0.00, label: plane, carpenter's plane, woodworking plane", '4: probability: 0.00, label: lighter, light, igniter, ignitor', '5: probability: 0.00, label: holster']]
# step 10, loss=0.0474644
# step 20, loss=0.0220832
# step 30, loss=0.0151252
# step 40, loss=0.0117562
# step 50, loss=0.00973938
# step 60, loss=0.0083079
# step 70, loss=0.00728759
# step 80, loss=0.00653949
# step 90, loss=0.00595083
# step 100, loss=0.00545881
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: pencil sharpener', '3: probability: 0.00, label: thimble', '4: probability: 0.00, label: lighter, light, igniter, ignitor', '5: probability: 0.00, label: remote control, remote']]
# [['', '1: probability: 1.00, label: pencil sharpener', '2: probability: 0.00, label: cassette', '3: probability: 0.00, label: mousetrap', '4: probability: 0.00, label: rubber eraser, rubber, pencil eraser', '5: probability: 0.00, label: switch, electric switch, electrical switch']]
# step 10, loss=0.0583955
# step 20, loss=0.0277195
# step 30, loss=0.0196479
# step 40, loss=0.0155567
# step 50, loss=0.0131267
# step 60, loss=0.0114251
# step 70, loss=0.0101996
# step 80, loss=0.00923327
# step 90, loss=0.00845602
# step 100, loss=0.00781479
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: pencil sharpener', '3: probability: 0.00, label: pool table, billiard table, snooker table', '4: probability: 0.00, label: tray', '5: probability: 0.00, label: teapot']]
# [['', '1: probability: 0.95, label: pencil sharpener', '2: probability: 0.01, label: rubber eraser, rubber, pencil eraser', '3: probability: 0.01, label: lighter, light, igniter, ignitor', '4: probability: 0.00, label: switch, electric switch, electrical switch', '5: probability: 0.00, label: pencil box, pencil case']]
# step 10, loss=0.010247
# step 20, loss=0.00475906
# step 30, loss=0.00336402
# step 40, loss=0.00265995
# step 50, loss=0.0022416
# step 60, loss=0.00194979
# step 70, loss=0.0017393
# step 80, loss=0.00157863
# step 90, loss=0.00145032
# step 100, loss=0.00134402
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: pencil sharpener', '3: probability: 0.00, label: perfume, essence', '4: probability: 0.00, label: lighter, light, igniter, ignitor', '5: probability: 0.00, label: pill bottle']]
# [['', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: Polaroid camera, Polaroid Land camera', '4: probability: 0.00, label: reflex camera', '5: probability: 0.00, label: joystick']]
# step 10, loss=0.0302129
# step 20, loss=0.0116835
# step 30, loss=0.00804777
# step 40, loss=0.0062718
# step 50, loss=0.00517825
# step 60, loss=0.00442158
# step 70, loss=0.00388926
# step 80, loss=0.00350088
# step 90, loss=0.00319079
# step 100, loss=0.00292826
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: dial telephone, dial phone', '3: probability: 0.00, label: espresso maker', '4: probability: 0.00, label: pencil sharpener', '5: probability: 0.00, label: thimble']]
# [['', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: hard disc, hard disk, fixed disk', '4: probability: 0.00, label: iron, smoothing iron', '5: probability: 0.00, label: magnetic compass']]
# step 10, loss=0.0574949
# step 20, loss=0.028286
# step 30, loss=0.0198218
# step 40, loss=0.0156827
# step 50, loss=0.013119
# step 60, loss=0.0113267
# step 70, loss=0.00999576
# step 80, loss=0.00893464
# step 90, loss=0.00811399
# step 100, loss=0.00744663
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: dial telephone, dial phone', '3: probability: 0.00, label: pencil sharpener', '4: probability: 0.00, label: tray', '5: probability: 0.00, label: pitcher, ewer']]
# [['', '1: probability: 1.00, label: dial telephone, dial phone', '2: probability: 0.00, label: pay-phone, pay-station', '3: probability: 0.00, label: iron, smoothing iron', '4: probability: 0.00, label: iPod', '5: probability: 0.00, label: hard disc, hard disk, fixed disk']]
# step 10, loss=0.106759
# step 20, loss=0.0343433
# step 30, loss=0.0215039
# step 40, loss=0.016189
# step 50, loss=0.0131363
# step 60, loss=0.0111739
# step 70, loss=0.00976004
# step 80, loss=0.00868449
# step 90, loss=0.00778853
# step 100, loss=0.00706898
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: dial telephone, dial phone', '3: probability: 0.00, label: piggy bank, penny bank', '4: probability: 0.00, label: pencil sharpener', '5: probability: 0.00, label: teapot']]
# [['', '1: probability: 0.84, label: dial telephone, dial phone', '2: probability: 0.02, label: vacuum, vacuum cleaner', '3: probability: 0.01, label: hand blower, blow dryer, blow drier, hair dryer, hair drier', '4: probability: 0.01, label: reflex camera', '5: probability: 0.01, label: Polaroid camera, Polaroid Land camera']]
# step 10, loss=0.0108797
# step 20, loss=0.00545892
# step 30, loss=0.00376124
# step 40, loss=0.00290341
# step 50, loss=0.00240275
# step 60, loss=0.00205841
# step 70, loss=0.00180558
# step 80, loss=0.00160767
# step 90, loss=0.00145639
# step 100, loss=0.00133616
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: pop bottle, soda bottle', '3: probability: 0.00, label: pill bottle', '4: probability: 0.00, label: dial telephone, dial phone', '5: probability: 0.00, label: perfume, essence']]
# [['', '1: probability: 0.99, label: dial telephone, dial phone', '2: probability: 0.00, label: vacuum, vacuum cleaner', '3: probability: 0.00, label: iron, smoothing iron', '4: probability: 0.00, label: oxygen mask', '5: probability: 0.00, label: pay-phone, pay-station']]
# step 10, loss=0.0256525
# step 20, loss=0.0125384
# step 30, loss=0.00901096
# step 40, loss=0.00723859
# step 50, loss=0.00613046
# step 60, loss=0.00534771
# step 70, loss=0.00475597
# step 80, loss=0.00428995
# step 90, loss=0.00392975
# step 100, loss=0.00364722
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: teapot', '3: probability: 0.00, label: soap dispenser', '4: probability: 0.00, label: piggy bank, penny bank', '5: probability: 0.00, label: coffeepot']]
# [['', '1: probability: 0.91, label: water tower', '2: probability: 0.01, label: mushroom', '3: probability: 0.01, label: golf ball', '4: probability: 0.00, label: ping-pong ball', '5: probability: 0.00, label: mosque']]
# step 10, loss=1.1533
# step 20, loss=0.00602773
# step 30, loss=0.00375317
# step 40, loss=0.00291839
# step 50, loss=0.002459
# step 60, loss=0.00215965
# step 70, loss=0.00193968
# step 80, loss=0.00176679
# step 90, loss=0.00162624
# step 100, loss=0.00151341
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: thimble', '4: probability: 0.00, label: pill bottle', '5: probability: 0.00, label: candle, taper, wax light']]
# [['', '1: probability: 1.00, label: water tower', '2: probability: 0.00, label: balloon', '3: probability: 0.00, label: American black bear, black bear, Ursus americanus, Euarctos americanus', '4: probability: 0.00, label: radio telescope, radio reflector', '5: probability: 0.00, label: beacon, lighthouse, beacon light, pharos']]
# step 10, loss=0.706651
# step 20, loss=0.0130068
# step 30, loss=0.00817974
# step 40, loss=0.00640992
# step 50, loss=0.00542442
# step 60, loss=0.00477246
# step 70, loss=0.00427843
# step 80, loss=0.00391051
# step 90, loss=0.00362264
# step 100, loss=0.00338838
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: soap dispenser', '4: probability: 0.00, label: nipple', '5: probability: 0.00, label: water tower']]
# [['', '1: probability: 0.94, label: water tower', '2: probability: 0.00, label: flagpole, flagstaff', '3: probability: 0.00, label: hand blower, blow dryer, blow drier, hair dryer, hair drier', '4: probability: 0.00, label: airship, dirigible', '5: probability: 0.00, label: spotlight, spot']]
# step 10, loss=1.53593
# step 20, loss=0.00810938
# step 30, loss=0.00412601
# step 40, loss=0.00302085
# step 50, loss=0.00246578
# step 60, loss=0.00211076
# step 70, loss=0.00186198
# step 80, loss=0.00166921
# step 90, loss=0.00151876
# step 100, loss=0.00139318
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: perfume, essence', '4: probability: 0.00, label: ocarina, sweet potato', '5: probability: 0.00, label: candle, taper, wax light']]
# [['', '1: probability: 0.93, label: water tower', '2: probability: 0.00, label: radio telescope, radio reflector', '3: probability: 0.00, label: folding chair', '4: probability: 0.00, label: planetarium', '5: probability: 0.00, label: solar dish, solar collector, solar furnace']]
# step 10, loss=4.09849
# step 20, loss=3.17149
# step 30, loss=2.23113
# step 40, loss=1.72075
# step 50, loss=0.790862
# step 60, loss=0.0655363
# step 70, loss=0.0139173
# step 80, loss=0.00990689
# step 90, loss=0.0080421
# step 100, loss=0.00701974
# [['adv', '1: probability: 0.99, label: saltshaker, salt shaker', '2: probability: 0.00, label: thimble', '3: probability: 0.00, label: eggnog', '4: probability: 0.00, label: strainer', '5: probability: 0.00, label: water tower']]
# [['', '1: probability: 0.84, label: water tower', '2: probability: 0.07, label: beacon, lighthouse, beacon light, pharos', '3: probability: 0.00, label: missile', '4: probability: 0.00, label: balloon', '5: probability: 0.00, label: freight car']]
# step 10, loss=0.0105132
# step 20, loss=0.00435998
# step 30, loss=0.00311723
# step 40, loss=0.0025181
# step 50, loss=0.00214049
# step 60, loss=0.00186305
# step 70, loss=0.00165516
# step 80, loss=0.00149793
# step 90, loss=0.00137187
# step 100, loss=0.00126925
# [['adv', '1: probability: 1.00, label: saltshaker, salt shaker', '2: probability: 0.00, label: soap dispenser', '3: probability: 0.00, label: water bottle', '4: probability: 0.00, label: thimble', '5: probability: 0.00, label: candle, taper, wax light']]

# %%
img_path, _ = urlretrieve("file:///home/w266ajh/Documents/top5gen/data_imageparts_1/burger1.jpg") #urlretrieve('http://www.anishathalye.com/media/2017/07/25/cat.jpg')
img_class = 281
img = PIL.Image.open(img_path)
big_dim = max(img.width, img.height)
wide = img.width > img.height
new_w = 224 if not wide else int(img.width * 224 / img.height)
new_h = 224 if wide else int(img.height * 224 / img.width)
img = img.resize((new_w, new_h)).crop((0, 0, 224, 224))
img = (np.asarray(img) / 255.0).astype(np.float32)
with open("adv_input", "w") as out:
    out.write(str(img))

# %%
classify(img, correct_class=img_class)

# %% [markdown]
# # Adversarial examples
#
# Given an image $\mathbf{x}$, our neural network outputs a probability distribution over labels, $P(y \mid \mathbf{x})$. When we craft an adversarial input, we want to find an $\hat{\mathbf{x}}$ where $\log P(\hat{y} \mid \hat{\mathbf{x}})$ is maximized for a target label $\hat{y}$: that way, our input will be misclassified as the target class. We can ensure that $\hat{\mathbf{x}}$ doesn't look too different from the original $\mathbf{x}$ by constraining ourselves to some $\ell_\infty$ box with radius $\epsilon$, requiring that $\left\lVert \mathbf{x} - \hat{\mathbf{x}} \right\rVert_\infty \le \epsilon$.
#
# In this framework, an adversarial example is the solution to a constrained optimization problem that we can solve using [backpropagation](http://colah.github.io/posts/2015-08-Backprop/) and projected gradient descent, basically the same techniques that are used to train networks themselves. The algorithm is simple:
#
# We begin by initializing our adversarial example as $\hat{\mathbf{x}} \leftarrow \mathbf{x}$. Then, we repeat the following until convergence:
#
# 1. $\hat{\mathbf{x}} \leftarrow \hat{\mathbf{x}} + \alpha \cdot \nabla \log P(\hat{y} \mid \hat{\mathbf{x}})$
# 2. $\hat{\mathbf{x}} \leftarrow \mathrm{clip}(\hat{\mathbf{x}}, \mathbf{x} - \epsilon, \mathbf{x} + \epsilon)$

# %% [markdown]
# ## Initialization
#
# We start with the easiest part: writing a TensorFlow op for initialization.

# %%
x = tf.placeholder(tf.float32, (224, 224, 3))

x_hat = image # our trainable adversarial input
assign_op = tf.assign(x_hat, x)

# %% [markdown]
# ## Gradient descent step
#
# Next, we write the gradient descent step to maximize the log probability of the target class (or equivalently, minimize the [cross entropy](https://en.wikipedia.org/wiki/Cross_entropy)).

# %%
learning_rate = tf.placeholder(tf.float32, ())
y_hat = tf.placeholder(tf.int32, ())

labels = tf.one_hot(y_hat, 1000)
loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=[labels])
optim_step = tf.train.GradientDescentOptimizer(
    learning_rate).minimize(loss, var_list=[x_hat])

# %% [markdown]
# ## Projection step
#
# Finally, we write the projection step to keep our adversarial example visually close to the original image. Additionally, we clip to $[0, 1]$ to keep it a valid image.

# %%
epsilon = tf.placeholder(tf.float32, ())

below = x - epsilon
above = x + epsilon
projected = tf.clip_by_value(tf.clip_by_value(x_hat, below, above), 0, 1)
with tf.control_dependencies([projected]):
    project_step = tf.assign(x_hat, projected)

# %% [markdown]
# ## Execution
#
# Finally, we're ready to synthesize an adversarial example. We arbitrarily choose "guacamole" (imagenet class 924) as our target class.

# %%
demo_epsilon = 2.0/255.0 # a really small perturbation
demo_lr = 1e-1
demo_steps = 100
demo_target = 5 # "guacamole"

# initialization step
sess.run(assign_op, feed_dict={x: img})

# projected gradient descent
for i in range(demo_steps):
    # gradient descent step
    _, loss_value = sess.run(
        [optim_step, loss],
        feed_dict={learning_rate: demo_lr, y_hat: demo_target})
    # project step
    sess.run(project_step, feed_dict={x: img, epsilon: demo_epsilon})
    if (i+1) % 10 == 0:
        print('step %d, loss=%g' % (i+1, loss_value))
    

adv = x_hat.eval() # retrieve the adversarial example
from skimage.io import imsave
imsave("adv.png", adv, plugin='pil', format_str='png')
# with open("adv_output.txt", 'w') as out:
#     out.write(str(a) for a in adv)
np.set_printoptions(threshold=np.nan)
with open("adv_output.txt", "w") as out:
    out.write(str(adv))
# Out:
# step 10, loss=0.0745826
# step 20, loss=0.0274223
# step 30, loss=0.0193071
# step 40, loss=0.0152627
# step 50, loss=0.0128315
# step 60, loss=0.0111517
# step 70, loss=0.00996165
# step 80, loss=0.00905573
# step 90, loss=0.00833261
# step 100, loss=0.00773743
# /home/w266ajh/.local/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float32 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %% [markdown]
# This adversarial image is visually indistinguishable from the original, with no visual artifacts. However, it's classified as "guacamole" with high probability!

# %%
classify(adv, correct_class=img_class, target_class=demo_target)

# %% [markdown]
# # Robust adversarial examples
#
# Now, we go through a more advanced example. We follow our approach for [synthesizing robust adversarial examples](https://arxiv.org/abs/1707.07397) to find a single perturbation of our cat image that's simultaneously adversarial under some chosen distribution of transformations.  We could choose any distribution of differentiable transformations; in this post, we'll synthesize a single adversarial input that's robust to rotation by $\theta \in [-\pi/4, \pi/4]$.
#
# Before we proceed, let's check if our previous example is still adversarial if we rotate it, say by an angle of $\theta = \pi/8$.

# %%
ex_angle = np.pi/8

angle = tf.placeholder(tf.float32, ())
rotated_image = tf.contrib.image.rotate(image, angle)
rotated_example = rotated_image.eval(feed_dict={image: adv, angle: ex_angle})
classify(rotated_example, correct_class=img_class, target_class=demo_target)

# %% [markdown]
# Looks like our original adversarial example is not rotation-invariant!
#
# So, how do we make an adversarial example robust to a distribution of transformations? Given some distribution of transformations $T$, we can maximize $\mathbb{E}_{t \sim T} \log P\left(\hat{y} \mid t(\hat{\mathbf{x}})\right)$, subject to $\left\lVert \mathbf{x} - \hat{\mathbf{x}} \right\rVert_\infty \le \epsilon$. We can solve this optimization problem via projected gradient descent, noting that $\nabla \mathbb{E}_{t \sim T} \log P\left(\hat{y} \mid t(\hat{\mathbf{x}})\right)$ is $\mathbb{E}_{t \sim T} \nabla \log P\left(\hat{y} \mid t(\hat{\mathbf{x}})\right)$ and approximating with samples at each gradient descent step.
#
# Rather than manually implementing the gradient sampling, we can use a trick to get TensorFlow to do it for us: we can model our sampling-based gradient descent as doing gradient descent over an ensemble of stochastic classifiers that randomly sample from the distribution and transform their input before classifying it.

# %%
num_samples = 10
average_loss = 0
for i in range(num_samples):
    rotated = tf.contrib.image.rotate(
        image, tf.random_uniform((), minval=-np.pi/4, maxval=np.pi/4))
    rotated_logits, _ = inception(rotated, reuse=True)
    average_loss += tf.nn.softmax_cross_entropy_with_logits(
        logits=rotated_logits, labels=labels) / num_samples

# %% [markdown]
# We can reuse our `assign_op` and `project_step`, though we'll have to write a new `optim_step` for this new objective.

# %%
optim_step = tf.train.GradientDescentOptimizer(
    learning_rate).minimize(average_loss, var_list=[x_hat])

# %% [markdown]
# Finally, we're ready to run PGD to generate our adversarial input. As in the previous example, we'll choose "guacamole" as our target class.

# %%
demo_epsilon = 8.0/255.0 # still a pretty small perturbation
demo_lr = 2e-1
demo_steps = 300
demo_target = 924 # "guacamole"

# initialization step
sess.run(assign_op, feed_dict={x: img})

# projected gradient descent
for i in range(demo_steps):
    # gradient descent step
    _, loss_value = sess.run(
        [optim_step, average_loss],
        feed_dict={learning_rate: demo_lr, y_hat: demo_target})
    # project step
    sess.run(project_step, feed_dict={x: img, epsilon: demo_epsilon})
    if (i+1) % 50 == 0:
        print('step %d, loss=%g' % (i+1, loss_value))
    

adv_robust = x_hat.eval() # retrieve the adversarial example
# Out:
# step 50, loss=4.92575
# step 100, loss=3.15049
# step 150, loss=0.332409
# step 200, loss=0.066395
# step 250, loss=0.0516987
# step 300, loss=0.0207874

# %%
from skimage.io import imsave
imsave("adv_robust.png", adv_robust, plugin='pil', format_str='png')
# Out:
# /home/w266ajh/.local/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float32 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %% [markdown]
# This adversarial image is classified as "guacamole" with high confidence, even when it's rotated!

# %%
rotated_example = rotated_image.eval(feed_dict={image: adv_robust, angle: ex_angle})
classify(rotated_example, correct_class=img_class, target_class=demo_target)

# %% [markdown]
# ## Evaluation
#
# Let's examine the rotation-invariance of the robust adversarial example we produced over the entire range of angles, looking at $P(\hat{y} \mid \hat{\mathbf{x}})$ over $\theta \in [-\pi/4, \pi/4]$.

# %%
thetas = np.linspace(-np.pi/4, np.pi/4, 301)

p_naive = []
p_robust = []
for theta in thetas:
    rotated = rotated_image.eval(feed_dict={image: adv_robust, angle: theta})
    p_robust.append(probs.eval(feed_dict={image: rotated})[0][demo_target])
    
    rotated = rotated_image.eval(feed_dict={image: adv, angle: theta})
    p_naive.append(probs.eval(feed_dict={image: rotated})[0][demo_target])

robust_line, = plt.plot(thetas, p_robust, color='b', linewidth=2, label='robust')
naive_line, = plt.plot(thetas, p_naive, color='r', linewidth=2, label='naive')
plt.ylim([0, 1.05])
plt.xlabel('rotation angle')
plt.ylabel('target class probability')
plt.legend(handles=[robust_line, naive_line], loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b618cb8a4088> in <module>()
#       4 p_robust = []
#       5 for theta in thetas:
# ----> 6     rotated = rotated_image.eval(feed_dict={image: adv_robust, angle: theta})
#       7     p_robust.append(probs.eval(feed_dict={image: rotated})[0][demo_target])
#       8
#
# NameError: name 'rotated_image' is not defined

# %% [markdown]
# It's super effective!
