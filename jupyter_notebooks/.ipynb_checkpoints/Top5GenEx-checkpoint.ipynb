# %%
import os
import sys
sys.path.append('../')
from top5gen.examples.inception_pretrained import get_top_five
# Out:
# WARNING:tensorflow:From /home/w266ajh/.local/lib/python3.6/site-packages/tensorflow/python/keras/initializers.py:104: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with distribution=normal is deprecated and will be removed in a future version.
# Instructions for updating:
# `normal` is a deprecated alias for `truncated_normal`
# Load conv1_7x7_s2 weights!
# Load conv1_7x7_s2 biases!
# Load conv2_3x3_reduce weights!
# Load conv2_3x3_reduce biases!
# Load conv2_3x3 weights!
# Load conv2_3x3 biases!
# Load inception_3a_1x1 weights!
# Load inception_3a_1x1 biases!
# Load inception_3a_3x3_reduce weights!
# Load inception_3a_3x3_reduce biases!
# Load inception_3a_3x3 weights!
# Load inception_3a_3x3 biases!
# Load inception_3a_5x5_reduce weights!
# Load inception_3a_5x5_reduce biases!
# Load inception_3a_5x5 weights!
# Load inception_3a_5x5 biases!
# Load inception_3a_pool_proj weights!
# Load inception_3a_pool_proj biases!
# Load inception_3b_1x1 weights!
# Load inception_3b_1x1 biases!
# Load inception_3b_3x3_reduce weights!
# Load inception_3b_3x3_reduce biases!
# Load inception_3b_3x3 weights!
# Load inception_3b_3x3 biases!
# Load inception_3b_5x5_reduce weights!
# Load inception_3b_5x5_reduce biases!
# Load inception_3b_5x5 weights!
# Load inception_3b_5x5 biases!
# Load inception_3b_pool_proj weights!
# Load inception_3b_pool_proj biases!
# Load inception_4a_1x1 weights!
# Load inception_4a_1x1 biases!
# Load inception_4a_3x3_reduce weights!
# Load inception_4a_3x3_reduce biases!
# Load inception_4a_3x3 weights!
# Load inception_4a_3x3 biases!
# Load inception_4a_5x5_reduce weights!
# Load inception_4a_5x5_reduce biases!
# Load inception_4a_5x5 weights!
# Load inception_4a_5x5 biases!
# Load inception_4a_pool_proj weights!
# Load inception_4a_pool_proj biases!
# Load inception_4b_1x1 weights!
# Load inception_4b_1x1 biases!
# Load inception_4b_3x3_reduce weights!
# Load inception_4b_3x3_reduce biases!
# Load inception_4b_3x3 weights!
# Load inception_4b_3x3 biases!
# Load inception_4b_5x5_reduce weights!
# Load inception_4b_5x5_reduce biases!
# Load inception_4b_5x5 weights!
# Load inception_4b_5x5 biases!
# Load inception_4b_pool_proj weights!
# Load inception_4b_pool_proj biases!
# Load inception_4c_1x1 weights!
# Load inception_4c_1x1 biases!
# Load inception_4c_3x3_reduce weights!
# Load inception_4c_3x3_reduce biases!
# Load inception_4c_3x3 weights!
# Load inception_4c_3x3 biases!
# Load inception_4c_5x5_reduce weights!
# Load inception_4c_5x5_reduce biases!
# Load inception_4c_5x5 weights!
# Load inception_4c_5x5 biases!
# Load inception_4c_pool_proj weights!
# Load inception_4c_pool_proj biases!
# Load inception_4d_1x1 weights!
# Load inception_4d_1x1 biases!
# Load inception_4d_3x3_reduce weights!
# Load inception_4d_3x3_reduce biases!
# Load inception_4d_3x3 weights!
# Load inception_4d_3x3 biases!
# Load inception_4d_5x5_reduce weights!
# Load inception_4d_5x5_reduce biases!
# Load inception_4d_5x5 weights!
# Load inception_4d_5x5 biases!
# Load inception_4d_pool_proj weights!
# Load inception_4d_pool_proj biases!
# Load inception_4e_1x1 weights!
# Load inception_4e_1x1 biases!
# Load inception_4e_3x3_reduce weights!
# Load inception_4e_3x3_reduce biases!
# Load inception_4e_3x3 weights!
# Load inception_4e_3x3 biases!
# Load inception_4e_5x5_reduce weights!
# Load inception_4e_5x5_reduce biases!
# Load inception_4e_5x5 weights!
# Load inception_4e_5x5 biases!
# Load inception_4e_pool_proj weights!
# Load inception_4e_pool_proj biases!
# Load inception_5a_1x1 weights!
# Load inception_5a_1x1 biases!
# Load inception_5a_3x3_reduce weights!
# Load inception_5a_3x3_reduce biases!
# Load inception_5a_3x3 weights!
# Load inception_5a_3x3 biases!
# Load inception_5a_5x5_reduce weights!
# Load inception_5a_5x5_reduce biases!
# Load inception_5a_5x5 weights!
# Load inception_5a_5x5 biases!
# Load inception_5a_pool_proj weights!
# Load inception_5a_pool_proj biases!
# Load inception_5b_1x1 weights!
# Load inception_5b_1x1 biases!
# Load inception_5b_3x3_reduce weights!
# Load inception_5b_3x3_reduce biases!
# Load inception_5b_3x3 weights!
# Load inception_5b_3x3 biases!
# Load inception_5b_5x5_reduce weights!
# Load inception_5b_5x5_reduce biases!
# Load inception_5b_5x5 weights!
# Load inception_5b_5x5 biases!
# Load inception_5b_pool_proj weights!
# Load inception_5b_pool_proj biases!
# Load loss3_classifier weights!
# Load loss3_classifier biases!
# Tensor("fc_layers/Squeeze:0", shape=(?, 1000), dtype=float32)
# Tensor("fc_layers/Squeeze:0", shape=(?, 1000), dtype=float32)

# %%
a = get_top_five('/home/w266ajh/Documents/top5gen/data_imageparts_1/', '.jpg')
print(a)
#for thing in a: 
    #for t in thing: print(t)
# Out:
# /home/w266ajh/.local/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/w266ajh/.local/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/w266ajh/Documents/top5gen/data_imageparts_1/burger1.jpg
# 1: probability: 0.99, label: cheeseburger
# 2: probability: 0.00, label: hotdog
# 3: probability: 0.00, label: bagel
# 4: probability: 0.00, label: meat loaf
# 5: probability: 0.00, label: ice cream
# /home/w266ajh/Documents/top5gen/data_imageparts_1/burger2.jpg
# 1: probability: 0.99, label: cheeseburger
# 2: probability: 0.00, label: meat loaf
# 3: probability: 0.00, label: plate
# 4: probability: 0.00, label: bagel
# 5: probability: 0.00, label: ice cream
# /home/w266ajh/Documents/top5gen/data_imageparts_1/burger3.jpg
# 1: probability: 1.00, label: cheeseburger
# 2: probability: 0.00, label: hotdog
# 3: probability: 0.00, label: meat loaf
# 4: probability: 0.00, label: ice cream
# 5: probability: 0.00, label: bagel
# /home/w266ajh/Documents/top5gen/data_imageparts_1/burger4.jpg
# 1: probability: 0.99, label: cheeseburger
# 2: probability: 0.01, label: bagel
# 3: probability: 0.00, label: hotdog
# 4: probability: 0.00, label: French loaf
# 5: probability: 0.00, label: potpie
# /home/w266ajh/Documents/top5gen/data_imageparts_1/burger5.jpg
# 1: probability: 1.00, label: cheeseburger
# 2: probability: 0.00, label: bagel
# 3: probability: 0.00, label: ice cream
# 4: probability: 0.00, label: bakery
# 5: probability: 0.00, label: meat loaf
# /home/w266ajh/Documents/top5gen/data_imageparts_1/colobus1.jpg
# 1: probability: 0.96, label: colobus
# 2: probability: 0.03, label: guenon
# 3: probability: 0.01, label: langur
# 4: probability: 0.00, label: marmoset
# 5: probability: 0.00, label: patas
# /home/w266ajh/Documents/top5gen/data_imageparts_1/colobus2.jpg
# 1: probability: 1.00, label: colobus
# 2: probability: 0.00, label: guenon
# 3: probability: 0.00, label: gibbon
# 4: probability: 0.00, label: siamang
# 5: probability: 0.00, label: langur
# /home/w266ajh/Documents/top5gen/data_imageparts_1/colobus3.jpg
# 1: probability: 0.95, label: colobus
# 2: probability: 0.03, label: gibbon
# 3: probability: 0.01, label: guenon
# 4: probability: 0.01, label: langur
# 5: probability: 0.00, label: siamang
# /home/w266ajh/Documents/top5gen/data_imageparts_1/colobus4.jpg
# 1: probability: 0.95, label: colobus
# 2: probability: 0.02, label: gibbon
# 3: probability: 0.02, label: guenon
# 4: probability: 0.01, label: siamang
# 5: probability: 0.00, label: langur
# /home/w266ajh/Documents/top5gen/data_imageparts_1/colobus5.jpg
# 1: probability: 0.90, label: colobus
# 2: probability: 0.03, label: capuchin
# 3: probability: 0.03, label: guenon
# 4: probability: 0.02, label: titi
# 5: probability: 0.01, label: gibbon
# /home/w266ajh/Documents/top5gen/data_imageparts_1/jackfruit1.jpg
# 1: probability: 1.00, label: jackfruit
# 2: probability: 0.00, label: brain coral
# 3: probability: 0.00, label: stingray
# 4: probability: 0.00, label: bolete
# 5: probability: 0.00, label: tench
# /home/w266ajh/Documents/top5gen/data_imageparts_1/jackfruit2.jpg
# 1: probability: 1.00, label: jackfruit
# 2: probability: 0.00, label: brain coral
# 3: probability: 0.00, label: broccoli
# 4: probability: 0.00, label: sea urchin
# 5: probability: 0.00, label: strainer
# /home/w266ajh/Documents/top5gen/data_imageparts_1/jackfruit3.jpg
# 1: probability: 1.00, label: jackfruit
# 2: probability: 0.00, label: bolete
# 3: probability: 0.00, label: lemon
# 4: probability: 0.00, label: honeycomb
# 5: probability: 0.00, label: green snake
# /home/w266ajh/Documents/top5gen/data_imageparts_1/jackfruit4.jpg
# 1: probability: 0.98, label: jackfruit
# 2: probability: 0.01, label: bolete
# 3: probability: 0.00, label: honeycomb
# 4: probability: 0.00, label: lemon
# 5: probability: 0.00, label: buckeye
# /home/w266ajh/Documents/top5gen/data_imageparts_1/jackfruit5.jpg
# 1: probability: 0.99, label: jackfruit
# 2: probability: 0.00, label: green snake
# 3: probability: 0.00, label: lemon
# 4: probability: 0.00, label: tree frog
# 5: probability: 0.00, label: green mamba
# /home/w266ajh/Documents/top5gen/data_imageparts_1/nematode1.jpg
# 1: probability: 1.00, label: nematode
# 2: probability: 0.00, label: vine snake
# 3: probability: 0.00, label: oscilloscope
# 4: probability: 0.00, label: velvet
# 5: probability: 0.00, label: night snake
# /home/w266ajh/Documents/top5gen/data_imageparts_1/nematode2.jpg
# 1: probability: 1.00, label: nematode
# 2: probability: 0.00, label: letter opener
# 3: probability: 0.00, label: sea snake
# 4: probability: 0.00, label: gar
# 5: probability: 0.00, label: eel
# /home/w266ajh/Documents/top5gen/data_imageparts_1/nematode3.jpg
# 1: probability: 0.98, label: nematode
# 2: probability: 0.00, label: grey whale
# 3: probability: 0.00, label: velvet
# 4: probability: 0.00, label: isopod
# 5: probability: 0.00, label: gar
# /home/w266ajh/Documents/top5gen/data_imageparts_1/nematode4.jpg
# 1: probability: 1.00, label: nematode
# 2: probability: 0.00, label: rule
# 3: probability: 0.00, label: slide rule
# 4: probability: 0.00, label: gar
# 5: probability: 0.00, label: lacewing
# /home/w266ajh/Documents/top5gen/data_imageparts_1/nematode5.jpg
# 1: probability: 1.00, label: nematode
# 2: probability: 0.00, label: velvet
# 3: probability: 0.00, label: grey whale
# 4: probability: 0.00, label: spotlight
# 5: probability: 0.00, label: stove
# /home/w266ajh/Documents/top5gen/data_imageparts_1/remote1.jpg
# 1: probability: 1.00, label: remote control
# 2: probability: 0.00, label: microwave
# 3: probability: 0.00, label: dial telephone
# 4: probability: 0.00, label: radio
# 5: probability: 0.00, label: CD player
# /home/w266ajh/Documents/top5gen/data_imageparts_1/remote2.jpg
# 1: probability: 1.00, label: remote control
# 2: probability: 0.00, label: Band Aid
# 3: probability: 0.00, label: space bar
# 4: probability: 0.00, label: spotted salamander
# 5: probability: 0.00, label: modem
# /home/w266ajh/Documents/top5gen/data_imageparts_1/remote3.jpg
# 1: probability: 1.00, label: remote control
# 2: probability: 0.00, label: switch
# 3: probability: 0.00, label: hand-held computer
# 4: probability: 0.00, label: cellular telephone
# 5: probability: 0.00, label: joystick
# /home/w266ajh/Documents/top5gen/data_imageparts_1/remote4.jpg
# 1: probability: 1.00, label: remote control
# 2: probability: 0.00, label: joystick
# 3: probability: 0.00, label: switch
# 4: probability: 0.00, label: space bar
# 5: probability: 0.00, label: thimble
# /home/w266ajh/Documents/top5gen/data_imageparts_1/remote5.jpg
# 1: probability: 0.97, label: remote control
# 2: probability: 0.00, label: CD player
# 3: probability: 0.00, label: combination lock
# 4: probability: 0.00, label: radio
# 5: probability: 0.00, label: cellular telephone
# /home/w266ajh/Documents/top5gen/data_imageparts_1/rule1.jpg
# 1: probability: 0.99, label: slide rule
# 2: probability: 0.01, label: rule
# 3: probability: 0.00, label: computer keyboard
# 4: probability: 0.00, label: brass
# 5: probability: 0.00, label: envelope
# /home/w266ajh/Documents/top5gen/data_imageparts_1/rule2.jpg
# 1: probability: 0.94, label: slide rule
# 2: probability: 0.02, label: cassette player
# 3: probability: 0.01, label: rule
# 4: probability: 0.00, label: web site
# 5: probability: 0.00, label: oscilloscope
# /home/w266ajh/Documents/top5gen/data_imageparts_1/rule3.jpg
# 1: probability: 1.00, label: slide rule
# 2: probability: 0.00, label: rule
# 3: probability: 0.00, label: computer keyboard
# 4: probability: 0.00, label: space bar
# 5: probability: 0.00, label: crossword puzzle
# /home/w266ajh/Documents/top5gen/data_imageparts_1/rule4.jpg
# 1: probability: 1.00, label: slide rule
# 2: probability: 0.00, label: rule
# 3: probability: 0.00, label: harmonica
# 4: probability: 0.00, label: cleaver
# 5: probability: 0.00, label: letter opener
# /home/w266ajh/Documents/top5gen/data_imageparts_1/rule5.jpg
# 1: probability: 1.00, label: slide rule
# 2: probability: 0.00, label: rule
# 3: probability: 0.00, label: computer keyboard
# 4: probability: 0.00, label: syringe
# 5: probability: 0.00, label: menu
# /home/w266ajh/Documents/top5gen/data_imageparts_1/schoolbus1.jpg
# 1: probability: 1.00, label: school bus
# 2: probability: 0.00, label: passenger car
# 3: probability: 0.00, label: trolleybus
# 4: probability: 0.00, label: minibus
# 5: probability: 0.00, label: streetcar
# /home/w266ajh/Documents/top5gen/data_imageparts_1/schoolbus2.jpg
# 1: probability: 1.00, label: school bus
# 2: probability: 0.00, label: cab
# 3: probability: 0.00, label: moving van
# 4: probability: 0.00, label: minibus
# 5: probability: 0.00, label: ambulance
# /home/w266ajh/Documents/top5gen/data_imageparts_1/schoolbus3.jpg
# 1: probability: 1.00, label: school bus
# 2: probability: 0.00, label: cab
# 3: probability: 0.00, label: minibus
# 4: probability: 0.00, label: moving van
# 5: probability: 0.00, label: ambulance
# /home/w266ajh/Documents/top5gen/data_imageparts_1/schoolbus4.jpg
# 1: probability: 1.00, label: school bus
# 2: probability: 0.00, label: passenger car
# 3: probability: 0.00, label: minibus
# 4: probability: 0.00, label: streetcar
# 5: probability: 0.00, label: trolleybus
# /home/w266ajh/Documents/top5gen/data_imageparts_1/schoolbus5.jpg
# 1: probability: 1.00, label: school bus
# 2: probability: 0.00, label: moving van
# 3: probability: 0.00, label: minibus
# 4: probability: 0.00, label: ambulance
# 5: probability: 0.00, label: trailer truck
# /home/w266ajh/Documents/top5gen/data_imageparts_1/stocking1.jpg
# 1: probability: 1.00, label: Christmas stocking
# 2: probability: 0.00, label: sock
# 3: probability: 0.00, label: mitten
# 4: probability: 0.00, label: punching bag
# 5: probability: 0.00, label: teddy
# /home/w266ajh/Documents/top5gen/data_imageparts_1/stocking2.jpg
# 1: probability: 0.92, label: Christmas stocking
# 2: probability: 0.06, label: sock
# 3: probability: 0.01, label: mitten
# 4: probability: 0.00, label: wool
# 5: probability: 0.00, label: clog
# /home/w266ajh/Documents/top5gen/data_imageparts_1/stocking3.jpg
# 1: probability: 1.00, label: Christmas stocking
# 2: probability: 0.00, label: sock
# 3: probability: 0.00, label: mitten
# 4: probability: 0.00, label: wool
# 5: probability: 0.00, label: cowboy boot
# /home/w266ajh/Documents/top5gen/data_imageparts_1/stocking4.jpg
# 1: probability: 1.00, label: Christmas stocking
# 2: probability: 0.00, label: sock
# 3: probability: 0.00, label: punching bag
# 4: probability: 0.00, label: doormat
# 5: probability: 0.00, label: iPod
# /home/w266ajh/Documents/top5gen/data_imageparts_1/stocking5.jpg
# 1: probability: 1.00, label: Christmas stocking
# 2: probability: 0.00, label: sock
# 3: probability: 0.00, label: apron
# 4: probability: 0.00, label: diaper
# 5: probability: 0.00, label: mailbag
# /home/w266ajh/Documents/top5gen/data_imageparts_1/train1.jpg
# 1: probability: 1.00, label: bullet train
# 2: probability: 0.00, label: bobsled
# 3: probability: 0.00, label: missile
# 4: probability: 0.00, label: passenger car
# 5: probability: 0.00, label: projectile
# /home/w266ajh/Documents/top5gen/data_imageparts_1/train2.jpg
# 1: probability: 1.00, label: bullet train
# 2: probability: 0.00, label: passenger car
# 3: probability: 0.00, label: electric locomotive
# 4: probability: 0.00, label: space shuttle
# 5: probability: 0.00, label: bobsled
# /home/w266ajh/Documents/top5gen/data_imageparts_1/train3.jpg
# 1: probability: 1.00, label: bullet train
# 2: probability: 0.00, label: bobsled
# 3: probability: 0.00, label: passenger car
# 4: probability: 0.00, label: submarine
# 5: probability: 0.00, label: streetcar
# /home/w266ajh/Documents/top5gen/data_imageparts_1/train4.jpg
# 1: probability: 1.00, label: bullet train
# 2: probability: 0.00, label: bobsled
# 3: probability: 0.00, label: passenger car
# 4: probability: 0.00, label: limousine
# 5: probability: 0.00, label: streetcar
# /home/w266ajh/Documents/top5gen/data_imageparts_1/train5.jpg
# 1: probability: 0.95, label: bullet train
# 2: probability: 0.03, label: bobsled
# 3: probability: 0.01, label: wing
# 4: probability: 0.00, label: warplane
# 5: probability: 0.00, label: speedboat
# /home/w266ajh/Documents/top5gen/data_imageparts_1/weevil1.jpg
# 1: probability: 0.98, label: weevil
# 2: probability: 0.00, label: long-horned beetle
# 3: probability: 0.00, label: wolf spider
# 4: probability: 0.00, label: ground beetle
# 5: probability: 0.00, label: barn spider
# /home/w266ajh/Documents/top5gen/data_imageparts_1/weevil2.jpg
# 1: probability: 1.00, label: weevil
# 2: probability: 0.00, label: leaf beetle
# 3: probability: 0.00, label: long-horned beetle
# 4: probability: 0.00, label: ground beetle
# 5: probability: 0.00, label: rhinoceros beetle
# /home/w266ajh/Documents/top5gen/data_imageparts_1/weevil3.jpg
# 1: probability: 0.97, label: weevil
# 2: probability: 0.01, label: long-horned beetle
# 3: probability: 0.00, label: dung beetle
# 4: probability: 0.00, label: leaf beetle
# 5: probability: 0.00, label: ant
# /home/w266ajh/Documents/top5gen/data_imageparts_1/weevil4.jpg
# 1: probability: 0.99, label: weevil
# 2: probability: 0.00, label: long-horned beetle
# 3: probability: 0.00, label: dung beetle
# 4: probability: 0.00, label: leaf beetle
# 5: probability: 0.00, label: ground beetle
# /home/w266ajh/Documents/top5gen/data_imageparts_1/weevil5.jpg
# 1: probability: 0.96, label: weevil
# 2: probability: 0.01, label: dung beetle
# 3: probability: 0.01, label: long-horned beetle
# 4: probability: 0.01, label: leafhopper
# 5: probability: 0.00, label: leaf beetle
